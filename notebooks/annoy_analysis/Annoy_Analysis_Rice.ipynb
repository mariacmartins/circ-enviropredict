# %% [markdown]
# # Annoy Analysis:
# Annoy (Approximate Nearest Neighbors Oh Yeah) is an efficient technique for finding nearest neighbors in large datasets, particularly in applications involving vectors, such as machine learning and information retrieval.
#
# ## How Annoy Works:
#
# Data (typically vectors) are added to an index. Each vector represents a numerical representation of an item.
#
# Tree Division: Annoy builds multiple search trees, where each tree is constructed based on a random sample of the data. The idea is to partition the space into regions, allowing for faster neighbor searches.
#
# Search Algorithm:
# When querying a vector, Annoy searches through the constructed trees. It traverses the trees to find the nearest neighbors.
# The algorithm is designed to be fast, using approximation, which means it might not always find the exact nearest neighbors but frequently finds very close neighbors efficiently.

# %%
# !pip install annoy
# Out:
# Collecting annoy
#   Downloading annoy-1.17.3.tar.gz (647 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.5/647.5 kB 9.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: annoy
#   Building wheel for annoy (setup.py) ... done
#   Created wheel for annoy: filename=annoy-1.17.3-cp310-cp310-linux_x86_64.whl size=552448 sha256=ab261789336281aba0524ada12a8054b4ef5fc099dc0a10d71c39cc51f9c7eee
#   Stored in directory: /root/.cache/pip/wheels/64/8a/da/f714bcf46c5efdcfcac0559e63370c21abe961c48e3992465a
# Successfully built annoy
# Installing collected packages: annoy
# Successfully installed annoy-1.17.3

# %%
# Import Libs
import pandas as pd
from annoy import AnnoyIndex

# %%
df = pd.read_excel('/content/rice_word2vec_3mer_dataset.xlsx')

# %%
df.head(2)
# Out:
#                  circName stress          tissue  chr     start       end  \
# 0  osa-circ1-OS01T0723400      -  multipleTissue    1  30167620  30167771
# 1  osa-circ2-OS03T0223400      -  multipleTissue    3   6461672   6462146
#
#   strand start_anno  wc_3mer_1  wc_3mer_2  ...  wc_3mer_55  wc_3mer_56  \
# 0      +   exon,CDS  -3.738741   8.954664  ...  -25.198840    2.249939
# 1      -   exon,CDS  31.042567  37.664923  ...  -27.264821   51.359450
#
#    wc_3mer_57  wc_3mer_58  wc_3mer_59  wc_3mer_60  wc_3mer_61  wc_3mer_62  \
# 0   -4.701558   -3.633969    5.212902   -6.579618   11.032136   -8.533007
# 1  -73.188428   -1.662928   56.565280   28.610637   80.878607   38.090248
#
#    wc_3mer_63  wc_3mer_64
# 0    -8.32791   18.141064
# 1   -30.54351   28.859375
#
# [2 rows x 72 columns]

# %% [markdown]
# # Cold stress dataset

# %%
df_cold = df.query('stress == "-" or stress == "cold"').replace('-', 'control')

# %%
df_vec = df_cold.drop(['tissue','chr','start','end','strand','start_anno'], axis=1)
df_vec
# Out:
#                      circName   stress  wc_3mer_1  wc_3mer_2  wc_3mer_3  \
# 0      osa-circ1-OS01T0723400  control  -3.738741   8.954664   0.703204
# 1      osa-circ2-OS03T0223400  control  31.042567  37.664923  95.821671
# 2      osa-circ3-OS11T0210300  control -31.307338  14.101101   6.012345
# 3      osa-circ4-OS02T0200900  control  15.773287  55.951050  71.105993
# 4      osa-circ5-OS05T0494800  control -44.379635 -33.514299   9.594330
# ...                       ...      ...        ...        ...        ...
# 63043         osa-circ63044--  control   1.187543  33.638602  46.761491
# 63044         osa-circ63045--  control -80.622757   6.318129  -2.366743
# 63045         osa-circ63046--  control -74.383266 -15.111880  -5.831784
# 63046         osa-circ63047--  control  15.836808  18.807946   3.763431
# 63047         osa-circ63048--  control  13.275132  14.006887 -16.164613
#
#        wc_3mer_4  wc_3mer_5  wc_3mer_6  wc_3mer_7   wc_3mer_8  ...  \
# 0      -7.427550   9.996643  -0.181532  18.598464  -34.975266  ...
# 1     -13.835744 -44.356329  15.314592  45.651881  -14.309955  ...
# 2     -38.559886  47.126226  -4.402491  -2.144210 -110.080545  ...
# 3      11.420289 -15.831468 -30.626971  37.164693  -23.572454  ...
# 4     -28.682953  23.765476  24.619851 -26.153289  -72.517970  ...
# ...          ...        ...        ...        ...         ...  ...
# 63043  33.606569 -28.457826 -18.402121  19.510404   26.983153  ...
# 63044  16.879751 -30.253832 -43.023873 -19.773850   -1.661586  ...
# 63045 -13.084491 -20.186291 -32.085257 -11.033929  -44.055941  ...
# 63046   5.834760 -12.692529  13.718565  11.533184  -19.348844  ...
# 63047  31.301259 -24.821918 -18.592994  36.497289   56.680641  ...
#
#        wc_3mer_55  wc_3mer_56  wc_3mer_57  wc_3mer_58  wc_3mer_59  wc_3mer_60  \
# 0      -25.198840    2.249939   -4.701558   -3.633969    5.212902   -6.579618
# 1      -27.264821   51.359450  -73.188428   -1.662928   56.565280   28.610637
# 2      -69.366830    1.113416  -42.689580   -6.150814   23.203639   -7.541412
# 3       42.391724   50.721551  -67.643923  -24.403869   41.171276   45.067768
# 4      -75.243917  -36.308267    7.583992  -27.560256  -24.934966  -15.739278
# ...           ...         ...         ...         ...         ...         ...
# 63043   39.581378    5.624058  -18.996478  -32.586105   -8.206610   38.324260
# 63044   22.650734  -26.579853  -16.502095 -137.357917  -76.090281  117.878950
# 63045  -16.439233   -7.612099  -29.730788  -98.997580  -40.800622   88.914954
# 63046   23.810030   14.158860  -25.809598   -1.792872   -4.828570    6.402574
# 63047   24.301647    7.611070   22.699691    0.278573  -20.886769   15.526908
#
#        wc_3mer_61  wc_3mer_62  wc_3mer_63  wc_3mer_64
# 0       11.032136   -8.533007   -8.327910   18.141064
# 1       80.878607   38.090248  -30.543510   28.859375
# 2      -11.218056  -40.615067   16.391329    1.324206
# 3        9.704687    9.653121    7.829608  -11.254961
# 4        9.237141  -16.380438  -18.462203    7.718794
# ...           ...         ...         ...         ...
# 63043    2.731934   28.181426    3.800943  -12.217631
# 63044 -128.438327   -9.823361    4.179330  -43.925242
# 63045  -93.826379  -28.685970  -15.167838  -35.795096
# 63046   10.700880    3.991035   -6.085688    4.940037
# 63047    4.474708   11.044193  -19.796999   34.250569
#
# [55911 rows x 66 columns]

# %%
df_vec['stress'].value_counts()
# Out:
# stress
# control    50187
# cold        5724
# Name: count, dtype: int64

# %%
dimension = 64

# %%
cold_sequences = df_vec[df_vec['stress'] == 'cold']
control_sequences = df_vec[df_vec['stress'] == 'control']

# creating sample
control_sample = control_sequences.sample(n=5724, random_state=42)

combined_sequences = pd.concat([cold_sequences, control_sample])

t = AnnoyIndex(dimension, 'angular')
for i in range(len(combined_sequences)):
    t.add_item(i, combined_sequences.iloc[i, 2:2 + dimension].values)
t.build(10)

similarities = {}
n_vizinhos = 5  # number of neighbors

# Analyzing only 'cold' sequences
for estresse_index in cold_sequences.index:
    if estresse_index < len(df_vec):
        adjusted_index = combined_sequences.index.get_loc(estresse_index)

        #Search neighbors
        vizinhos = t.get_nns_by_item(adjusted_index, n_vizinhos + 1)
        valid_vizinhos = []

        for i in vizinhos:
            if combined_sequences.iloc[i]['circName'] != combined_sequences.iloc[adjusted_index]['circName']:
                valid_vizinhos.append(i)
            if len(valid_vizinhos) == n_vizinhos:
                break

        similarities[estresse_index] = valid_vizinhos

# Results
cold_count = 0
control_count = 0
control_neighbors = set()

with open('neighbors_results.txt', 'w') as f:
  for estresse_index, vizinhos in similarities.items():
      cold_sequence = combined_sequences.iloc[combined_sequences.index.get_loc(estresse_index)]['circName']
      similar_sequences = [combined_sequences.iloc[i]['circName'] for i in vizinhos]
      similar_conditions = [combined_sequences.iloc[i]['stress'] for i in vizinhos]

      for i in vizinhos:
          if combined_sequences.iloc[i]['stress'] == 'control':
              control_neighbors.add(i)

      cold_count += similar_conditions.count('cold')

      print(f'Seq of "cold" group: {cold_sequence}')
      f.write(f'Seq of "cold" group: {cold_sequence}\n')

      for seq, cond in zip(similar_sequences, similar_conditions):
          print(f'Nearest neighbors: {seq}, Condition: {cond}')
          f.write(f'Nearest neighbors: {seq}, Condition: {cond}\n')

control_count = len(control_neighbors)

# Similarity analysis
total_vizinhos = len(similarities) * n_vizinhos
num_cold_sequences = len(cold_sequences)

print(f'Number of iterated cold stress sequences: {num_cold_sequences}')
print(f'Total number of neighbors in the "cold" group: {cold_count}')
print(f'Total number of neighbors in the "control" group": {control_count}')
print(f'Percentage of neighbors in the "cold" group: {cold_count / total_vizinhos * 100:.2f}%')
print(f'Percentage of neighbors in the "control" group: {control_count / total_vizinhos * 100:.2f}%')
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Nearest neighbors: osa-circ58565-OS01T0655500, Condition: cold
# Nearest neighbors: osa-circ43075-OS03T0171900, Condition: cold
# Nearest neighbors: osa-circ58134-OS02T0121000, Condition: cold
# Seq of "cold" group: osa-circ43625-OS09T0280300
# Nearest neighbors: osa-circ41297-OS01T0775300, Condition: cold
# Nearest neighbors: osa-circ58905-OS10T0566300, Condition: cold
# Nearest neighbors: osa-circ8532-OS02T0664100, Condition: control
# Nearest neighbors: osa-circ18570-OS01T0323000, Condition: control
# Nearest neighbors: osa-circ59208-OS06T0495700, Condition: cold
# Seq of "cold" group: osa-circ43626-OS09T0327400
# Nearest neighbors: osa-circ42002-OS01T0695300, Condition: cold
# Nearest neighbors: osa-circ41650-OS01T0841600, Condition: cold
# Nearest neighbors: osa-circ10595-OS03T0646900, Condition: control
# Nearest neighbors: osa-circ41912-OS04T0252200, Condition: cold
# Nearest neighbors: osa-circ42992-OS08T0474700, Condition: cold
# Seq of "cold" group: osa-circ43627-OS09T0332700
# Nearest neighbors: osa-circ44624-OS04T0602800, Condition: cold
# Nearest neighbors: osa-circ23416-OS01T0681200, Condition: control
# Nearest neighbors: osa-circ16167-OS01T0164700, Condition: control
# Nearest neighbors: osa-circ22558-OS12T0576700, Condition: control
# Nearest neighbors: osa-circ59370-OS02T0148000, Condition: control
# Seq of "cold" group: osa-circ43628-OS09T0344800
# Nearest neighbors: osa-circ40216-OS09T0344800, Condition: control
# Nearest neighbors: osa-circ41263-OS12T0233300, Condition: cold
# Nearest neighbors: osa-circ58004-OS06T0297700, Condition: cold
# Nearest neighbors: osa-circ41464-OS12T0138900, Condition: cold
# Nearest neighbors: osa-circ58602-OS02T0221600, Condition: cold
# Seq of "cold" group: osa-circ43629-OS09T0401300
# Nearest neighbors: osa-circ25875-OS02T0250400, Condition: control
# Nearest neighbors: osa-circ49475--, Condition: control
# Nearest neighbors: osa-circ48477--, Condition: control
# Nearest neighbors: osa-circ54738-OS05T0473500, Condition: control
# Nearest neighbors: osa-circ13665-OS03T0831700, Condition: control
# Seq of "cold" group: osa-circ43630-OS09T0454600
# Nearest neighbors: osa-circ21898-OS10T0132300, Condition: control
# Nearest neighbors: osa-circ22781-OS01T0170500, Condition: control
# Nearest neighbors: osa-circ44650-OS07T0684100, Condition: cold
# Nearest neighbors: osa-circ10454-OS01T0805200, Condition: control
# Nearest neighbors: osa-circ2365-OS03T0177400, Condition: control
# Seq of "cold" group: osa-circ43631-OS09T0520700
# Nearest neighbors: osa-circ15919-OS10T0456900, Condition: control
# Nearest neighbors: osa-circ30144-OS09T0533900, Condition: control
# Nearest neighbors: osa-circ27531-OS05T0582100, Condition: control
# Nearest neighbors: osa-circ50677-OS10T0536000, Condition: control
# Nearest neighbors: osa-circ44584-OS02T0797425, Condition: cold
# Seq of "cold" group: osa-circ43632-OS09T0556400
# Nearest neighbors: osa-circ60571-OS03T0168400, Condition: cold
# Nearest neighbors: osa-circ57949-OS07T0559700, Condition: cold
# Nearest neighbors: osa-circ50547-OS07T0559700, Condition: cold
# Nearest neighbors: osa-circ60579-OS03T0783700, Condition: cold
# Nearest neighbors: osa-circ58765-OS04T0218701, Condition: cold
# Seq of "cold" group: osa-circ43633-OS09T0563200
# Nearest neighbors: osa-circ15483-OS01T0816400, Condition: control
# Nearest neighbors: osa-circ43671-OS12T0560600, Condition: cold
# Nearest neighbors: osa-circ6759-OS04T0467901, Condition: control
# Nearest neighbors: osa-circ5730-OS01T0748600, Condition: control
# Nearest neighbors: osa-circ12249-OS02T0685900, Condition: cold
# Seq of "cold" group: osa-circ43634-OS08T0129700
# Nearest neighbors: osa-circ43635-OS08T0129700, Condition: cold
# Nearest neighbors: osa-circ55520-OS03T0110900, Condition: control
# Nearest neighbors: osa-circ55794-OS04T0684100, Condition: control
# Nearest neighbors: osa-circ60581-OS02T0173800, Condition: cold
# Nearest neighbors: osa-circ58089-OS05T0388600, Condition: cold
# Seq of "cold" group: osa-circ43635-OS08T0129700
# Nearest neighbors: osa-circ43634-OS08T0129700, Condition: cold
# Nearest neighbors: osa-circ55520-OS03T0110900, Condition: control
# Nearest neighbors: osa-circ55794-OS04T0684100, Condition: control
# Nearest neighbors: osa-circ60581-OS02T0173800, Condition: cold
# Nearest neighbors: osa-circ58089-OS05T0388600, Condition: cold
# Seq of "cold" group: osa-circ43636-OS08T0156600
# Nearest neighbors: osa-circ12406-OS08T0156600, Condition: cold
# Nearest neighbors: osa-circ52525-OS01T0103800, Condition: control
# Nearest neighbors: osa-circ43543-OS02T0744700, Condition: cold
# Nearest neighbors: osa-circ57912-OS04T0436100, Condition: control
# Nearest neighbors: osa-circ59958-OS04T0431100, Condition: cold
# Seq of "cold" group: osa-circ43637-OS08T0158500
# Nearest neighbors: osa-circ48271--, Condition: control
# Nearest neighbors: osa-circ42804-OS01T0744400, Condition: cold
# Nearest neighbors: osa-circ15959-OS03T0680800, Condition: control
# Nearest neighbors: osa-circ43099-OS03T0680800, Condition: cold
# Nearest neighbors: osa-circ3080-OS10T0209700, Condition: control
# Seq of "cold" group: osa-circ43638-OS08T0295300
# Nearest neighbors: osa-circ59216-OS08T0178700, Condition: cold
# Nearest neighbors: osa-circ53567-OS11T0302900, Condition: control
# Nearest neighbors: osa-circ22554-OS12T0572400, Condition: control
# Nearest neighbors: osa-circ52998-OS11T0546100, Condition: control
# Nearest neighbors: osa-circ57948-OS04T0530300, Condition: cold
# Seq of "cold" group: osa-circ43639-OS08T0314800
# Nearest neighbors: osa-circ40432-OS03T0859700, Condition: cold
# Nearest neighbors: osa-circ41509-OS03T0689100, Condition: cold
# Nearest neighbors: osa-circ40506-OS09T0411700, Condition: cold
# Nearest neighbors: osa-circ25016-OS03T0666200, Condition: control
# Nearest neighbors: osa-circ53936-OS11T0189900, Condition: control
# Seq of "cold" group: osa-circ43640-OS08T0360300
# Nearest neighbors: osa-circ41312-OS03T0143700, Condition: cold
# Nearest neighbors: osa-circ42085-OS09T0401200, Condition: cold
# Nearest neighbors: osa-circ7493-OS08T0338200, Condition: control
# Nearest neighbors: osa-circ12301-OS08T0357000, Condition: cold
# Nearest neighbors: osa-circ43334-OS02T0564000, Condition: cold
# Seq of "cold" group: osa-circ43641-OS08T0436000
# Nearest neighbors: osa-circ40437-OS02T0819500, Condition: cold
# Nearest neighbors: osa-circ59372-OS02T0208500, Condition: control
# Nearest neighbors: osa-circ25308-OS03T0773600, Condition: control
# Nearest neighbors: osa-circ32280-OS03T0786100, Condition: control
# Nearest neighbors: osa-circ9607-OS05T0411300, Condition: control
# Seq of "cold" group: osa-circ43642-OS08T0451000
# Nearest neighbors: osa-circ15600-OS01T0617500, Condition: control
# Nearest neighbors: osa-circ23108-OS01T0502400, Condition: control
# Nearest neighbors: osa-circ16555-OS03T0776000, Condition: control
# Nearest neighbors: osa-circ20415-OS04T0414100, Condition: control
# Nearest neighbors: osa-circ20564-OS02T0745000, Condition: control
# Seq of "cold" group: osa-circ43643-OS08T0480100
# Nearest neighbors: osa-circ2086-OS06T0561000, Condition: control
# Nearest neighbors: osa-circ43654-OS11T0518900, Condition: cold
# Nearest neighbors: osa-circ24255-OS03T0154750, Condition: control
# Nearest neighbors: osa-circ6942-OS03T0646900, Condition: control
# Nearest neighbors: osa-circ145-OS03T0278300, Condition: control
# Seq of "cold" group: osa-circ43644-OS08T0497600
# Nearest neighbors: osa-circ44067-OS09T0531100, Condition: cold
# Nearest neighbors: osa-circ33587-OS08T0220600, Condition: control
# Nearest neighbors: osa-circ41326-OS03T0412800, Condition: cold
# Nearest neighbors: osa-circ33010-OS04T0632300, Condition: control
# Nearest neighbors: osa-circ25817-OS02T0216300, Condition: control
# Seq of "cold" group: osa-circ43645-OS08T0520900
# Nearest neighbors: osa-circ21369-OS09T0526700, Condition: control
# Nearest neighbors: osa-circ4841-OS06T0152100, Condition: control
# Nearest neighbors: osa-circ43439-OS12T0134000, Condition: cold
# Nearest neighbors: osa-circ36690-OS02T0709400, Condition: control
# Nearest neighbors: osa-circ23544-OS01T0750666, Condition: control
# Seq of "cold" group: osa-circ43646-OS08T0521400
# Nearest neighbors: osa-circ53293-OS10T0573100, Condition: control
# Nearest neighbors: osa-circ41781-OS11T0168300, Condition: cold
# Nearest neighbors: osa-circ41231-OS08T0198700, Condition: cold
# Nearest neighbors: osa-circ43420-OS11T0264300, Condition: cold
# Nearest neighbors: osa-circ31999-OS01T0966500, Condition: control
# Seq of "cold" group: osa-circ43647-OS08T0560500
# Nearest neighbors: osa-circ13560-OS02T0571100, Condition: control
# Nearest neighbors: osa-circ3479-OS02T0276900, Condition: control
# Nearest neighbors: osa-circ31567-OS12T0176700, Condition: control
# Nearest neighbors: osa-circ27277-OS05T0475400, Condition: control
# Nearest neighbors: osa-circ40327-OS03T0291500, Condition: cold
# Seq of "cold" group: osa-circ43648-OS08T0562700
# Nearest neighbors: osa-circ41422-OS06T0712300, Condition: cold
# Nearest neighbors: osa-circ41952-OS06T0712300, Condition: cold
# Nearest neighbors: osa-circ44715-OS10T0571200, Condition: control
# Nearest neighbors: osa-circ41120-OS03T0101900, Condition: cold
# Nearest neighbors: osa-circ43101-OS03T0726500, Condition: cold
# Seq of "cold" group: osa-circ43649-OS08T0562700
# Nearest neighbors: osa-circ12081-OS03T0212700, Condition: cold
# Nearest neighbors: osa-circ2879-OS02T0672200, Condition: control
# Nearest neighbors: osa-circ29811-OS06T0728800, Condition: control
# Nearest neighbors: osa-circ22389-OS12T0238100, Condition: control
# Nearest neighbors: osa-circ9288-OS03T0430400, Condition: control
# Seq of "cold" group: osa-circ43650-OS11T0191400
# Nearest neighbors: osa-circ53919-OS11T0139900, Condition: control
# Nearest neighbors: osa-circ60091-OS07T0213400, Condition: cold
# Nearest neighbors: osa-circ60308-OS01T0915800, Condition: cold
# Nearest neighbors: osa-circ40631-OS03T0825700, Condition: control
# Nearest neighbors: osa-circ41441-OS08T0379400, Condition: cold
# Seq of "cold" group: osa-circ43651-OS11T0206700
# Nearest neighbors: osa-circ5056-OS01T0883200, Condition: control
# Nearest neighbors: osa-circ5230-OS04T0550400, Condition: control
# Nearest neighbors: osa-circ21801-OS11T0592200, Condition: control
# Nearest neighbors: osa-circ1714-OS06T0265000, Condition: control
# Nearest neighbors: osa-circ41319-OS03T0309200, Condition: cold
# Seq of "cold" group: osa-circ43652-OS11T0207200
# Nearest neighbors: osa-circ49385--, Condition: control
# Nearest neighbors: osa-circ2519-OS02T0735200, Condition: control
# Nearest neighbors: osa-circ12891-OS01T0872700, Condition: control
# Nearest neighbors: osa-circ60104-OS06T0505302, Condition: cold
# Nearest neighbors: osa-circ37282-OS06T0625400, Condition: control
# Seq of "cold" group: osa-circ43653-OS11T0482100
# Nearest neighbors: osa-circ30772-OS08T0557900, Condition: control
# Nearest neighbors: osa-circ43711-OS03T0194500, Condition: cold
# Nearest neighbors: osa-circ62625-OS03T0833700, Condition: cold
# Nearest neighbors: osa-circ8809-OS06T0715500, Condition: control
# Nearest neighbors: osa-circ26855-OS05T0135800, Condition: control
# Seq of "cold" group: osa-circ43654-OS11T0518900
# Nearest neighbors: osa-circ43643-OS08T0480100, Condition: cold
# Nearest neighbors: osa-circ2086-OS06T0561000, Condition: control
# Nearest neighbors: osa-circ43692-OS01T0805700, Condition: cold
# Nearest neighbors: osa-circ17847-OS03T0750100, Condition: control
# Nearest neighbors: osa-circ43143-OS02T0810400, Condition: cold
# Seq of "cold" group: osa-circ43655-OS11T0525600
# Nearest neighbors: osa-circ43369-OS04T0538000, Condition: cold
# Nearest neighbors: osa-circ41718-OS05T0588800, Condition: cold
# Nearest neighbors: osa-circ53879-OS03T0747800, Condition: control
# Nearest neighbors: osa-circ61776-OS01T0372350, Condition: control
# Nearest neighbors: osa-circ52730-OS03T0710700, Condition: control
# Seq of "cold" group: osa-circ43656-OS11T0537375
# Nearest neighbors: osa-circ62222-OS03T0386000, Condition: cold
# Nearest neighbors: osa-circ22657-OS12T0634900, Condition: control
# Nearest neighbors: osa-circ7008-OS04T0229100, Condition: control
# Nearest neighbors: osa-circ7578-OS01T0978000, Condition: control
# Nearest neighbors: osa-circ23698-OS01T0823100, Condition: control
# Seq of "cold" group: osa-circ43657-OS11T0582300
# Nearest neighbors: osa-circ43648-OS08T0562700, Condition: cold
# Nearest neighbors: osa-circ58588-OS03T0385400, Condition: cold
# Nearest neighbors: osa-circ25276-OS03T0755800, Condition: control
# Nearest neighbors: osa-circ43284-OS01T0147200, Condition: cold
# Nearest neighbors: osa-circ15731-OS01T0232500, Condition: control
# Seq of "cold" group: osa-circ43658-OS11T0603200
# Nearest neighbors: osa-circ59055-OS01T0930400, Condition: cold
# Nearest neighbors: osa-circ41629-OS12T0225150, Condition: cold
# Nearest neighbors: osa-circ19729-OS02T0579600, Condition: control
# Nearest neighbors: osa-circ53859-OS08T0401500, Condition: control
# Nearest neighbors: osa-circ42008-OS01T0880200, Condition: cold
# Seq of "cold" group: osa-circ43659-OS11T0604600
# Nearest neighbors: osa-circ37394-OS09T0481700, Condition: control
# Nearest neighbors: osa-circ40269-OS05T0524400, Condition: cold
# Nearest neighbors: osa-circ60371-OS04T0613400, Condition: cold
# Nearest neighbors: osa-circ41027-OS04T0601800, Condition: control
# Nearest neighbors: osa-circ24345-OS03T0197400, Condition: control
# Seq of "cold" group: osa-circ43660-OS11T0657100
# Nearest neighbors: osa-circ43425-OS10T0118900, Condition: cold
# Nearest neighbors: osa-circ22435-OS12T0406200, Condition: control
# Nearest neighbors: osa-circ43339-OS02T0702400, Condition: cold
# Nearest neighbors: osa-circ42039-OS02T0717400, Condition: cold
# Nearest neighbors: osa-circ8809-OS06T0715500, Condition: control
# Seq of "cold" group: osa-circ43661-OS10T0345100
# Nearest neighbors: osa-circ41150-OS02T0151800, Condition: cold
# Nearest neighbors: osa-circ27457-OS05T0554000, Condition: control
# Nearest neighbors: osa-circ44478-OS10T0539900, Condition: cold
# Nearest neighbors: osa-circ22188-OS10T0539900, Condition: control
# Nearest neighbors: osa-circ2734-OS07T0669100, Condition: control
# Seq of "cold" group: osa-circ43662-OS10T0466000
# Nearest neighbors: osa-circ58726-OS03T0565300, Condition: cold
# Nearest neighbors: osa-circ55256-OS02T0100300, Condition: control
# Nearest neighbors: osa-circ13704-OS07T0252400, Condition: control
# Nearest neighbors: osa-circ58597-OS02T0131050, Condition: cold
# Nearest neighbors: osa-circ2796-OS06T0114066, Condition: control
# Seq of "cold" group: osa-circ43663-OS10T0479600
# Nearest neighbors: osa-circ62675-OS07T0195100, Condition: cold
# Nearest neighbors: osa-circ53936-OS11T0189900, Condition: control
# Nearest neighbors: osa-circ45597--, Condition: control
# Nearest neighbors: osa-circ44635-OS07T0185800, Condition: cold
# Nearest neighbors: osa-circ43065-OS01T0835500, Condition: cold
# Seq of "cold" group: osa-circ43664-OS10T0479700
# Nearest neighbors: osa-circ59974-OS07T0479200, Condition: cold
# Nearest neighbors: osa-circ59152-OS08T0364900, Condition: cold
# Nearest neighbors: osa-circ58991-OS07T0667300, Condition: cold
# Nearest neighbors: osa-circ50153-OS01T0200700, Condition: cold
# Nearest neighbors: osa-circ60282-OS01T0200700, Condition: cold
# Seq of "cold" group: osa-circ43665-OS10T0489000
# Nearest neighbors: osa-circ32789-OS05T0551000, Condition: control
# Nearest neighbors: osa-circ50-OS06T0606800, Condition: control
# Nearest neighbors: osa-circ45546--, Condition: control
# Nearest neighbors: osa-circ8245-OS01T0862300, Condition: control
# Nearest neighbors: osa-circ12321-OS06T0308000, Condition: cold
# Seq of "cold" group: osa-circ43666-OS10T0503200
# Nearest neighbors: osa-circ58923-OS01T0756400, Condition: cold
# Nearest neighbors: osa-circ40965-OS03T0109900, Condition: control
# Nearest neighbors: osa-circ40482-OS11T0636900, Condition: cold
# Nearest neighbors: osa-circ53256-OS05T0144100, Condition: control
# Nearest neighbors: osa-circ62730-OS02T0131050, Condition: cold
# Seq of "cold" group: osa-circ43667-OS12T0123700
# Nearest neighbors: osa-circ12307-OS01T0104400, Condition: control
# Nearest neighbors: osa-circ32503-OS02T0700100, Condition: control
# Nearest neighbors: osa-circ3234-OS04T0616700, Condition: control
# Nearest neighbors: osa-circ29991-OS09T0439200, Condition: control
# Nearest neighbors: osa-circ50158-OS12T0189400, Condition: control
# Seq of "cold" group: osa-circ43668-OS12T0145700
# Nearest neighbors: osa-circ4841-OS06T0152100, Condition: control
# Nearest neighbors: osa-circ40527-OS10T0167300, Condition: cold
# Nearest neighbors: osa-circ16739-OS07T0673500, Condition: control
# Nearest neighbors: osa-circ53553-OS06T0154200, Condition: control
# Nearest neighbors: osa-circ15771-OS05T0542600, Condition: control
# Seq of "cold" group: osa-circ43669-OS12T0190000
# Nearest neighbors: osa-circ43442-OS12T0190000, Condition: cold
# Nearest neighbors: osa-circ41554-OS04T0129500, Condition: cold
# Nearest neighbors: osa-circ43515-OS03T0815200, Condition: cold
# Nearest neighbors: osa-circ59209-OS06T0655100, Condition: cold
# Nearest neighbors: osa-circ58929-OS01T0965400, Condition: cold
# Seq of "cold" group: osa-circ43670-OS12T0237000
# Nearest neighbors: osa-circ58863-OS05T0474800, Condition: cold
# Nearest neighbors: osa-circ44510-OS01T0771350, Condition: cold
# Nearest neighbors: osa-circ14971-OS02T0787966, Condition: control
# Nearest neighbors: osa-circ41629-OS12T0225150, Condition: cold
# Nearest neighbors: osa-circ23600-OS01T0771350, Condition: control
# Seq of "cold" group: osa-circ43671-OS12T0560600
# Nearest neighbors: osa-circ48564--, Condition: control
# Nearest neighbors: osa-circ40557-OS08T0525600, Condition: cold
# Nearest neighbors: osa-circ40427-OS01T0265400, Condition: cold
# Nearest neighbors: osa-circ40339-OS05T0575300, Condition: cold
# Nearest neighbors: osa-circ12500-OS02T0255100, Condition: cold
# Seq of "cold" group: osa-circ43672-OS12T0620400
# Nearest neighbors: osa-circ44671-OS09T0346400, Condition: cold
# Nearest neighbors: osa-circ43929-OS03T0214200, Condition: cold
# Nearest neighbors: osa-circ15959-OS03T0680800, Condition: control
# Nearest neighbors: osa-circ3446-OS01T0575000, Condition: control
# Nearest neighbors: osa-circ43167-OS05T0595300, Condition: cold
# Seq of "cold" group: osa-circ43673-OS12T0623500
# Nearest neighbors: osa-circ41816-OS01T0663800, Condition: cold
# Nearest neighbors: osa-circ32679-OS05T0230700, Condition: control
# Nearest neighbors: osa-circ57943-OS08T0156700, Condition: cold
# Nearest neighbors: osa-circ41299-OS01T0796400, Condition: cold
# Nearest neighbors: osa-circ19792-OS06T0702600, Condition: control
# Seq of "cold" group: osa-circ43674-OS12T0623900
# Nearest neighbors: osa-circ43545-OS02T0761100, Condition: cold
# Nearest neighbors: osa-circ43197-OS07T0150700, Condition: cold
# Nearest neighbors: osa-circ43831-OS06T0729000, Condition: cold
# Nearest neighbors: osa-circ49488--, Condition: control
# Nearest neighbors: osa-circ2996-OS04T0614600, Condition: control
# Seq of "cold" group: osa-circ43675-OS12T0625000
# Nearest neighbors: osa-circ59947-OS05T0287800, Condition: cold
# Nearest neighbors: osa-circ52215-OS04T0619400, Condition: control
# Nearest neighbors: osa-circ60128-OS11T0234200, Condition: cold
# Nearest neighbors: osa-circ60253-OS08T0155100, Condition: cold
# Nearest neighbors: osa-circ51758-OS05T0148600, Condition: control
# Seq of "cold" group: osa-circ43676-OS01T0106700
# Nearest neighbors: osa-circ3291-OS03T0376100, Condition: control
# Nearest neighbors: osa-circ59257-OS03T0734900, Condition: control
# Nearest neighbors: osa-circ40340-OS04T0434800, Condition: cold
# Nearest neighbors: osa-circ58201-OS06T0710300, Condition: cold
# Nearest neighbors: osa-circ58794-OS06T0710300, Condition: cold
# Seq of "cold" group: osa-circ43677-OS01T0183300
# Nearest neighbors: osa-circ8284-OS10T0376200, Condition: control
# Nearest neighbors: osa-circ44001-OS05T0586600, Condition: cold
# Nearest neighbors: osa-circ8474-OS03T0180900, Condition: control
# Nearest neighbors: osa-circ54167-OS01T0246700, Condition: control
# Nearest neighbors: osa-circ43850-OS08T0242800, Condition: cold
# Seq of "cold" group: osa-circ43678-OS01T0185400
# Nearest neighbors: osa-circ16030-OS08T0192900, Condition: control
# Nearest neighbors: osa-circ4518-OS01T0292200, Condition: control
# Nearest neighbors: osa-circ10267-OS10T0471350, Condition: control
# Nearest neighbors: osa-circ47894--, Condition: control
# Nearest neighbors: osa-circ14288-OS07T0406300, Condition: control
# Seq of "cold" group: osa-circ43679-OS01T0292900
# Nearest neighbors: osa-circ40515-OS03T0114800, Condition: cold
# Nearest neighbors: osa-circ50127-OS06T0729900, Condition: cold
# Nearest neighbors: osa-circ59987-OS06T0729900, Condition: cold
# Nearest neighbors: osa-circ42903-OS05T0496200, Condition: cold
# Nearest neighbors: osa-circ59204-OS06T0105800, Condition: cold
# Seq of "cold" group: osa-circ43680-OS01T0316600
# Nearest neighbors: osa-circ44074-OS08T0500200, Condition: cold
# Nearest neighbors: osa-circ50591-OS04T0463500, Condition: cold
# Nearest neighbors: osa-circ43286-OS01T0189700, Condition: cold
# Nearest neighbors: osa-circ18481-OS02T0702500, Condition: control
# Nearest neighbors: osa-circ59988-OS09T0434500, Condition: cold
# Seq of "cold" group: osa-circ43681-OS01T0356400
# Nearest neighbors: osa-circ18266-OS09T0491772, Condition: control
# Nearest neighbors: osa-circ52897-OS03T0202200, Condition: control
# Nearest neighbors: osa-circ46885--, Condition: control
# Nearest neighbors: osa-circ60794-OS12T0190200, Condition: control
# Nearest neighbors: osa-circ43333-OS02T0537700, Condition: cold
# Seq of "cold" group: osa-circ43682-OS01T0367400
# Nearest neighbors: osa-circ44081-OS10T0103700, Condition: control
# Nearest neighbors: osa-circ3437-OS08T0557100, Condition: control
# Nearest neighbors: osa-circ44007-OS04T0459800, Condition: cold
# Nearest neighbors: osa-circ14325-OS08T0564300, Condition: control
# Nearest neighbors: osa-circ28688-OS07T0511000, Condition: control
# Seq of "cold" group: osa-circ43683-OS01T0382700
# Nearest neighbors: osa-circ4838-OS06T0114000, Condition: control
# Nearest neighbors: osa-circ42811-OS01T0839700, Condition: cold
# Nearest neighbors: osa-circ41596-OS09T0250700, Condition: cold
# Nearest neighbors: osa-circ30304-OS08T0157600, Condition: control
# Nearest neighbors: osa-circ40472-OS05T0542200, Condition: cold
# Seq of "cold" group: osa-circ43684-OS01T0559600
# Nearest neighbors: osa-circ27596-OS04T0105000, Condition: control
# Nearest neighbors: osa-circ43196-OS07T0142000, Condition: cold
# Nearest neighbors: osa-circ7305-OS07T0176200, Condition: control
# Nearest neighbors: osa-circ25930-OS02T0302900, Condition: control
# Nearest neighbors: osa-circ9371-OS03T0851300, Condition: control
# Seq of "cold" group: osa-circ43685-OS01T0575000
# Nearest neighbors: osa-circ33513-OS09T0525600, Condition: control
# Nearest neighbors: osa-circ3874-OS04T0677500, Condition: control
# Nearest neighbors: osa-circ25183-OS03T0728900, Condition: control
# Nearest neighbors: osa-circ14931-OS01T0805700, Condition: control
# Nearest neighbors: osa-circ748-OS05T0346300, Condition: control
# Seq of "cold" group: osa-circ43686-OS01T0617900
# Nearest neighbors: osa-circ18876-OS09T0286400, Condition: control
# Nearest neighbors: osa-circ29898-OS09T0297400, Condition: control
# Nearest neighbors: osa-circ62722-OS03T0168400, Condition: cold
# Nearest neighbors: osa-circ55455-OS01T0271400, Condition: control
# Nearest neighbors: osa-circ60609-OS09T0457833, Condition: cold
# Seq of "cold" group: osa-circ43687-OS01T0645400
# Nearest neighbors: osa-circ36424-OS03T0638200, Condition: control
# Nearest neighbors: osa-circ46957--, Condition: control
# Nearest neighbors: osa-circ59630-OS02T0736600, Condition: cold
# Nearest neighbors: osa-circ41093-OS12T0538900, Condition: cold
# Nearest neighbors: osa-circ60105-OS06T0514700, Condition: cold
# Seq of "cold" group: osa-circ43688-OS01T0658900
# Nearest neighbors: osa-circ27628-OS04T0195000, Condition: control
# Nearest neighbors: osa-circ41691-OS02T0554300, Condition: cold
# Nearest neighbors: osa-circ47907--, Condition: control
# Nearest neighbors: osa-circ23722-OS01T0835000, Condition: control
# Nearest neighbors: osa-circ30883-OS08T0320300, Condition: control
# Seq of "cold" group: osa-circ43689-OS01T0659200
# Nearest neighbors: osa-circ4906-OS08T0430500, Condition: control
# Nearest neighbors: osa-circ25877-OS02T0252100, Condition: control
# Nearest neighbors: osa-circ1401-OS01T0191100, Condition: control
# Nearest neighbors: osa-circ21292-OS03T0106400, Condition: control
# Nearest neighbors: osa-circ42085-OS09T0401200, Condition: cold
# Seq of "cold" group: osa-circ43690-OS01T0716800
# Nearest neighbors: osa-circ28860-OS07T0617800, Condition: control
# Nearest neighbors: osa-circ19577-OS07T0205200, Condition: control
# Nearest neighbors: osa-circ15567-OS06T0623600, Condition: control
# Nearest neighbors: osa-circ44501-OS01T0532200, Condition: cold
# Nearest neighbors: osa-circ43064-OS01T0775100, Condition: cold
# Seq of "cold" group: osa-circ43691-OS01T0723400
# Nearest neighbors: osa-circ27846-OS04T0464200, Condition: control
# Nearest neighbors: osa-circ6997-OS02T0592400, Condition: control
# Nearest neighbors: osa-circ31972-OS01T0928800, Condition: control
# Nearest neighbors: osa-circ41471-OS12T0541400, Condition: cold
# Nearest neighbors: osa-circ14266-OS05T0305100, Condition: control
# Seq of "cold" group: osa-circ43692-OS01T0805700
# Nearest neighbors: osa-circ48524--, Condition: control
# Nearest neighbors: osa-circ43643-OS08T0480100, Condition: cold
# Nearest neighbors: osa-circ17847-OS03T0750100, Condition: control
# Nearest neighbors: osa-circ43654-OS11T0518900, Condition: cold
# Nearest neighbors: osa-circ43349-OS05T0290400, Condition: cold
# Seq of "cold" group: osa-circ43693-OS01T0807900
# Nearest neighbors: osa-circ2772-OS09T0521500, Condition: control
# Nearest neighbors: osa-circ30038-OS09T0474100, Condition: control
# Nearest neighbors: osa-circ18890-OS08T0384500, Condition: control
# Nearest neighbors: osa-circ41713-OS05T0497600, Condition: cold
# Nearest neighbors: osa-circ684-OS03T0320100, Condition: control
# Seq of "cold" group: osa-circ43694-OS01T0816400
# Nearest neighbors: osa-circ40323-OS01T0655800, Condition: cold
# Nearest neighbors: osa-circ59711-OS10T0579200, Condition: cold
# Nearest neighbors: osa-circ60599-OS07T0404900, Condition: cold
# Nearest neighbors: osa-circ40475-OS04T0543900, Condition: cold
# Nearest neighbors: osa-circ59257-OS03T0734900, Condition: control
# Seq of "cold" group: osa-circ43695-OS01T0830100
# Nearest neighbors: osa-circ57944-OS01T0749200, Condition: cold
# Nearest neighbors: osa-circ60195-OS02T0608300, Condition: cold
# Nearest neighbors: osa-circ58781-OS07T0409100, Condition: cold
# Nearest neighbors: osa-circ60139-OS12T0578400, Condition: cold
# Nearest neighbors: osa-circ60072-OS05T0108100, Condition: cold
# Seq of "cold" group: osa-circ43696-OS01T0839801
# Nearest neighbors: osa-circ1686-OS05T0574550, Condition: control
# Nearest neighbors: osa-circ675-OS05T0111300, Condition: control
# Nearest neighbors: osa-circ43179-OS04T0547900, Condition: cold
# Nearest neighbors: osa-circ55009-OS06T0297500, Condition: control
# Nearest neighbors: osa-circ43622-OS06T0729500, Condition: cold
# Seq of "cold" group: osa-circ43697-OS01T0876800
# Nearest neighbors: osa-circ31796-OS01T0618400, Condition: control
# Nearest neighbors: osa-circ25832-OS02T0219200, Condition: control
# Nearest neighbors: osa-circ42084-OS06T0705100, Condition: cold
# Nearest neighbors: osa-circ675-OS05T0111300, Condition: control
# Nearest neighbors: osa-circ40107-OS01T0558200, Condition: cold
# Seq of "cold" group: osa-circ43698-OS01T0889800
# Nearest neighbors: osa-circ26068-OS02T0549200, Condition: control
# Nearest neighbors: osa-circ13898-OS05T0111800, Condition: control
# Nearest neighbors: osa-circ374-OS02T0192500, Condition: control
# Nearest neighbors: osa-circ14363-OS03T0174300, Condition: control
# Nearest neighbors: osa-circ8279-OS08T0557600, Condition: control
# Seq of "cold" group: osa-circ43699-OS01T0896700
# Nearest neighbors: osa-circ59924-OS03T0402800, Condition: cold
# Nearest neighbors: osa-circ15954-OS03T0325500, Condition: control
# Nearest neighbors: osa-circ894-OS02T0601800, Condition: control
# Nearest neighbors: osa-circ49441--, Condition: control
# Nearest neighbors: osa-circ12128-OS04T0659100, Condition: cold
# Seq of "cold" group: osa-circ43700-OS01T0899500
# Nearest neighbors: osa-circ30038-OS09T0474100, Condition: control
# Nearest neighbors: osa-circ42902-OS05T0482600, Condition: cold
# Nearest neighbors: osa-circ2772-OS09T0521500, Condition: control
# Nearest neighbors: osa-circ28313-OS04T0685500, Condition: control
# Nearest neighbors: osa-circ17369-OS01T0960500, Condition: control
# Seq of "cold" group: osa-circ43701-OS01T0904200
# Nearest neighbors: osa-circ3924-OS12T0571900, Condition: control
# Nearest neighbors: osa-circ45268--, Condition: control
# Nearest neighbors: osa-circ32646-OS05T0143500, Condition: control
# Nearest neighbors: osa-circ44454-OS11T0186400, Condition: cold
# Nearest neighbors: osa-circ30439-OS08T0318500, Condition: control
# Seq of "cold" group: osa-circ43702-OS01T0948400
# Nearest neighbors: osa-circ60081-OS04T0379400, Condition: cold
# Nearest neighbors: osa-circ43972-OS02T0777100, Condition: cold
# Nearest neighbors: osa-circ40260-OS03T0333300, Condition: cold
# Nearest neighbors: osa-circ20099-OS04T0465000, Condition: control
# Nearest neighbors: osa-circ51257-OS11T0219000, Condition: control
# Seq of "cold" group: osa-circ43703-OS01T0948400
# Nearest neighbors: osa-circ803-OS04T0601700, Condition: control
# Nearest neighbors: osa-circ10539-OS03T0214100, Condition: control
# Nearest neighbors: osa-circ3148-OS12T0168700, Condition: control
# Nearest neighbors: osa-circ1257-OS03T0638800, Condition: control
# Nearest neighbors: osa-circ41336-OS03T0737000, Condition: cold
# Seq of "cold" group: osa-circ43704-OS01T0966700
# Nearest neighbors: osa-circ12280-OS03T0131300, Condition: cold
# Nearest neighbors: osa-circ42953-OS07T0672500, Condition: cold
# Nearest neighbors: osa-circ58618-OS05T0110900, Condition: cold
# Nearest neighbors: osa-circ60694-OS02T0824300, Condition: control
# Nearest neighbors: osa-circ32443-OS02T0557200, Condition: control
# Seq of "cold" group: osa-circ43705-OS01T0966700
# Nearest neighbors: osa-circ58910-OS12T0485500, Condition: cold
# Nearest neighbors: osa-circ59022-OS12T0208900, Condition: cold
# Nearest neighbors: osa-circ28051-OS04T0563801, Condition: control
# Nearest neighbors: osa-circ19820-OS11T0629200, Condition: control
# Nearest neighbors: osa-circ58560-OS01T0178500, Condition: cold
# Seq of "cold" group: osa-circ43706-OS01T0971200
# Nearest neighbors: osa-circ1827-OS03T0425200, Condition: control
# Nearest neighbors: osa-circ58209-OS01T0540800, Condition: cold
# Nearest neighbors: osa-circ50578-OS01T0540800, Condition: control
# Nearest neighbors: osa-circ27911-OS04T0488000, Condition: control
# Nearest neighbors: osa-circ24885-OS03T0441601, Condition: control
# Seq of "cold" group: osa-circ43707-OS01T0977250
# Nearest neighbors: osa-circ43068-OS01T0894600, Condition: cold
# Nearest neighbors: osa-circ50961-OS05T0136400, Condition: cold
# Nearest neighbors: osa-circ9710-OS04T0497350, Condition: control
# Nearest neighbors: osa-circ19423-OS08T0230200, Condition: control
# Nearest neighbors: osa-circ14002-OS03T0194900, Condition: control
# Seq of "cold" group: osa-circ43708-OS03T0109600
# Nearest neighbors: osa-circ52334-OS01T0747400, Condition: control
# Nearest neighbors: osa-circ57927-OS11T0175400, Condition: cold
# Nearest neighbors: osa-circ58783-OS07T0492000, Condition: cold
# Nearest neighbors: osa-circ41339-OS03T0776000, Condition: cold
# Nearest neighbors: osa-circ30911-OS06T0704600, Condition: control
# Seq of "cold" group: osa-circ43709-OS03T0159800
# Nearest neighbors: osa-circ50937-OS06T0194900, Condition: cold
# Nearest neighbors: osa-circ43945-OS03T0755000, Condition: cold
# Nearest neighbors: osa-circ7413-OS07T0657200, Condition: control
# Nearest neighbors: osa-circ55180-OS08T0471850, Condition: control
# Nearest neighbors: osa-circ44045-OS06T0265000, Condition: cold
# Seq of "cold" group: osa-circ43710-OS03T0179900
# Nearest neighbors: osa-circ47562--, Condition: control
# Nearest neighbors: osa-circ62443-OS03T0125100, Condition: cold
# Nearest neighbors: osa-circ41519-OS02T0179950, Condition: cold
# Nearest neighbors: osa-circ40631-OS03T0825700, Condition: control
# Nearest neighbors: osa-circ62632-OS05T0156401, Condition: cold
# Seq of "cold" group: osa-circ43711-OS03T0194500
# Nearest neighbors: osa-circ40286-OS01T0916800, Condition: cold
# Nearest neighbors: osa-circ10518-OS03T0146400, Condition: control
# Nearest neighbors: osa-circ1038-OS08T0557600, Condition: control
# Nearest neighbors: osa-circ43653-OS11T0482100, Condition: cold
# Nearest neighbors: osa-circ43127-OS02T0666300, Condition: cold
# Seq of "cold" group: osa-circ43712-OS03T0215700
# Nearest neighbors: osa-circ44488-OS12T0540900, Condition: cold
# Nearest neighbors: osa-circ11113-OS06T0701300, Condition: control
# Nearest neighbors: osa-circ43399-OS06T0682800, Condition: cold
# Nearest neighbors: osa-circ4634-OS03T0689300, Condition: control
# Nearest neighbors: osa-circ44605-OS05T0559900, Condition: cold
# Seq of "cold" group: osa-circ43713-OS03T0328900
# Nearest neighbors: osa-circ2957-OS04T0244800, Condition: control
# Nearest neighbors: osa-circ48271--, Condition: control
# Nearest neighbors: osa-circ8947-OS12T0132200, Condition: control
# Nearest neighbors: osa-circ43831-OS06T0729000, Condition: cold
# Nearest neighbors: osa-circ43099-OS03T0680800, Condition: cold
# Seq of "cold" group: osa-circ43714-OS03T0330300
# Nearest neighbors: osa-circ43688-OS01T0658900, Condition: cold
# Nearest neighbors: osa-circ26227-OS02T0617300, Condition: control
# Nearest neighbors: osa-circ30883-OS08T0320300, Condition: control
# Nearest neighbors: osa-circ27628-OS04T0195000, Condition: control
# Nearest neighbors: osa-circ33346-OS06T0625400, Condition: control
# Seq of "cold" group: osa-circ43715-OS03T0351100
# Nearest neighbors: osa-circ20112-OS07T0632600, Condition: control
# Nearest neighbors: osa-circ43951-OS02T0161200, Condition: cold
# Nearest neighbors: osa-circ40471-OS05T0162200, Condition: cold
# Nearest neighbors: osa-circ49487--, Condition: control
# Nearest neighbors: osa-circ6823-OS01T0711000, Condition: control
# Seq of "cold" group: osa-circ43716-OS03T0376100
# Nearest neighbors: osa-circ58060-OS06T0486800, Condition: cold
# Nearest neighbors: osa-circ37079-OS07T0172900, Condition: control
# Nearest neighbors: osa-circ43737-OS02T0198600, Condition: cold
# Nearest neighbors: osa-circ42542-OS01T0911300, Condition: control
# Nearest neighbors: osa-circ6712-OS05T0567100, Condition: control
# Seq of "cold" group: osa-circ43717-OS03T0626600
# Nearest neighbors: osa-circ40295-OS06T0699400, Condition: cold
# Nearest neighbors: osa-circ58707-OS01T0793701, Condition: cold
# Nearest neighbors: osa-circ41918-OS04T0558400, Condition: cold
# Nearest neighbors: osa-circ13799-OS07T0461600, Condition: control
# Nearest neighbors: osa-circ44467-OS10T0405600, Condition: cold
# Seq of "cold" group: osa-circ43718-OS03T0666500
# Nearest neighbors: osa-circ13621-OS11T0587600, Condition: control
# Nearest neighbors: osa-circ12385-OS08T0282400, Condition: cold
# Nearest neighbors: osa-circ3148-OS12T0168700, Condition: control
# Nearest neighbors: osa-circ803-OS04T0601700, Condition: control
# Nearest neighbors: osa-circ12369-OS02T0281000, Condition: cold
# Seq of "cold" group: osa-circ43719-OS03T0667100
# Nearest neighbors: osa-circ41332-OS03T0667100, Condition: cold
# Nearest neighbors: osa-circ40218-OS09T0558300, Condition: control
# Nearest neighbors: osa-circ7669-OS01T0550100, Condition: control
# Nearest neighbors: osa-circ44054-OS09T0128600, Condition: cold
# Nearest neighbors: osa-circ44896-OS04T0680000, Condition: control
# Seq of "cold" group: osa-circ43720-OS03T0680800
# Nearest neighbors: osa-circ40520-OS05T0555300, Condition: cold
# Nearest neighbors: osa-circ44633-OS07T0176200, Condition: cold
# Nearest neighbors: osa-circ12400-OS05T0551000, Condition: cold
# Nearest neighbors: osa-circ42830-OS03T0224700, Condition: cold
# Nearest neighbors: osa-circ30349-OS08T0192900, Condition: control
# Seq of "cold" group: osa-circ43721-OS03T0680800
# Nearest neighbors: osa-circ25507-OS03T0845000, Condition: control
# Nearest neighbors: osa-circ40279-OS08T0191433, Condition: cold
# Nearest neighbors: osa-circ62338-OS09T0413700, Condition: cold
# Nearest neighbors: osa-circ9672-OS04T0178300, Condition: control
# Nearest neighbors: osa-circ27930-OS04T0493100, Condition: control
# Seq of "cold" group: osa-circ43722-OS03T0680800
# Nearest neighbors: osa-circ32131-OS03T0307100, Condition: control
# Nearest neighbors: osa-circ43506-OS03T0640800, Condition: cold
# Nearest neighbors: osa-circ41116-OS01T0881300, Condition: cold
# Nearest neighbors: osa-circ41681-OS03T0799100, Condition: cold
# Nearest neighbors: osa-circ43539-OS02T0704900, Condition: cold
# Seq of "cold" group: osa-circ43723-OS03T0698900
# Nearest neighbors: osa-circ42057-OS05T0549000, Condition: cold
# Nearest neighbors: osa-circ59877-OS09T0409950, Condition: cold
# Nearest neighbors: osa-circ47075--, Condition: control
# Nearest neighbors: osa-circ55916-OS09T0509300, Condition: control
# Nearest neighbors: osa-circ30286-OS08T0151800, Condition: control
# Seq of "cold" group: osa-circ43724-OS03T0721200
# Nearest neighbors: osa-circ50611-OS03T0178100, Condition: cold
# Nearest neighbors: osa-circ60312-OS01T0954400, Condition: cold
# Nearest neighbors: osa-circ43523-OS02T0274100, Condition: cold
# Nearest neighbors: osa-circ50003-OS03T0685500, Condition: cold
# Nearest neighbors: osa-circ44899-OS07T0157700, Condition: control
# Seq of "cold" group: osa-circ43725-OS03T0735000
# Nearest neighbors: osa-circ18506-OS04T0614000, Condition: control
# Nearest neighbors: osa-circ7180-OS01T0635400, Condition: control
# Nearest neighbors: osa-circ62400-OS06T0196900, Condition: cold
# Nearest neighbors: osa-circ41723-OS04T0464200, Condition: cold
# Nearest neighbors: osa-circ54676-OS05T0280200, Condition: control
# Seq of "cold" group: osa-circ43726-OS03T0776000
# Nearest neighbors: osa-circ59852-OS07T0556200, Condition: cold
# Nearest neighbors: osa-circ50529-OS07T0556200, Condition: control
# Nearest neighbors: osa-circ43728-OS03T0821300, Condition: cold
# Nearest neighbors: osa-circ47430--, Condition: control
# Nearest neighbors: osa-circ33203-OS07T0673100, Condition: control
# Seq of "cold" group: osa-circ43727-OS03T0818100
# Nearest neighbors: osa-circ3749-OS07T0192900, Condition: control
# Nearest neighbors: osa-circ59116-OS04T0609600, Condition: cold
# Nearest neighbors: osa-circ41696-OS02T0625000, Condition: cold
# Nearest neighbors: osa-circ41365-OS02T0625000, Condition: cold
# Nearest neighbors: osa-circ59705-OS11T0582100, Condition: cold
# Seq of "cold" group: osa-circ43728-OS03T0821300
# Nearest neighbors: osa-circ43726-OS03T0776000, Condition: cold
# Nearest neighbors: osa-circ41576-OS07T0496200, Condition: cold
# Nearest neighbors: osa-circ44000-OS05T0573700, Condition: cold
# Nearest neighbors: osa-circ49327--, Condition: control
# Nearest neighbors: osa-circ23044-OS01T0305200, Condition: control
# Seq of "cold" group: osa-circ43729-OS03T0827700
# Nearest neighbors: osa-circ46914--, Condition: control
# Nearest neighbors: osa-circ31423-OS11T0603200, Condition: control
# Nearest neighbors: osa-circ21742-OS11T0521000, Condition: control
# Nearest neighbors: osa-circ43593-OS07T0565600, Condition: cold
# Nearest neighbors: osa-circ51526-OS07T0542800, Condition: control
# Seq of "cold" group: osa-circ43730-OS03T0839900
# Nearest neighbors: osa-circ22641-OS12T0624000, Condition: control
# Nearest neighbors: osa-circ46139--, Condition: control
# Nearest neighbors: osa-circ10694-OS02T0489525, Condition: control
# Nearest neighbors: osa-circ43602-OS07T0659400, Condition: cold
# Nearest neighbors: osa-circ37355-OS09T0323100, Condition: control
# Seq of "cold" group: osa-circ43731-OS03T0846400
# Nearest neighbors: osa-circ42683-OS07T0232200, Condition: control
# Nearest neighbors: osa-circ62231-OS02T0652550, Condition: cold
# Nearest neighbors: osa-circ27716-OS04T0393300, Condition: control
# Nearest neighbors: osa-circ10924-OS04T0599900, Condition: control
# Nearest neighbors: osa-circ33212-OS07T0693500, Condition: control
# Seq of "cold" group: osa-circ43732-OS02T0125300
# Nearest neighbors: osa-circ41149-OS02T0125300, Condition: cold
# Nearest neighbors: osa-circ15566-OS06T0499900, Condition: control
# Nearest neighbors: osa-circ58924-OS01T0784900, Condition: cold
# Nearest neighbors: osa-circ60298-OS01T0692700, Condition: cold
# Nearest neighbors: osa-circ55734-OS05T0548900, Condition: control
# Seq of "cold" group: osa-circ43733-OS02T0127700
# Nearest neighbors: osa-circ47849--, Condition: control
# Nearest neighbors: osa-circ7039-OS03T0285700, Condition: control
# Nearest neighbors: osa-circ23725-OS01T0835500, Condition: control
# Nearest neighbors: osa-circ25699-OS02T0168400, Condition: control
# Nearest neighbors: osa-circ29794-OS06T0717900, Condition: control
# Seq of "cold" group: osa-circ43734-OS02T0150700
# Nearest neighbors: osa-circ24919-OS03T0586800, Condition: control
# Nearest neighbors: osa-circ43649-OS08T0562700, Condition: cold
# Nearest neighbors: osa-circ9288-OS03T0430400, Condition: control
# Nearest neighbors: osa-circ12081-OS03T0212700, Condition: cold
# Nearest neighbors: osa-circ22389-OS12T0238100, Condition: control
# Seq of "cold" group: osa-circ43735-OS02T0164300
# Nearest neighbors: osa-circ42929-OS04T0647800, Condition: cold
# Nearest neighbors: osa-circ14616-OS01T0155600, Condition: control
# Nearest neighbors: osa-circ22715-OS01T0121100, Condition: control
# Nearest neighbors: osa-circ4825-OS07T0618800, Condition: control
# Nearest neighbors: osa-circ43749-OS02T0641800, Condition: cold
# Seq of "cold" group: osa-circ43736-OS02T0194000
# Nearest neighbors: osa-circ42064-OS04T0584600, Condition: cold
# Nearest neighbors: osa-circ22371-OS12T0194800, Condition: control
# Nearest neighbors: osa-circ33642-OS08T0495866, Condition: control
# Nearest neighbors: osa-circ25142-OS03T0715332, Condition: control
# Nearest neighbors: osa-circ1394-OS03T0772800, Condition: control
# Seq of "cold" group: osa-circ43737-OS02T0198600
# Nearest neighbors: osa-circ60187-OS03T0820700, Condition: cold
# Nearest neighbors: osa-circ414-OS07T0113700, Condition: control
# Nearest neighbors: osa-circ41955-OS09T0363600, Condition: cold
# Nearest neighbors: osa-circ42039-OS02T0717400, Condition: cold
# Nearest neighbors: osa-circ3040-OS09T0115400, Condition: control
# Seq of "cold" group: osa-circ43738-OS02T0208600
# Nearest neighbors: osa-circ36016-OS12T0574900, Condition: control
# Nearest neighbors: osa-circ15954-OS03T0325500, Condition: control
# Nearest neighbors: osa-circ33387-OS06T0716700, Condition: control
# Nearest neighbors: osa-circ21767-OS11T0544700, Condition: control
# Nearest neighbors: osa-circ12128-OS04T0659100, Condition: cold
# Seq of "cold" group: osa-circ43739-OS02T0274900
# Nearest neighbors: osa-circ61345-OS02T0721600, Condition: control
# Nearest neighbors: osa-circ14768-OS01T0310100, Condition: control
# Nearest neighbors: osa-circ11623-OS06T0207700, Condition: control
# Nearest neighbors: osa-circ21137-OS12T0429200, Condition: control
# Nearest neighbors: osa-circ42273-OS09T0558000, Condition: control
# Seq of "cold" group: osa-circ43740-OS02T0285800
# Nearest neighbors: osa-circ58010-OS03T0337500, Condition: cold
# Nearest neighbors: osa-circ12492-OS08T0449500, Condition: cold
# Nearest neighbors: osa-circ43138-OS02T0795300, Condition: cold
# Nearest neighbors: osa-circ6806-OS04T0440100, Condition: control
# Nearest neighbors: osa-circ54821-OS04T0538850, Condition: control
# Seq of "cold" group: osa-circ43741-OS02T0324300
# Nearest neighbors: osa-circ43672-OS12T0620400, Condition: cold
# Nearest neighbors: osa-circ40351-OS10T0396300, Condition: cold
# Nearest neighbors: osa-circ58345-OS12T0480200, Condition: control
# Nearest neighbors: osa-circ25614-OS02T0120600, Condition: control
# Nearest neighbors: osa-circ12485-OS03T0308100, Condition: cold
# Seq of "cold" group: osa-circ43742-OS02T0326200
# Nearest neighbors: osa-circ29241-OS06T0194900, Condition: control
# Nearest neighbors: osa-circ643-OS07T0529800, Condition: control
# Nearest neighbors: osa-circ10674-OS02T0197125, Condition: control
# Nearest neighbors: osa-circ42882-OS02T0664000, Condition: cold
# Nearest neighbors: osa-circ25832-OS02T0219200, Condition: control
# Seq of "cold" group: osa-circ43743-OS02T0469200
# Nearest neighbors: osa-circ58203-OS10T0167600, Condition: cold
# Nearest neighbors: osa-circ7797-OS02T0137500, Condition: control
# Nearest neighbors: osa-circ60322-OS03T0295700, Condition: cold
# Nearest neighbors: osa-circ43215-OS07T0585100, Condition: cold
# Nearest neighbors: osa-circ58062-OS08T0524100, Condition: cold
# Seq of "cold" group: osa-circ43744-OS02T0554000
# Nearest neighbors: osa-circ6950-OS02T0777100, Condition: control
# Nearest neighbors: osa-circ40467-OS03T0712700, Condition: cold
# Nearest neighbors: osa-circ24515-OS03T0262400, Condition: control
# Nearest neighbors: osa-circ5385-OS03T0655700, Condition: control
# Nearest neighbors: osa-circ46322--, Condition: control
# Seq of "cold" group: osa-circ43745-OS02T0564400
# Nearest neighbors: osa-circ31505-OS10T0539900, Condition: control
# Nearest neighbors: osa-circ17188-OS10T0539900, Condition: control
# Nearest neighbors: osa-circ22188-OS10T0539900, Condition: control
# Nearest neighbors: osa-circ45832--, Condition: control
# Nearest neighbors: osa-circ44478-OS10T0539900, Condition: cold
# Seq of "cold" group: osa-circ43746-OS02T0591600
# Nearest neighbors: osa-circ41122-OS03T0198500, Condition: cold
# Nearest neighbors: osa-circ6479-OS02T0827300, Condition: control
# Nearest neighbors: osa-circ43688-OS01T0658900, Condition: cold
# Nearest neighbors: osa-circ37486-OS08T0342400, Condition: control
# Nearest neighbors: osa-circ26443-OS02T0719800, Condition: control
# Seq of "cold" group: osa-circ43747-OS02T0639700
# Nearest neighbors: osa-circ3852-OS08T0102100, Condition: control
# Nearest neighbors: osa-circ43567-OS05T0559400, Condition: cold
# Nearest neighbors: osa-circ26154-OS02T0600400, Condition: control
# Nearest neighbors: osa-circ43952-OS02T0175800, Condition: cold
# Nearest neighbors: osa-circ60375-OS07T0187300, Condition: cold
# Seq of "cold" group: osa-circ43748-OS02T0640800
# Nearest neighbors: osa-circ9674-OS04T0284100, Condition: control
# Nearest neighbors: osa-circ43827-OS06T0701300, Condition: cold
# Nearest neighbors: osa-circ12076-OS12T0264500, Condition: cold
# Nearest neighbors: osa-circ42831-OS03T0234600, Condition: cold
# Nearest neighbors: osa-circ15428-OS07T0475900, Condition: control
# Seq of "cold" group: osa-circ43749-OS02T0641800
# Nearest neighbors: osa-circ33284-OS06T0264300, Condition: control
# Nearest neighbors: osa-circ41966-OS08T0436600, Condition: cold
# Nearest neighbors: osa-circ22715-OS01T0121100, Condition: control
# Nearest neighbors: osa-circ5538-OS02T0608900, Condition: cold
# Nearest neighbors: osa-circ41955-OS09T0363600, Condition: cold
# Seq of "cold" group: osa-circ43750-OS02T0699400
# Nearest neighbors: osa-circ59716-OS12T0448900, Condition: cold
# Nearest neighbors: osa-circ55903-OS09T0340400, Condition: control
# Nearest neighbors: osa-circ49101--, Condition: control
# Nearest neighbors: osa-circ50134-OS01T0710700, Condition: control
# Nearest neighbors: osa-circ59588-OS01T0710700, Condition: cold
# Seq of "cold" group: osa-circ43751-OS02T0700600
# Nearest neighbors: osa-circ13566-OS05T0155700, Condition: control
# Nearest neighbors: osa-circ44533-OS03T0411500, Condition: cold
# Nearest neighbors: osa-circ8772-OS07T0223100, Condition: control
# Nearest neighbors: osa-circ41127-OS03T0254700, Condition: cold
# Nearest neighbors: osa-circ56831-OS03T0417900, Condition: control
# Seq of "cold" group: osa-circ43752-OS02T0728100
# Nearest neighbors: osa-circ14540-OS05T0408200, Condition: control
# Nearest neighbors: osa-circ48385--, Condition: control
# Nearest neighbors: osa-circ41385-OS05T0519900, Condition: cold
# Nearest neighbors: osa-circ25682-OS02T0161200, Condition: control
# Nearest neighbors: osa-circ21047-OS03T0747900, Condition: control
# Seq of "cold" group: osa-circ43753-OS02T0734600
# Nearest neighbors: osa-circ43606-OS07T0693700, Condition: cold
# Nearest neighbors: osa-circ20489-OS01T0177200, Condition: control
# Nearest neighbors: osa-circ40313-OS09T0281600, Condition: cold
# Nearest neighbors: osa-circ11178-OS08T0240800, Condition: control
# Nearest neighbors: osa-circ5961-OS05T0150300, Condition: control
# Seq of "cold" group: osa-circ43754-OS02T0742000
# Nearest neighbors: osa-circ41889-OS02T0742000, Condition: cold
# Nearest neighbors: osa-circ40281-OS12T0407500, Condition: cold
# Nearest neighbors: osa-circ51524-OS04T0620400, Condition: control
# ...
# Nearest neighbors: osa-circ53195-OS02T0631000, Condition: control
# Nearest neighbors: osa-circ60399-OS09T0438400, Condition: cold
# Nearest neighbors: osa-circ53984-OS10T0446200, Condition: control
# Nearest neighbors: osa-circ43584-OS04T0613500, Condition: cold
# Seq of "cold" group: osa-circ50656-OS09T0441400
# Nearest neighbors: osa-circ9931-OS06T0603800, Condition: control
# Nearest neighbors: osa-circ58010-OS03T0337500, Condition: cold
# Nearest neighbors: osa-circ29314-OS06T0247651, Condition: control
# Nearest neighbors: osa-circ28205-OS04T0643550, Condition: control
# Nearest neighbors: osa-circ58995-OS06T0665500, Condition: cold
# Seq of "cold" group: osa-circ50657-OS08T0519400
# Nearest neighbors: osa-circ7375-OS01T0865100, Condition: control
# Nearest neighbors: osa-circ58526-OS06T0155300, Condition: control
# Nearest neighbors: osa-circ40289-OS05T0521300, Condition: cold
# Nearest neighbors: osa-circ59887-OS08T0360100, Condition: cold
# Nearest neighbors: osa-circ50298-OS05T0564300, Condition: control
# Seq of "cold" group: osa-circ50658-OS01T0246500
# Nearest neighbors: osa-circ58692-OS01T0246500, Condition: cold
# Nearest neighbors: osa-circ58719-OS03T0321000, Condition: cold
# Nearest neighbors: osa-circ19007-OS04T0252200, Condition: control
# Nearest neighbors: osa-circ58566-OS01T0658400, Condition: cold
# Nearest neighbors: osa-circ8817-OS01T0886900, Condition: control
# Seq of "cold" group: osa-circ50659-OS01T0558600
# Nearest neighbors: osa-circ60290-OS01T0558600, Condition: cold
# Nearest neighbors: osa-circ56658-OS11T0707800, Condition: control
# Nearest neighbors: osa-circ59621-OS02T0465900, Condition: cold
# Nearest neighbors: osa-circ60608-OS09T0448900, Condition: cold
# Nearest neighbors: osa-circ53289-OS10T0440100, Condition: control
# Seq of "cold" group: osa-circ50660-OS01T0841700
# Nearest neighbors: osa-circ23600-OS01T0771350, Condition: control
# Nearest neighbors: osa-circ59711-OS10T0579200, Condition: cold
# Nearest neighbors: osa-circ59920-OS03T0310500, Condition: cold
# Nearest neighbors: osa-circ24179-OS03T0126825, Condition: control
# Nearest neighbors: osa-circ54759-OS05T0556201, Condition: control
# Seq of "cold" group: osa-circ50661-OS07T0544800
# Nearest neighbors: osa-circ58023-OS07T0544800, Condition: cold
# Nearest neighbors: osa-circ59882-OS08T0111200, Condition: cold
# Nearest neighbors: osa-circ58078-OS08T0111200, Condition: cold
# Nearest neighbors: osa-circ41905-OS05T0519500, Condition: cold
# Nearest neighbors: osa-circ58892-OS06T0696600, Condition: cold
# Seq of "cold" group: osa-circ50662-OS11T0216100
# Nearest neighbors: osa-circ59994-OS11T0216100, Condition: cold
# Nearest neighbors: osa-circ60206-OS05T0114000, Condition: cold
# Nearest neighbors: osa-circ55055-OS06T0707100, Condition: control
# Nearest neighbors: osa-circ59017-OS10T0518300, Condition: cold
# Nearest neighbors: osa-circ41485-OS01T0665200, Condition: cold
# Seq of "cold" group: osa-circ50663-OS01T0944200
# Nearest neighbors: osa-circ59914-OS01T0944200, Condition: cold
# Nearest neighbors: osa-circ58838-OS03T0116300, Condition: cold
# Nearest neighbors: osa-circ46266--, Condition: control
# Nearest neighbors: osa-circ59627-OS02T0673500, Condition: cold
# Nearest neighbors: osa-circ46698--, Condition: control
# Seq of "cold" group: osa-circ50664-OS02T0526400
# Nearest neighbors: osa-circ58121-OS02T0526400, Condition: cold
# Nearest neighbors: osa-circ59798-OS02T0663300, Condition: cold
# Nearest neighbors: osa-circ16433-OS03T0448500, Condition: control
# Nearest neighbors: osa-circ58089-OS05T0388600, Condition: cold
# Nearest neighbors: osa-circ59974-OS07T0479200, Condition: cold
# Seq of "cold" group: osa-circ50665-OS08T0144000
# Nearest neighbors: osa-circ50621-OS08T0144000, Condition: cold
# Nearest neighbors: osa-circ59991-OS08T0144000, Condition: cold
# Nearest neighbors: osa-circ13584-OS04T0674100, Condition: control
# Nearest neighbors: osa-circ40965-OS03T0109900, Condition: control
# Nearest neighbors: osa-circ41477-OS01T0239200, Condition: cold
# Seq of "cold" group: osa-circ50932-OS11T0518900
# Nearest neighbors: osa-circ52203-OS02T0567200, Condition: control
# Nearest neighbors: osa-circ57934-OS04T0583700, Condition: cold
# Nearest neighbors: osa-circ62213-OS01T0558600, Condition: cold
# Nearest neighbors: osa-circ40354-OS01T0761300, Condition: cold
# Nearest neighbors: osa-circ59624-OS02T0592400, Condition: cold
# Seq of "cold" group: osa-circ50933-OS03T0285700
# Nearest neighbors: osa-circ41345-OS02T0123500, Condition: cold
# Nearest neighbors: osa-circ62531-OS08T0482100, Condition: control
# Nearest neighbors: osa-circ23604-OS01T0772800, Condition: control
# Nearest neighbors: osa-circ54034-OS10T0536400, Condition: control
# Nearest neighbors: osa-circ11797-OS03T0253100, Condition: control
# Seq of "cold" group: osa-circ50935-OS06T0714000
# Nearest neighbors: osa-circ14996-OS07T0523150, Condition: control
# Nearest neighbors: osa-circ62220-OS09T0450300, Condition: cold
# Nearest neighbors: osa-circ41744-OS07T0531600, Condition: cold
# Nearest neighbors: osa-circ15959-OS03T0680800, Condition: control
# Nearest neighbors: osa-circ4800-OS07T0173200, Condition: control
# Seq of "cold" group: osa-circ50936-OS01T0911100
# Nearest neighbors: osa-circ1990-OS02T0176700, Condition: control
# Nearest neighbors: osa-circ41401-OS04T0682500, Condition: cold
# Nearest neighbors: osa-circ7197-OS04T0165700, Condition: control
# Nearest neighbors: osa-circ29001-OS07T0675000, Condition: control
# Nearest neighbors: osa-circ44682-OS08T0127700, Condition: cold
# Seq of "cold" group: osa-circ50937-OS06T0194900
# Nearest neighbors: osa-circ44045-OS06T0265000, Condition: cold
# Nearest neighbors: osa-circ43709-OS03T0159800, Condition: cold
# Nearest neighbors: osa-circ43945-OS03T0755000, Condition: cold
# Nearest neighbors: osa-circ7413-OS07T0657200, Condition: control
# Nearest neighbors: osa-circ41900-OS05T0160100, Condition: cold
# Seq of "cold" group: osa-circ50956-OS06T0687700
# Nearest neighbors: osa-circ41230-OS08T0156600, Condition: cold
# Nearest neighbors: osa-circ40527-OS10T0167300, Condition: cold
# Nearest neighbors: osa-circ19593-OS06T0265000, Condition: control
# Nearest neighbors: osa-circ43668-OS12T0145700, Condition: cold
# Nearest neighbors: osa-circ30772-OS08T0557900, Condition: control
# Seq of "cold" group: osa-circ50957-OS04T0459900
# Nearest neighbors: osa-circ58777-OS07T0142900, Condition: cold
# Nearest neighbors: osa-circ60108-OS09T0484900, Condition: cold
# Nearest neighbors: osa-circ58187-OS09T0484900, Condition: cold
# Nearest neighbors: osa-circ22586-OS12T0595000, Condition: control
# Nearest neighbors: osa-circ2390-OS04T0687100, Condition: control
# Seq of "cold" group: osa-circ50958-OS09T0346400
# Nearest neighbors: osa-circ62627-OS02T0595700, Condition: cold
# Nearest neighbors: osa-circ11767-OS01T0571200, Condition: control
# Nearest neighbors: osa-circ61686-OS06T0273800, Condition: control
# Nearest neighbors: osa-circ54223-OS01T0631200, Condition: control
# Nearest neighbors: osa-circ24974-OS03T0646400, Condition: control
# Seq of "cold" group: osa-circ50959-OS01T0252100
# Nearest neighbors: osa-circ55718-OS05T0437300, Condition: control
# Nearest neighbors: osa-circ42631-OS02T0696900, Condition: control
# Nearest neighbors: osa-circ44159-OS09T0116400, Condition: control
# Nearest neighbors: osa-circ40955-OS01T0895100, Condition: control
# Nearest neighbors: osa-circ5480-OS01T0667700, Condition: cold
# Seq of "cold" group: osa-circ50960-OS02T0133000
# Nearest neighbors: osa-circ22176-OS10T0529400, Condition: control
# Nearest neighbors: osa-circ7568-OS01T0280500, Condition: control
# Nearest neighbors: osa-circ9014-OS01T0214600, Condition: control
# Nearest neighbors: osa-circ41240-OS08T0508800, Condition: cold
# Nearest neighbors: osa-circ42770-OS10T0525000, Condition: cold
# Seq of "cold" group: osa-circ50961-OS05T0136400
# Nearest neighbors: osa-circ59559-OS11T0417400, Condition: cold
# Nearest neighbors: osa-circ50683-OS12T0189300, Condition: control
# Nearest neighbors: osa-circ52203-OS02T0567200, Condition: control
# Nearest neighbors: osa-circ54544-OS02T0534400, Condition: control
# Nearest neighbors: osa-circ61206-OS01T0623550, Condition: control
# Seq of "cold" group: osa-circ50962-OS04T0645100
# Nearest neighbors: osa-circ19189-OS04T0440000, Condition: control
# Nearest neighbors: osa-circ8505-OS11T0483600, Condition: control
# Nearest neighbors: osa-circ17327-OS10T0388500, Condition: control
# Nearest neighbors: osa-circ49109--, Condition: control
# Nearest neighbors: osa-circ26190-OS02T0605600, Condition: control
# Seq of "cold" group: osa-circ50963-OS08T0562100
# Nearest neighbors: osa-circ46408--, Condition: control
# Nearest neighbors: osa-circ23725-OS01T0835500, Condition: control
# Nearest neighbors: osa-circ23604-OS01T0772800, Condition: control
# Nearest neighbors: osa-circ2657-OS02T0717500, Condition: control
# Nearest neighbors: osa-circ3841-OS03T0432100, Condition: control
# Seq of "cold" group: osa-circ50964-OS11T0660000
# Nearest neighbors: osa-circ168-OS04T0399000, Condition: control
# Nearest neighbors: osa-circ62561-OS10T0100300, Condition: cold
# Nearest neighbors: osa-circ5531-OS05T0103200, Condition: cold
# Nearest neighbors: osa-circ44453-OS08T0564300, Condition: control
# Nearest neighbors: osa-circ43000-OS08T0564300, Condition: cold
# Seq of "cold" group: osa-circ50967-OS11T0168300
# Nearest neighbors: osa-circ41601-OS09T0413600, Condition: cold
# Nearest neighbors: osa-circ17460-OS06T0162600, Condition: control
# Nearest neighbors: osa-circ62829-OS03T0737900, Condition: cold
# Nearest neighbors: osa-circ40341-OS04T0450600, Condition: cold
# Nearest neighbors: osa-circ43970-OS02T0757900, Condition: cold
# Seq of "cold" group: osa-circ50968-OS12T0583900
# Nearest neighbors: osa-circ53591-OS03T0423850, Condition: control
# Nearest neighbors: osa-circ43621-OS06T0715500, Condition: cold
# Nearest neighbors: osa-circ8532-OS02T0664100, Condition: control
# Nearest neighbors: osa-circ40551-OS07T0633100, Condition: cold
# Nearest neighbors: osa-circ58371-OS03T0782500, Condition: control
# Seq of "cold" group: osa-circ50969-OS03T0203800
# Nearest neighbors: osa-circ62415-OS03T0203800, Condition: cold
# Nearest neighbors: osa-circ62725-OS03T0203800, Condition: cold
# Nearest neighbors: osa-circ54624-OS05T0108800, Condition: control
# Nearest neighbors: osa-circ60901-OS09T0558100, Condition: control
# Nearest neighbors: osa-circ58624-OS05T0429900, Condition: cold
# Seq of "cold" group: osa-circ50970-OS07T0658400
# Nearest neighbors: osa-circ35829-OS11T0129000, Condition: control
# Nearest neighbors: osa-circ41104-OS01T0331900, Condition: cold
# Nearest neighbors: osa-circ57928-OS10T0376200, Condition: cold
# Nearest neighbors: osa-circ49654--, Condition: control
# Nearest neighbors: osa-circ28535-OS07T0245100, Condition: control
# Seq of "cold" group: osa-circ50971-OS06T0126000
# Nearest neighbors: osa-circ61131-OS12T0448900, Condition: control
# Nearest neighbors: osa-circ59671-OS06T0347100, Condition: cold
# Nearest neighbors: osa-circ59452-OS12T0552500, Condition: control
# Nearest neighbors: osa-circ20518-OS03T0241900, Condition: control
# Nearest neighbors: osa-circ40160-OS07T0406300, Condition: cold
# Seq of "cold" group: osa-circ50972-OS09T0279000
# Nearest neighbors: osa-circ62399-OS07T0618000, Condition: cold
# Nearest neighbors: osa-circ24541-OS03T0268900, Condition: control
# Nearest neighbors: osa-circ54990-OS06T0247900, Condition: control
# Nearest neighbors: osa-circ51707-OS06T0233000, Condition: control
# Nearest neighbors: osa-circ41463-OS12T0123500, Condition: cold
# Seq of "cold" group: osa-circ50975-OS02T0729700
# Nearest neighbors: osa-circ62698-OS02T0729700, Condition: cold
# Nearest neighbors: osa-circ43878-OS12T0123100, Condition: cold
# Nearest neighbors: osa-circ62186-OS01T0679700, Condition: cold
# Nearest neighbors: osa-circ41516-OS02T0125100, Condition: cold
# Nearest neighbors: osa-circ30762-OS08T0557100, Condition: control
# Seq of "cold" group: osa-circ50976-OS05T0310500
# Nearest neighbors: osa-circ43713-OS03T0328900, Condition: cold
# Nearest neighbors: osa-circ63006--, Condition: control
# Nearest neighbors: osa-circ15280-OS10T0554100, Condition: control
# Nearest neighbors: osa-circ32885-OS04T0402200, Condition: control
# Nearest neighbors: osa-circ49061--, Condition: control
# Seq of "cold" group: osa-circ50977-OS06T0606800
# Nearest neighbors: osa-circ62309-OS11T0241900, Condition: cold
# Nearest neighbors: osa-circ61335-OS04T0402300, Condition: control
# Nearest neighbors: osa-circ9495-OS02T0682600, Condition: control
# Nearest neighbors: osa-circ23602-OS01T0772500, Condition: control
# Nearest neighbors: osa-circ13693-OS04T0432000, Condition: control
# Seq of "cold" group: osa-circ50990-OS03T0679700
# Nearest neighbors: osa-circ50995-OS03T0679700, Condition: cold
# Nearest neighbors: osa-circ14660-OS02T0120100, Condition: control
# Nearest neighbors: osa-circ59981-OS06T0140100, Condition: cold
# Nearest neighbors: osa-circ36126-OS01T0539400, Condition: control
# Nearest neighbors: osa-circ22228-OS10T0563200, Condition: control
# Seq of "cold" group: osa-circ50991-OS05T0241200
# Nearest neighbors: osa-circ3168-OS06T0611900, Condition: control
# Nearest neighbors: osa-circ36788-OS05T0241150, Condition: control
# Nearest neighbors: osa-circ32616-OS02T0831500, Condition: control
# Nearest neighbors: osa-circ24255-OS03T0154750, Condition: control
# Nearest neighbors: osa-circ45719--, Condition: control
# Seq of "cold" group: osa-circ50992-OS04T0185500
# Nearest neighbors: osa-circ26560-OS02T0770000, Condition: control
# Nearest neighbors: osa-circ26561-OS02T0770000, Condition: control
# Nearest neighbors: osa-circ60151-OS01T0610300, Condition: cold
# Nearest neighbors: osa-circ58155-OS07T0669700, Condition: cold
# Nearest neighbors: osa-circ44955-OS08T0116500, Condition: control
# Seq of "cold" group: osa-circ50993-OS01T0199400
# Nearest neighbors: osa-circ31657-OS01T0116900, Condition: control
# Nearest neighbors: osa-circ15532-OS05T0382600, Condition: control
# Nearest neighbors: osa-circ15232-OS04T0439100, Condition: control
# Nearest neighbors: osa-circ81-OS03T0406200, Condition: control
# Nearest neighbors: osa-circ42788-OS01T0252100, Condition: cold
# Seq of "cold" group: osa-circ50994-OS03T0261100
# Nearest neighbors: osa-circ62739-OS04T0401700, Condition: cold
# Nearest neighbors: osa-circ62177-OS09T0123200, Condition: control
# Nearest neighbors: osa-circ43676-OS01T0106700, Condition: cold
# Nearest neighbors: osa-circ62741-OS04T0578400, Condition: cold
# Nearest neighbors: osa-circ44584-OS02T0797425, Condition: cold
# Seq of "cold" group: osa-circ50995-OS03T0679700
# Nearest neighbors: osa-circ50990-OS03T0679700, Condition: cold
# Nearest neighbors: osa-circ14660-OS02T0120100, Condition: control
# Nearest neighbors: osa-circ60218-OS04T0394500, Condition: cold
# Nearest neighbors: osa-circ59981-OS06T0140100, Condition: cold
# Nearest neighbors: osa-circ40210-OS04T0388500, Condition: control
# Seq of "cold" group: osa-circ50997-OS05T0241200
# Nearest neighbors: osa-circ62188-OS02T0735200, Condition: control
# Nearest neighbors: osa-circ62673-OS04T0629000, Condition: cold
# Nearest neighbors: osa-circ52897-OS03T0202200, Condition: control
# Nearest neighbors: osa-circ18266-OS09T0491772, Condition: control
# Nearest neighbors: osa-circ55916-OS09T0509300, Condition: control
# Seq of "cold" group: osa-circ50998-OS06T0547900
# Nearest neighbors: osa-circ59695-OS11T0104400, Condition: cold
# Nearest neighbors: osa-circ39693-OS01T0661500, Condition: control
# Nearest neighbors: osa-circ43135-OS02T0771600, Condition: cold
# Nearest neighbors: osa-circ45099--, Condition: control
# Nearest neighbors: osa-circ59857-OS07T0622200, Condition: cold
# Seq of "cold" group: osa-circ50999-OS03T0319400
# Nearest neighbors: osa-circ31154-OS07T0490200, Condition: control
# Nearest neighbors: osa-circ9253-OS03T0321800, Condition: control
# Nearest neighbors: osa-circ49315--, Condition: control
# Nearest neighbors: osa-circ43415-OS08T0562700, Condition: cold
# Nearest neighbors: osa-circ41613-OS08T0562700, Condition: cold
# Number of iterated cold stress sequences: 5724
# Total number of neighbors in the "cold" group: 7788
# Total number of neighbors in the "control" group": 3963
# Percentage of neighbors in the "cold" group: 46.10%
# Percentage of neighbors in the "control" group: 23.46%

# %% [markdown]
# ### Analysis of Results
#
# - Number of ref sequences from the "cold" group: 5724
#
# - Total neighbors from the "cold" group: 7788
#
# This number indicates that when searching for the nearest neighbors for the 5724 sequences from the "cold" group, a total of 7788 instances of neighbors that also belong to the "cold" group were found. This means that, on average, each sequence from the "cold" group has similar neighbors within the same group.
#
# - Total neighbors from the "control" group: 3963
#
# This value shows that, among the neighbors of the sequences from the "cold" group, 3963 of them belong to the "control" group. This is less than 5724, indicating that not all sequences from the "cold" group are getting close to those from the "control" group.
#
# - Percentage of neighbors in the "control" group: 23.46%
#
# - Percentage of neighbors in the "cold" group: 46.10%
#
# The high percentage indicates that the sequences in the "cold" group are closer to each other than to those in the "control" group.
#
#  The fact that the total number of neighbors in the "control" group is smaller than the number of "cold" sequences suggests that the sequences in the "cold" group tend to be more similar to each other and have less relationship with the sequences in the "control" group.

# %% [markdown]
# # Drought stress dataset

# %%
df_drought = df.query('stress == "-" or stress == "drought"').replace('-', 'control')

# %%
df_vec = df_drought.drop(['tissue','chr','start','end','strand','start_anno'], axis=1)
df_vec
# Out:
#                      circName   stress  wc_3mer_1  wc_3mer_2  wc_3mer_3  \
# 0      osa-circ1-OS01T0723400  control  -3.738741   8.954664   0.703204
# 1      osa-circ2-OS03T0223400  control  31.042567  37.664923  95.821671
# 2      osa-circ3-OS11T0210300  control -31.307338  14.101101   6.012345
# 3      osa-circ4-OS02T0200900  control  15.773287  55.951050  71.105993
# 4      osa-circ5-OS05T0494800  control -44.379635 -33.514299   9.594330
# ...                       ...      ...        ...        ...        ...
# 63043         osa-circ63044--  control   1.187543  33.638602  46.761491
# 63044         osa-circ63045--  control -80.622757   6.318129  -2.366743
# 63045         osa-circ63046--  control -74.383266 -15.111880  -5.831784
# 63046         osa-circ63047--  control  15.836808  18.807946   3.763431
# 63047         osa-circ63048--  control  13.275132  14.006887 -16.164613
#
#        wc_3mer_4  wc_3mer_5  wc_3mer_6  wc_3mer_7   wc_3mer_8  ...  \
# 0      -7.427550   9.996643  -0.181532  18.598464  -34.975266  ...
# 1     -13.835744 -44.356329  15.314592  45.651881  -14.309955  ...
# 2     -38.559886  47.126226  -4.402491  -2.144210 -110.080545  ...
# 3      11.420289 -15.831468 -30.626971  37.164693  -23.572454  ...
# 4     -28.682953  23.765476  24.619851 -26.153289  -72.517970  ...
# ...          ...        ...        ...        ...         ...  ...
# 63043  33.606569 -28.457826 -18.402121  19.510404   26.983153  ...
# 63044  16.879751 -30.253832 -43.023873 -19.773850   -1.661586  ...
# 63045 -13.084491 -20.186291 -32.085257 -11.033929  -44.055941  ...
# 63046   5.834760 -12.692529  13.718565  11.533184  -19.348844  ...
# 63047  31.301259 -24.821918 -18.592994  36.497289   56.680641  ...
#
#        wc_3mer_55  wc_3mer_56  wc_3mer_57  wc_3mer_58  wc_3mer_59  wc_3mer_60  \
# 0      -25.198840    2.249939   -4.701558   -3.633969    5.212902   -6.579618
# 1      -27.264821   51.359450  -73.188428   -1.662928   56.565280   28.610637
# 2      -69.366830    1.113416  -42.689580   -6.150814   23.203639   -7.541412
# 3       42.391724   50.721551  -67.643923  -24.403869   41.171276   45.067768
# 4      -75.243917  -36.308267    7.583992  -27.560256  -24.934966  -15.739278
# ...           ...         ...         ...         ...         ...         ...
# 63043   39.581378    5.624058  -18.996478  -32.586105   -8.206610   38.324260
# 63044   22.650734  -26.579853  -16.502095 -137.357917  -76.090281  117.878950
# 63045  -16.439233   -7.612099  -29.730788  -98.997580  -40.800622   88.914954
# 63046   23.810030   14.158860  -25.809598   -1.792872   -4.828570    6.402574
# 63047   24.301647    7.611070   22.699691    0.278573  -20.886769   15.526908
#
#        wc_3mer_61  wc_3mer_62  wc_3mer_63  wc_3mer_64
# 0       11.032136   -8.533007   -8.327910   18.141064
# 1       80.878607   38.090248  -30.543510   28.859375
# 2      -11.218056  -40.615067   16.391329    1.324206
# 3        9.704687    9.653121    7.829608  -11.254961
# 4        9.237141  -16.380438  -18.462203    7.718794
# ...           ...         ...         ...         ...
# 63043    2.731934   28.181426    3.800943  -12.217631
# 63044 -128.438327   -9.823361    4.179330  -43.925242
# 63045  -93.826379  -28.685970  -15.167838  -35.795096
# 63046   10.700880    3.991035   -6.085688    4.940037
# 63047    4.474708   11.044193  -19.796999   34.250569
#
# [51011 rows x 66 columns]

# %%
df_vec['stress'].value_counts()
# Out:
# stress
# control    50187
# drought      824
# Name: count, dtype: int64

# %%
drought_sequences = df_vec[df_vec['stress'] == 'drought']
control_sequences = df_vec[df_vec['stress'] == 'control']

# creating sample
control_sample = control_sequences.sample(n=824, random_state=42)

combined_sequences = pd.concat([drought_sequences, control_sample])

t = AnnoyIndex(dimension, 'angular')
for i in range(len(combined_sequences)):
    t.add_item(i, combined_sequences.iloc[i, 2:2 + dimension].values)
t.build(10)

similarities = {}
n_vizinhos = 5  # number of neighbors

# Analyzing only 'cold' sequences
for estresse_index in drought_sequences.index:
    if estresse_index < len(df_vec):
        adjusted_index = combined_sequences.index.get_loc(estresse_index)

        #Search neighbors
        vizinhos = t.get_nns_by_item(adjusted_index, n_vizinhos + 1)
        valid_vizinhos = []

        for i in vizinhos:
            if combined_sequences.iloc[i]['circName'] != combined_sequences.iloc[adjusted_index]['circName']:
                valid_vizinhos.append(i)
            if len(valid_vizinhos) == n_vizinhos:
                break

        similarities[estresse_index] = valid_vizinhos

# Results
drought_count = 0
control_count = 0
control_neighbors = set()

with open('neighbors_results_drought.txt', 'w') as f:
  for estresse_index, vizinhos in similarities.items():
      drought_sequence = combined_sequences.iloc[combined_sequences.index.get_loc(estresse_index)]['circName']
      similar_sequences = [combined_sequences.iloc[i]['circName'] for i in vizinhos]
      similar_conditions = [combined_sequences.iloc[i]['stress'] for i in vizinhos]

      for i in vizinhos:
          if combined_sequences.iloc[i]['stress'] == 'control':
              control_neighbors.add(i)

      drought_count += similar_conditions.count('drought')

      print(f'Seq of "drought" group: {drought_sequence}')
      f.write(f'Seq of "drought" group: {drought_sequence}\n')

      for seq, cond in zip(similar_sequences, similar_conditions):
          print(f'Nearest neighbors: {seq}, Condition: {cond}')
          f.write(f'Nearest neighbors: {seq}, Condition: {cond}\n')

control_count = len(control_neighbors)

# Similarity analysis
total_vizinhos = len(similarities) * n_vizinhos
num_drought_sequences = len(drought_sequences)

print(f'Number of iterated drought stress sequences: {num_drought_sequences}')
print(f'Total number of neighbors in the "drought" group: {drought_count}')
print(f'Total number of neighbors in the "control" group": {control_count}')
print(f'Percentage of neighbors in the "drought" group: {drought_count / total_vizinhos * 100:.2f}%')
print(f'Percentage of neighbors in the "control" group: {control_count / total_vizinhos * 100:.2f}%')
# Out:
# Seq of "drought" group: osa-circ5574-OS05T0563400
# Nearest neighbors: osa-circ12645-OS02T0735200, Condition: drought
# Nearest neighbors: osa-circ12543-OS02T0507400, Condition: drought
# Nearest neighbors: osa-circ13459-OS05T0455600, Condition: drought
# Nearest neighbors: osa-circ53481-OS02T0704600, Condition: control
# Nearest neighbors: osa-circ42170-OS03T0278200, Condition: control
# Seq of "drought" group: osa-circ5588-OS01T0730500
# Nearest neighbors: osa-circ12729-OS01T0495900, Condition: drought
# Nearest neighbors: osa-circ29614-OS06T0660800, Condition: control
# Nearest neighbors: osa-circ27442-OS05T0551000, Condition: control
# Nearest neighbors: osa-circ2196-OS01T0924900, Condition: control
# Nearest neighbors: osa-circ36664-OS02T0623500, Condition: control
# Seq of "drought" group: osa-circ5598-OS03T0117100
# Nearest neighbors: osa-circ13495-OS09T0509200, Condition: drought
# Nearest neighbors: osa-circ13448-OS02T0169800, Condition: drought
# Nearest neighbors: osa-circ32196-OS03T0616700, Condition: control
# Nearest neighbors: osa-circ23255-OS01T0610100, Condition: control
# Nearest neighbors: osa-circ25022-OS03T0667800, Condition: control
# Seq of "drought" group: osa-circ5610-OS02T0285800
# Nearest neighbors: osa-circ12720-OS01T0108000, Condition: drought
# Nearest neighbors: osa-circ6121-OS04T0671500, Condition: control
# Nearest neighbors: osa-circ12849-OS08T0487800, Condition: drought
# Nearest neighbors: osa-circ12685-OS06T0218500, Condition: drought
# Nearest neighbors: osa-circ62170-OS05T0593150, Condition: control
# Seq of "drought" group: osa-circ5620-OS05T0335401
# Nearest neighbors: osa-circ28091-OS04T0592600, Condition: control
# Nearest neighbors: osa-circ42144-OS01T0706700, Condition: control
# Nearest neighbors: osa-circ52303-OS05T0585500, Condition: control
# Nearest neighbors: osa-circ48709--, Condition: control
# Nearest neighbors: osa-circ11061-OS06T0207783, Condition: control
# Seq of "drought" group: osa-circ5636-OS06T0348800
# Nearest neighbors: osa-circ1644-OS03T0343500, Condition: control
# Nearest neighbors: osa-circ53932-OS11T0175450, Condition: control
# Nearest neighbors: osa-circ13334-OS02T0203000, Condition: drought
# Nearest neighbors: osa-circ46708--, Condition: control
# Nearest neighbors: osa-circ62892--, Condition: control
# Seq of "drought" group: osa-circ5641-OS09T0506900
# Nearest neighbors: osa-circ12794-OS04T0563801, Condition: drought
# Nearest neighbors: osa-circ51082-OS03T0265100, Condition: drought
# Nearest neighbors: osa-circ42666-OS04T0502900, Condition: control
# Nearest neighbors: osa-circ23607-OS01T0773600, Condition: control
# Nearest neighbors: osa-circ51390-OS02T0468400, Condition: drought
# Seq of "drought" group: osa-circ5646-OS08T0139700
# Nearest neighbors: osa-circ675-OS05T0111300, Condition: control
# Nearest neighbors: osa-circ31796-OS01T0618400, Condition: control
# Nearest neighbors: osa-circ27849-OS04T0464500, Condition: control
# Nearest neighbors: osa-circ17604-OS06T0115800, Condition: control
# Nearest neighbors: osa-circ12612-OS03T0266700, Condition: drought
# Seq of "drought" group: osa-circ5659-OS01T0711400
# Nearest neighbors: osa-circ12741-OS01T0897000, Condition: drought
# Nearest neighbors: osa-circ25849-OS02T0232400, Condition: control
# Nearest neighbors: osa-circ46272--, Condition: control
# Nearest neighbors: osa-circ13442-OS03T0846400, Condition: drought
# Nearest neighbors: osa-circ1648-OS03T0401300, Condition: control
# Seq of "drought" group: osa-circ5664-OS03T0701800
# Nearest neighbors: osa-circ13484-OS06T0237502, Condition: drought
# Nearest neighbors: osa-circ12801-OS04T0668800, Condition: drought
# Nearest neighbors: osa-circ25838-OS02T0224400, Condition: control
# Nearest neighbors: osa-circ13087-OS02T0751600, Condition: control
# Nearest neighbors: osa-circ6550-OS09T0465600, Condition: control
# Seq of "drought" group: osa-circ5668-OS03T0858100
# Nearest neighbors: osa-circ12539-OS12T0209300, Condition: drought
# Nearest neighbors: osa-circ6070-OS06T0726800, Condition: control
# Nearest neighbors: osa-circ13350-OS05T0533900, Condition: drought
# Nearest neighbors: osa-circ1282-OS03T0742400, Condition: control
# Nearest neighbors: osa-circ12675-OS07T0406600, Condition: drought
# Seq of "drought" group: osa-circ5707-OS09T0530000
# Nearest neighbors: osa-circ24324-OS03T0187300, Condition: control
# Nearest neighbors: osa-circ12760-OS03T0858400, Condition: drought
# Nearest neighbors: osa-circ13663-OS03T0825300, Condition: control
# Nearest neighbors: osa-circ13350-OS05T0533900, Condition: drought
# Nearest neighbors: osa-circ42321-OS01T0658500, Condition: control
# Seq of "drought" group: osa-circ12539-OS12T0209300
# Nearest neighbors: osa-circ5668-OS03T0858100, Condition: drought
# Nearest neighbors: osa-circ315-OS07T0252400, Condition: control
# Nearest neighbors: osa-circ15889-OS07T0694500, Condition: control
# Nearest neighbors: osa-circ6070-OS06T0726800, Condition: control
# Nearest neighbors: osa-circ33513-OS09T0525600, Condition: control
# Seq of "drought" group: osa-circ12540-OS03T0181600
# Nearest neighbors: osa-circ12542-OS02T0165000, Condition: drought
# Nearest neighbors: osa-circ51047-OS06T0215400, Condition: drought
# Nearest neighbors: osa-circ51078-OS01T0948100, Condition: drought
# Nearest neighbors: osa-circ12555-OS03T0721200, Condition: drought
# Nearest neighbors: osa-circ12614-OS03T0268200, Condition: drought
# Seq of "drought" group: osa-circ12541-OS03T0805500
# Nearest neighbors: osa-circ2013-OS03T0274000, Condition: control
# Nearest neighbors: osa-circ4119-OS02T0819500, Condition: control
# Nearest neighbors: osa-circ12594-OS01T0673800, Condition: drought
# Nearest neighbors: osa-circ13442-OS03T0846400, Condition: drought
# Nearest neighbors: osa-circ25849-OS02T0232400, Condition: control
# Seq of "drought" group: osa-circ12542-OS02T0165000
# Nearest neighbors: osa-circ12555-OS03T0721200, Condition: drought
# Nearest neighbors: osa-circ12554-OS03T0721200, Condition: drought
# Nearest neighbors: osa-circ12540-OS03T0181600, Condition: drought
# Nearest neighbors: osa-circ51054-OS11T0632200, Condition: drought
# Nearest neighbors: osa-circ53256-OS05T0144100, Condition: control
# Seq of "drought" group: osa-circ12543-OS02T0507400
# Nearest neighbors: osa-circ31518-OS10T0573100, Condition: control
# Nearest neighbors: osa-circ5574-OS05T0563400, Condition: drought
# Nearest neighbors: osa-circ42170-OS03T0278200, Condition: control
# Nearest neighbors: osa-circ51127-OS08T0557400, Condition: drought
# Nearest neighbors: osa-circ13459-OS05T0455600, Condition: drought
# Seq of "drought" group: osa-circ12552-OS10T0456800
# Nearest neighbors: osa-circ51036-OS11T0194800, Condition: drought
# Nearest neighbors: osa-circ51402-OS04T0502800, Condition: drought
# Nearest neighbors: osa-circ45560--, Condition: control
# Nearest neighbors: osa-circ51043-OS05T0363200, Condition: drought
# Nearest neighbors: osa-circ13362-OS04T0616700, Condition: drought
# Seq of "drought" group: osa-circ12553-OS03T0388100
# Nearest neighbors: osa-circ27742-OS04T0405600, Condition: control
# Nearest neighbors: osa-circ51391-OS02T0499000, Condition: drought
# Nearest neighbors: osa-circ13370-OS07T0570300, Condition: drought
# Nearest neighbors: osa-circ13456-OS05T0341600, Condition: drought
# Nearest neighbors: osa-circ13379-OS09T0280300, Condition: drought
# Seq of "drought" group: osa-circ12554-OS03T0721200
# Nearest neighbors: osa-circ12555-OS03T0721200, Condition: drought
# Nearest neighbors: osa-circ12542-OS02T0165000, Condition: drought
# Nearest neighbors: osa-circ61592-OS05T0147500, Condition: control
# Nearest neighbors: osa-circ51119-OS06T0230100, Condition: drought
# Nearest neighbors: osa-circ57874-OS09T0452300, Condition: control
# Seq of "drought" group: osa-circ12555-OS03T0721200
# Nearest neighbors: osa-circ12554-OS03T0721200, Condition: drought
# Nearest neighbors: osa-circ12542-OS02T0165000, Condition: drought
# Nearest neighbors: osa-circ61592-OS05T0147500, Condition: control
# Nearest neighbors: osa-circ57874-OS09T0452300, Condition: control
# Nearest neighbors: osa-circ51119-OS06T0230100, Condition: drought
# Seq of "drought" group: osa-circ12556-OS03T0754900
# Nearest neighbors: osa-circ12623-OS03T0690600, Condition: drought
# Nearest neighbors: osa-circ51165-OS07T0585100, Condition: drought
# Nearest neighbors: osa-circ12771-OS02T0601800, Condition: drought
# Nearest neighbors: osa-circ57874-OS09T0452300, Condition: control
# Nearest neighbors: osa-circ13400-OS10T0476700, Condition: drought
# Seq of "drought" group: osa-circ12557-OS05T0558900
# Nearest neighbors: osa-circ51179-OS08T0558200, Condition: drought
# Nearest neighbors: osa-circ13369-OS07T0568100, Condition: drought
# Nearest neighbors: osa-circ13441-OS03T0786100, Condition: drought
# Nearest neighbors: osa-circ51140-OS01T0142200, Condition: drought
# Nearest neighbors: osa-circ13424-OS03T0254700, Condition: drought
# Seq of "drought" group: osa-circ12558-OS04T0652400
# Nearest neighbors: osa-circ12561-OS09T0426100, Condition: drought
# Nearest neighbors: osa-circ51386-OS03T0269900, Condition: drought
# Nearest neighbors: osa-circ1594-OS03T0407050, Condition: control
# Nearest neighbors: osa-circ51021-OS02T0197200, Condition: drought
# Nearest neighbors: osa-circ12593-OS01T0658500, Condition: drought
# Seq of "drought" group: osa-circ12559-OS07T0138100
# Nearest neighbors: osa-circ18797-OS05T0373700, Condition: control
# Nearest neighbors: osa-circ50927-OS03T0353400, Condition: control
# Nearest neighbors: osa-circ26860-OS05T0143400, Condition: control
# Nearest neighbors: osa-circ30286-OS08T0151800, Condition: control
# Nearest neighbors: osa-circ13378-OS06T0623300, Condition: drought
# Seq of "drought" group: osa-circ12560-OS07T0576000
# Nearest neighbors: osa-circ12704-OS11T0216900, Condition: drought
# Nearest neighbors: osa-circ51417-OS01T0115600, Condition: drought
# Nearest neighbors: osa-circ60771-OS06T0133900, Condition: drought
# Nearest neighbors: osa-circ51322-OS08T0451200, Condition: control
# Nearest neighbors: osa-circ51099-OS02T0611300, Condition: drought
# Seq of "drought" group: osa-circ12561-OS09T0426100
# Nearest neighbors: osa-circ12558-OS04T0652400, Condition: drought
# Nearest neighbors: osa-circ51386-OS03T0269900, Condition: drought
# Nearest neighbors: osa-circ51439-OS05T0202800, Condition: drought
# Nearest neighbors: osa-circ1594-OS03T0407050, Condition: control
# Nearest neighbors: osa-circ31774-OS01T0559150, Condition: control
# Seq of "drought" group: osa-circ12562-OS11T0106200
# Nearest neighbors: osa-circ62078-OS05T0584750, Condition: control
# Nearest neighbors: osa-circ50309-OS07T0694700, Condition: control
# Nearest neighbors: osa-circ51393-OS02T0817900, Condition: drought
# Nearest neighbors: osa-circ51400-OS04T0479500, Condition: drought
# Nearest neighbors: osa-circ13471-OS07T0102400, Condition: drought
# Seq of "drought" group: osa-circ12563-OS11T0153600
# Nearest neighbors: osa-circ6942-OS03T0646900, Condition: control
# Nearest neighbors: osa-circ12539-OS12T0209300, Condition: drought
# Nearest neighbors: osa-circ12725-OS01T0279200, Condition: drought
# Nearest neighbors: osa-circ5668-OS03T0858100, Condition: drought
# Nearest neighbors: osa-circ13486-OS06T0498400, Condition: drought
# Seq of "drought" group: osa-circ12564-OS11T0171300
# Nearest neighbors: osa-circ46532--, Condition: control
# Nearest neighbors: osa-circ7578-OS01T0978000, Condition: control
# Nearest neighbors: osa-circ13440-OS03T0773800, Condition: drought
# Nearest neighbors: osa-circ13327-OS03T0586500, Condition: drought
# Nearest neighbors: osa-circ51397-OS04T0338100, Condition: drought
# Seq of "drought" group: osa-circ12565-OS11T0182400
# Nearest neighbors: osa-circ24933-OS03T0598800, Condition: control
# Nearest neighbors: osa-circ20814-OS02T0634900, Condition: control
# Nearest neighbors: osa-circ47051--, Condition: control
# Nearest neighbors: osa-circ25799-OS02T0205300, Condition: control
# Nearest neighbors: osa-circ13392-OS11T0427500, Condition: drought
# Seq of "drought" group: osa-circ12566-OS11T0483600
# Nearest neighbors: osa-circ51088-OS03T0837850, Condition: drought
# Nearest neighbors: osa-circ51128-OS11T0242800, Condition: drought
# Nearest neighbors: osa-circ12676-OS07T0558200, Condition: drought
# Nearest neighbors: osa-circ23416-OS01T0681200, Condition: control
# Nearest neighbors: osa-circ13493-OS09T0474300, Condition: drought
# Seq of "drought" group: osa-circ12567-OS11T0580800
# Nearest neighbors: osa-circ12730-OS01T0510800, Condition: drought
# Nearest neighbors: osa-circ26318-OS02T0664300, Condition: control
# Nearest neighbors: osa-circ29796-OS06T0724100, Condition: control
# Nearest neighbors: osa-circ17477-OS09T0363600, Condition: control
# Nearest neighbors: osa-circ24477-OS03T0252800, Condition: control
# Seq of "drought" group: osa-circ12568-OS11T0592400
# Nearest neighbors: osa-circ13422-OS03T0201200, Condition: drought
# Nearest neighbors: osa-circ12656-OS05T0394900, Condition: drought
# Nearest neighbors: osa-circ44742-OS01T0337900, Condition: control
# Nearest neighbors: osa-circ315-OS07T0252400, Condition: control
# Nearest neighbors: osa-circ12639-OS02T0610700, Condition: drought
# Seq of "drought" group: osa-circ12569-OS11T0707000
# Nearest neighbors: osa-circ26380-OS02T0700100, Condition: control
# Nearest neighbors: osa-circ3166-OS07T0683900, Condition: control
# Nearest neighbors: osa-circ54024-OS10T0536400, Condition: control
# Nearest neighbors: osa-circ21898-OS10T0132300, Condition: control
# Nearest neighbors: osa-circ12307-OS01T0104400, Condition: control
# Seq of "drought" group: osa-circ12570-OS11T0708400
# Nearest neighbors: osa-circ51384-OS01T0911800, Condition: drought
# Nearest neighbors: osa-circ12786-OS05T0589000, Condition: drought
# Nearest neighbors: osa-circ55455-OS01T0271400, Condition: control
# Nearest neighbors: osa-circ13416-OS01T0818000, Condition: drought
# Nearest neighbors: osa-circ19037-OS06T0298200, Condition: control
# Seq of "drought" group: osa-circ12571-OS10T0159800
# Nearest neighbors: osa-circ13342-OS02T0818000, Condition: drought
# Nearest neighbors: osa-circ60764-OS01T0837900, Condition: drought
# Nearest neighbors: osa-circ52565-OS04T0691300, Condition: control
# Nearest neighbors: osa-circ23041-OS01T0303600, Condition: control
# Nearest neighbors: osa-circ12847-OS08T0457600, Condition: drought
# Seq of "drought" group: osa-circ12572-OS10T0509200
# Nearest neighbors: osa-circ51116-OS06T0115300, Condition: drought
# Nearest neighbors: osa-circ51405-OS04T0672800, Condition: drought
# Nearest neighbors: osa-circ36996-OS04T0555600, Condition: control
# Nearest neighbors: osa-circ13510-OS08T0562200, Condition: drought
# Nearest neighbors: osa-circ48673--, Condition: control
# Seq of "drought" group: osa-circ12573-OS10T0565600
# Nearest neighbors: osa-circ12707-OS11T0603200, Condition: drought
# Nearest neighbors: osa-circ16167-OS01T0164700, Condition: control
# Nearest neighbors: osa-circ54673-OS05T0258400, Condition: control
# Nearest neighbors: osa-circ51016-OS10T0181333, Condition: drought
# Nearest neighbors: osa-circ16745-OS06T0563250, Condition: control
# Seq of "drought" group: osa-circ12574-OS10T0573700
# Nearest neighbors: osa-circ36368-OS03T0266800, Condition: control
# Nearest neighbors: osa-circ39795-OS03T0851300, Condition: control
# Nearest neighbors: osa-circ48896--, Condition: control
# Nearest neighbors: osa-circ4276-OS06T0325500, Condition: control
# Nearest neighbors: osa-circ47612--, Condition: control
# Seq of "drought" group: osa-circ12575-OS10T0577900
# Nearest neighbors: osa-circ12756-OS03T0708400, Condition: drought
# Nearest neighbors: osa-circ12776-OS02T0805800, Condition: drought
# Nearest neighbors: osa-circ33692-OS08T0562800, Condition: control
# Nearest neighbors: osa-circ55455-OS01T0271400, Condition: control
# Nearest neighbors: osa-circ11805-OS03T0323500, Condition: control
# Seq of "drought" group: osa-circ12576-OS10T0578800
# Nearest neighbors: osa-circ12657-OS05T0399100, Condition: drought
# Nearest neighbors: osa-circ31792-OS01T0610500, Condition: control
# Nearest neighbors: osa-circ20099-OS04T0465000, Condition: control
# Nearest neighbors: osa-circ12830-OS06T0716000, Condition: drought
# Nearest neighbors: osa-circ12622-OS03T0689100, Condition: drought
# Seq of "drought" group: osa-circ12577-OS12T0144000
# Nearest neighbors: osa-circ51437-OS02T0817900, Condition: drought
# Nearest neighbors: osa-circ21895-OS10T0115600, Condition: control
# Nearest neighbors: osa-circ37379-OS09T0439100, Condition: control
# Nearest neighbors: osa-circ51080-OS01T0965900, Condition: drought
# Nearest neighbors: osa-circ20793-OS01T0835500, Condition: control
# Seq of "drought" group: osa-circ12578-OS12T0292900
# Nearest neighbors: osa-circ50396-OS09T0365000, Condition: control
# Nearest neighbors: osa-circ13442-OS03T0846400, Condition: drought
# Nearest neighbors: osa-circ13458-OS05T0417200, Condition: drought
# Nearest neighbors: osa-circ6886-OS01T0817700, Condition: control
# Nearest neighbors: osa-circ15533-OS05T0384800, Condition: control
# Seq of "drought" group: osa-circ12579-OS12T0292900
# Nearest neighbors: osa-circ13254-OS06T0214900, Condition: control
# Nearest neighbors: osa-circ31572-OS12T0230100, Condition: control
# Nearest neighbors: osa-circ10305-OS12T0168700, Condition: control
# Nearest neighbors: osa-circ27716-OS04T0393300, Condition: control
# Nearest neighbors: osa-circ13368-OS07T0418000, Condition: drought
# Seq of "drought" group: osa-circ12580-OS12T0416300
# Nearest neighbors: osa-circ12540-OS03T0181600, Condition: drought
# Nearest neighbors: osa-circ20347-OS01T0837900, Condition: control
# Nearest neighbors: osa-circ12614-OS03T0268200, Condition: drought
# Nearest neighbors: osa-circ48673--, Condition: control
# Nearest neighbors: osa-circ12603-OS01T0934300, Condition: drought
# Seq of "drought" group: osa-circ12581-OS01T0102300
# Nearest neighbors: osa-circ33147-OS07T0565600, Condition: control
# Nearest neighbors: osa-circ32725-OS05T0402300, Condition: control
# Nearest neighbors: osa-circ1394-OS03T0772800, Condition: control
# Nearest neighbors: osa-circ32948-OS04T0538800, Condition: control
# Nearest neighbors: osa-circ13508-OS08T0557100, Condition: drought
# Seq of "drought" group: osa-circ12582-OS01T0109700
# Nearest neighbors: osa-circ12695-OS08T0110800, Condition: drought
# Nearest neighbors: osa-circ13422-OS03T0201200, Condition: drought
# Nearest neighbors: osa-circ13455-OS02T0795300, Condition: drought
# Nearest neighbors: osa-circ44742-OS01T0337900, Condition: control
# Nearest neighbors: osa-circ13301-OS01T0321300, Condition: drought
# Seq of "drought" group: osa-circ12583-OS01T0143800
# Nearest neighbors: osa-circ51402-OS04T0502800, Condition: drought
# Nearest neighbors: osa-circ13303-OS01T0382700, Condition: drought
# Nearest neighbors: osa-circ13392-OS11T0427500, Condition: drought
# Nearest neighbors: osa-circ26667-OS02T0813500, Condition: control
# Nearest neighbors: osa-circ13490-OS06T0709100, Condition: drought
# Seq of "drought" group: osa-circ12584-OS01T0178000
# Nearest neighbors: osa-circ12769-OS02T0570400, Condition: drought
# Nearest neighbors: osa-circ1648-OS03T0401300, Condition: control
# Nearest neighbors: osa-circ48913--, Condition: control
# Nearest neighbors: osa-circ13458-OS05T0417200, Condition: drought
# Nearest neighbors: osa-circ22237-OS10T0567800, Condition: control
# Seq of "drought" group: osa-circ12585-OS01T0220400
# Nearest neighbors: osa-circ16468-OS05T0595400, Condition: control
# Nearest neighbors: osa-circ19804-OS09T0436500, Condition: control
# Nearest neighbors: osa-circ22373-OS12T0207300, Condition: control
# Nearest neighbors: osa-circ13509-OS08T0557100, Condition: drought
# Nearest neighbors: osa-circ13374-OS06T0196300, Condition: drought
# Seq of "drought" group: osa-circ12586-OS01T0237100
# Nearest neighbors: osa-circ13422-OS03T0201200, Condition: drought
# Nearest neighbors: osa-circ13447-OS02T0168900, Condition: drought
# Nearest neighbors: osa-circ5250-OS07T0275300, Condition: control
# Nearest neighbors: osa-circ49109--, Condition: control
# Nearest neighbors: osa-circ33004-OS04T0624600, Condition: control
# Seq of "drought" group: osa-circ12587-OS01T0271400
# Nearest neighbors: osa-circ25838-OS02T0224400, Condition: control
# Nearest neighbors: osa-circ12843-OS08T0344600, Condition: drought
# Nearest neighbors: osa-circ51142-OS01T0242300, Condition: drought
# Nearest neighbors: osa-circ26822-OS05T0134400, Condition: control
# Nearest neighbors: osa-circ26843-OS05T0134400, Condition: control
# Seq of "drought" group: osa-circ12588-OS01T0279700
# Nearest neighbors: osa-circ13458-OS05T0417200, Condition: drought
# Nearest neighbors: osa-circ15533-OS05T0384800, Condition: control
# Nearest neighbors: osa-circ5024-OS01T0187400, Condition: control
# Nearest neighbors: osa-circ33120-OS07T0459200, Condition: control
# Nearest neighbors: osa-circ13442-OS03T0846400, Condition: drought
# Seq of "drought" group: osa-circ12589-OS01T0499300
# Nearest neighbors: osa-circ27959-OS04T0507000, Condition: control
# Nearest neighbors: osa-circ47612--, Condition: control
# Nearest neighbors: osa-circ13371-OS07T0636400, Condition: drought
# Nearest neighbors: osa-circ20934-OS02T0491400, Condition: control
# Nearest neighbors: osa-circ16914-OS10T0400800, Condition: control
# Seq of "drought" group: osa-circ12590-OS01T0570500
# Nearest neighbors: osa-circ12638-OS02T0554300, Condition: drought
# Nearest neighbors: osa-circ51130-OS10T0170200, Condition: drought
# Nearest neighbors: osa-circ13745-OS01T0617500, Condition: control
# Nearest neighbors: osa-circ26701-OS02T0822300, Condition: control
# Nearest neighbors: osa-circ51090-OS02T0174300, Condition: drought
# Seq of "drought" group: osa-circ12591-OS01T0614700
# Nearest neighbors: osa-circ52427-OS12T0641100, Condition: control
# Nearest neighbors: osa-circ51050-OS08T0461000, Condition: drought
# Nearest neighbors: osa-circ51155-OS05T0301600, Condition: drought
# Nearest neighbors: osa-circ53121-OS09T0516200, Condition: control
# Nearest neighbors: osa-circ12772-OS02T0623500, Condition: drought
# Seq of "drought" group: osa-circ12592-OS01T0633100
# Nearest neighbors: osa-circ12776-OS02T0805800, Condition: drought
# Nearest neighbors: osa-circ23797-OS01T0866800, Condition: control
# Nearest neighbors: osa-circ30038-OS09T0474100, Condition: control
# Nearest neighbors: osa-circ19591-OS06T0186500, Condition: control
# Nearest neighbors: osa-circ13346-OS05T0170800, Condition: drought
# Seq of "drought" group: osa-circ12593-OS01T0658500
# Nearest neighbors: osa-circ51146-OS03T0100030, Condition: drought
# Nearest neighbors: osa-circ1594-OS03T0407050, Condition: control
# Nearest neighbors: osa-circ12781-OS05T0148700, Condition: drought
# Nearest neighbors: osa-circ51404-OS04T0588700, Condition: drought
# Nearest neighbors: osa-circ51162-OS07T0160400, Condition: drought
# Seq of "drought" group: osa-circ12594-OS01T0673800
# Nearest neighbors: osa-circ19792-OS06T0702600, Condition: control
# Nearest neighbors: osa-circ51055-OS10T0466700, Condition: drought
# Nearest neighbors: osa-circ8632-OS07T0622000, Condition: control
# Nearest neighbors: osa-circ12619-OS03T0390600, Condition: drought
# Nearest neighbors: osa-circ58461-OS01T0590900, Condition: control
# Seq of "drought" group: osa-circ12595-OS01T0701900
# Nearest neighbors: osa-circ51073-OS01T0771350, Condition: drought
# Nearest neighbors: osa-circ51070-OS01T0250900, Condition: drought
# Nearest neighbors: osa-circ2498-OS11T0520500, Condition: control
# Nearest neighbors: osa-circ51429-OS03T0344700, Condition: drought
# Nearest neighbors: osa-circ56745-OS01T0390600, Condition: control
# Seq of "drought" group: osa-circ12596-OS01T0757500
# Nearest neighbors: osa-circ44876-OS04T0443500, Condition: control
# Nearest neighbors: osa-circ13309-OS01T0719100, Condition: drought
# Nearest neighbors: osa-circ12634-OS02T0290300, Condition: drought
# Nearest neighbors: osa-circ51121-OS09T0544300, Condition: drought
# Nearest neighbors: osa-circ59304-OS09T0540900, Condition: control
# Seq of "drought" group: osa-circ12597-OS01T0764300
# Nearest neighbors: osa-circ44885-OS04T0558400, Condition: control
# Nearest neighbors: osa-circ18113-OS12T0479900, Condition: control
# Nearest neighbors: osa-circ12610-OS03T0213400, Condition: drought
# Nearest neighbors: osa-circ13317-OS03T0157400, Condition: drought
# Nearest neighbors: osa-circ13473-OS07T0161600, Condition: drought
# Seq of "drought" group: osa-circ12598-OS01T0817700
# Nearest neighbors: osa-circ13387-OS08T0512300, Condition: drought
# Nearest neighbors: osa-circ7180-OS01T0635400, Condition: control
# Nearest neighbors: osa-circ6278-OS01T0700000, Condition: control
# Nearest neighbors: osa-circ21292-OS03T0106400, Condition: control
# Nearest neighbors: osa-circ60823-OS06T0149900, Condition: drought
# Seq of "drought" group: osa-circ12599-OS01T0834200
# Nearest neighbors: osa-circ12725-OS01T0279200, Condition: drought
# Nearest neighbors: osa-circ13317-OS03T0157400, Condition: drought
# Nearest neighbors: osa-circ45546--, Condition: control
# Nearest neighbors: osa-circ18113-OS12T0479900, Condition: control
# Nearest neighbors: osa-circ6942-OS03T0646900, Condition: control
# Seq of "drought" group: osa-circ12600-OS01T0877600
# Nearest neighbors: osa-circ12622-OS03T0689100, Condition: drought
# Nearest neighbors: osa-circ59304-OS09T0540900, Condition: control
# Nearest neighbors: osa-circ12635-OS02T0453300, Condition: drought
# Nearest neighbors: osa-circ13309-OS01T0719100, Condition: drought
# Nearest neighbors: osa-circ28525-OS07T0227400, Condition: control
# Seq of "drought" group: osa-circ12601-OS01T0898900
# Nearest neighbors: osa-circ12718-OS01T0104800, Condition: drought
# Nearest neighbors: osa-circ13355-OS04T0488000, Condition: drought
# Nearest neighbors: osa-circ13315-OS01T0924300, Condition: drought
# Nearest neighbors: osa-circ13423-OS03T0230500, Condition: drought
# Nearest neighbors: osa-circ27551-OS05T0588800, Condition: control
# Seq of "drought" group: osa-circ12602-OS01T0927900
# Nearest neighbors: osa-circ17904-OS06T0163400, Condition: control
# Nearest neighbors: osa-circ47637--, Condition: control
# Nearest neighbors: osa-circ6970-OS10T0167300, Condition: control
# Nearest neighbors: osa-circ12815-OS07T0695100, Condition: drought
# Nearest neighbors: osa-circ13356-OS04T0490800, Condition: drought
# Seq of "drought" group: osa-circ12603-OS01T0934300
# Nearest neighbors: osa-circ48673--, Condition: control
# Nearest neighbors: osa-circ57874-OS09T0452300, Condition: control
# Nearest neighbors: osa-circ53256-OS05T0144100, Condition: control
# Nearest neighbors: osa-circ12771-OS02T0601800, Condition: drought
# Nearest neighbors: osa-circ20347-OS01T0837900, Condition: control
# Seq of "drought" group: osa-circ12604-OS01T0973400
# Nearest neighbors: osa-circ22389-OS12T0238100, Condition: control
# Nearest neighbors: osa-circ19593-OS06T0265000, Condition: control
# Nearest neighbors: osa-circ3943-OS05T0567100, Condition: control
# Nearest neighbors: osa-circ50396-OS09T0365000, Condition: control
# Nearest neighbors: osa-circ49394--, Condition: control
# Seq of "drought" group: osa-circ12605-OS03T0101700
# Nearest neighbors: osa-circ12776-OS02T0805800, Condition: drought
# Nearest neighbors: osa-circ16336-OS02T0786000, Condition: control
# Nearest neighbors: osa-circ45698--, Condition: control
# Nearest neighbors: osa-circ31154-OS07T0490200, Condition: control
# Nearest neighbors: osa-circ55455-OS01T0271400, Condition: control
# Seq of "drought" group: osa-circ12606-OS03T0107800
# Nearest neighbors: osa-circ27959-OS04T0507000, Condition: control
# Nearest neighbors: osa-circ52269-OS07T0584000, Condition: control
# Nearest neighbors: osa-circ18086-OS08T0314800, Condition: control
# Nearest neighbors: osa-circ13888-OS02T0515200, Condition: control
# Nearest neighbors: osa-circ13468-OS04T0645100, Condition: drought
# Seq of "drought" group: osa-circ12607-OS03T0152600
# Nearest neighbors: osa-circ23185-OS01T0571000, Condition: control
# Nearest neighbors: osa-circ12588-OS01T0279700, Condition: drought
# Nearest neighbors: osa-circ4363-OS05T0405000, Condition: control
# Nearest neighbors: osa-circ48913--, Condition: control
# Nearest neighbors: osa-circ13396-OS10T0431900, Condition: drought
# Seq of "drought" group: osa-circ12608-OS03T0167500
# Nearest neighbors: osa-circ13350-OS05T0533900, Condition: drought
# Nearest neighbors: osa-circ12539-OS12T0209300, Condition: drought
# Nearest neighbors: osa-circ25238-OS03T0746500, Condition: control
# Nearest neighbors: osa-circ315-OS07T0252400, Condition: control
# Nearest neighbors: osa-circ31572-OS12T0230100, Condition: control
# Seq of "drought" group: osa-circ12609-OS03T0209600
# Nearest neighbors: osa-circ51177-OS08T0400300, Condition: drought
# Nearest neighbors: osa-circ36424-OS03T0638200, Condition: control
# Nearest neighbors: osa-circ12761-OS02T0100700, Condition: drought
# Nearest neighbors: osa-circ51404-OS04T0588700, Condition: drought
# Nearest neighbors: osa-circ58479-OS03T0184000, Condition: control
# Seq of "drought" group: osa-circ12610-OS03T0213400
# Nearest neighbors: osa-circ21701-OS11T0433200, Condition: control
# Nearest neighbors: osa-circ12597-OS01T0764300, Condition: drought
# Nearest neighbors: osa-circ18113-OS12T0479900, Condition: control
# Nearest neighbors: osa-circ13368-OS07T0418000, Condition: drought
# Nearest neighbors: osa-circ50460-OS04T0142400, Condition: control
# Seq of "drought" group: osa-circ12611-OS03T0240500
# Nearest neighbors: osa-circ53562-OS08T0290000, Condition: control
# Nearest neighbors: osa-circ40654-OS02T0718900, Condition: control
# Nearest neighbors: osa-circ51057-OS10T0556200, Condition: drought
# Nearest neighbors: osa-circ51391-OS02T0499000, Condition: drought
# Nearest neighbors: osa-circ51143-OS01T0281000, Condition: drought
# Seq of "drought" group: osa-circ12612-OS03T0266700
# Nearest neighbors: osa-circ42646-OS05T0158500, Condition: control
# Nearest neighbors: osa-circ6582-OS02T0120800, Condition: control
# Nearest neighbors: osa-circ5646-OS08T0139700, Condition: drought
# Nearest neighbors: osa-circ12715-OS12T0263000, Condition: drought
# Nearest neighbors: osa-circ17406-OS05T0121600, Condition: control
# Seq of "drought" group: osa-circ12613-OS03T0266800
# Nearest neighbors: osa-circ8385-OS12T0210400, Condition: control
# Nearest neighbors: osa-circ12765-OS02T0197200, Condition: drought
# Nearest neighbors: osa-circ13335-OS02T0229400, Condition: drought
# Nearest neighbors: osa-circ12784-OS05T0419500, Condition: drought
# Nearest neighbors: osa-circ51082-OS03T0265100, Condition: drought
# Seq of "drought" group: osa-circ12614-OS03T0268200
# Nearest neighbors: osa-circ53411-OS04T0449900, Condition: control
# Nearest neighbors: osa-circ51138-OS12T0502200, Condition: drought
# Nearest neighbors: osa-circ48673--, Condition: control
# Nearest neighbors: osa-circ12798-OS04T0623300, Condition: drought
# Nearest neighbors: osa-circ51047-OS06T0215400, Condition: drought
# Seq of "drought" group: osa-circ12615-OS03T0283100
# Nearest neighbors: osa-circ23041-OS01T0303600, Condition: control
# Nearest neighbors: osa-circ13405-OS01T0237100, Condition: drought
# Nearest neighbors: osa-circ45403--, Condition: control
# Nearest neighbors: osa-circ21450-OS03T0297100, Condition: control
# Nearest neighbors: osa-circ12598-OS01T0817700, Condition: drought
# Seq of "drought" group: osa-circ12616-OS03T0286200
# Nearest neighbors: osa-circ16571-OS02T0741500, Condition: control
# Nearest neighbors: osa-circ23797-OS01T0866800, Condition: control
# Nearest neighbors: osa-circ7721-OS09T0306800, Condition: control
# Nearest neighbors: osa-circ30038-OS09T0474100, Condition: control
# Nearest neighbors: osa-circ12697-OS08T0163400, Condition: drought
# Seq of "drought" group: osa-circ12617-OS03T0311300
# Nearest neighbors: osa-circ19200-OS07T0209000, Condition: control
# Nearest neighbors: osa-circ12829-OS06T0659300, Condition: drought
# Nearest neighbors: osa-circ13451-OS02T0708600, Condition: drought
# Nearest neighbors: osa-circ9785-OS07T0188800, Condition: control
# Nearest neighbors: osa-circ13490-OS06T0709100, Condition: drought
# Seq of "drought" group: osa-circ12618-OS03T0376600
# Nearest neighbors: osa-circ13433-OS03T0599600, Condition: drought
# Nearest neighbors: osa-circ12742-OS01T0911100, Condition: drought
# Nearest neighbors: osa-circ2873-OS02T0503400, Condition: control
# Nearest neighbors: osa-circ30997-OS05T0468600, Condition: control
# Nearest neighbors: osa-circ12768-OS02T0523500, Condition: drought
# Seq of "drought" group: osa-circ12619-OS03T0390600
# Nearest neighbors: osa-circ13407-OS01T0316600, Condition: drought
# Nearest neighbors: osa-circ51048-OS08T0157100, Condition: drought
# Nearest neighbors: osa-circ19792-OS06T0702600, Condition: control
# Nearest neighbors: osa-circ58461-OS01T0590900, Condition: control
# Nearest neighbors: osa-circ51055-OS10T0466700, Condition: drought
# Seq of "drought" group: osa-circ12620-OS03T0626800
# Nearest neighbors: osa-circ12849-OS08T0487800, Condition: drought
# Nearest neighbors: osa-circ45546--, Condition: control
# Nearest neighbors: osa-circ13330-OS03T0616300, Condition: drought
# Nearest neighbors: osa-circ6247-OS04T0671500, Condition: control
# Nearest neighbors: osa-circ3116-OS08T0154600, Condition: control
# Seq of "drought" group: osa-circ12621-OS03T0641700
# Nearest neighbors: osa-circ13434-OS03T0641700, Condition: drought
# Nearest neighbors: osa-circ13328-OS03T0596900, Condition: drought
# Nearest neighbors: osa-circ45546--, Condition: control
# Nearest neighbors: osa-circ36985-OS04T0509300, Condition: control
# Nearest neighbors: osa-circ48159--, Condition: control
# Seq of "drought" group: osa-circ12622-OS03T0689100
# Nearest neighbors: osa-circ12635-OS02T0453300, Condition: drought
# Nearest neighbors: osa-circ12600-OS01T0877600, Condition: drought
# Nearest neighbors: osa-circ60623-OS11T0620000, Condition: control
# Nearest neighbors: osa-circ13309-OS01T0719100, Condition: drought
# Nearest neighbors: osa-circ53559-OS09T0479400, Condition: control
# Seq of "drought" group: osa-circ12623-OS03T0690600
# Nearest neighbors: osa-circ51165-OS07T0585100, Condition: drought
# Nearest neighbors: osa-circ57874-OS09T0452300, Condition: control
# Nearest neighbors: osa-circ12556-OS03T0754900, Condition: drought
# Nearest neighbors: osa-circ45407--, Condition: control
# Nearest neighbors: osa-circ13400-OS10T0476700, Condition: drought
# Seq of "drought" group: osa-circ12624-OS03T0721200
# Nearest neighbors: osa-circ7721-OS09T0306800, Condition: control
# Nearest neighbors: osa-circ44876-OS04T0443500, Condition: control
# Nearest neighbors: osa-circ12696-OS08T0137100, Condition: drought
# Nearest neighbors: osa-circ12784-OS05T0419500, Condition: drought
# Nearest neighbors: osa-circ14578-OS06T0682800, Condition: control
# Seq of "drought" group: osa-circ12625-OS03T0735000
# Nearest neighbors: osa-circ13505-OS08T0482100, Condition: drought
# Nearest neighbors: osa-circ15394-OS02T0632500, Condition: control
# Nearest neighbors: osa-circ12785-OS05T0507300, Condition: drought
# Nearest neighbors: osa-circ40837-OS04T0448600, Condition: control
# Nearest neighbors: osa-circ24412-OS03T0227000, Condition: control
# Seq of "drought" group: osa-circ12626-OS03T0738400
# Nearest neighbors: osa-circ51062-OS12T0621025, Condition: drought
# Nearest neighbors: osa-circ42144-OS01T0706700, Condition: control
# Nearest neighbors: osa-circ55256-OS02T0100300, Condition: control
# Nearest neighbors: osa-circ52813-OS01T0667600, Condition: control
# Nearest neighbors: osa-circ52332-OS01T0667600, Condition: control
# Seq of "drought" group: osa-circ12627-OS03T0755100
# Nearest neighbors: osa-circ27716-OS04T0393300, Condition: control
# Nearest neighbors: osa-circ12651-OS05T0110800, Condition: drought
# Nearest neighbors: osa-circ21701-OS11T0433200, Condition: control
# Nearest neighbors: osa-circ49131--, Condition: control
# Nearest neighbors: osa-circ30128-OS09T0526700, Condition: control
# Seq of "drought" group: osa-circ12628-OS03T0786100
# Nearest neighbors: osa-circ13417-OS01T0929200, Condition: drought
# Nearest neighbors: osa-circ8424-OS12T0638750, Condition: control
# Nearest neighbors: osa-circ37379-OS09T0439100, Condition: control
# Nearest neighbors: osa-circ48071--, Condition: control
# Nearest neighbors: osa-circ13394-OS10T0154000, Condition: drought
# Seq of "drought" group: osa-circ12629-OS03T0789466
# Nearest neighbors: osa-circ12760-OS03T0858400, Condition: drought
# Nearest neighbors: osa-circ17904-OS06T0163400, Condition: control
# Nearest neighbors: osa-circ44866-OS05T0575300, Condition: control
# Nearest neighbors: osa-circ12807-OS07T0161000, Condition: drought
# Nearest neighbors: osa-circ10914-OS04T0527400, Condition: control
# Seq of "drought" group: osa-circ12630-OS03T0851600
# Nearest neighbors: osa-circ48208--, Condition: control
# Nearest neighbors: osa-circ51432-OS02T0310200, Condition: drought
# Nearest neighbors: osa-circ12572-OS10T0509200, Condition: drought
# Nearest neighbors: osa-circ12818-OS06T0145800, Condition: drought
# Nearest neighbors: osa-circ51093-OS02T0478700, Condition: drought
# Seq of "drought" group: osa-circ12631-OS02T0117100
# Nearest neighbors: osa-circ5225-OS04T0441900, Condition: control
# Nearest neighbors: osa-circ12541-OS03T0805500, Condition: drought
# Nearest neighbors: osa-circ12764-OS02T0167100, Condition: drought
# Nearest neighbors: osa-circ10741-OS02T0725200, Condition: control
# Nearest neighbors: osa-circ13458-OS05T0417200, Condition: drought
# Seq of "drought" group: osa-circ12632-OS02T0148500
# Nearest neighbors: osa-circ21450-OS03T0297100, Condition: control
# Nearest neighbors: osa-circ45403--, Condition: control
# Nearest neighbors: osa-circ12615-OS03T0283100, Condition: drought
# Nearest neighbors: osa-circ48579--, Condition: control
# Nearest neighbors: osa-circ2327-OS07T0622250, Condition: control
# Seq of "drought" group: osa-circ12633-OS02T0170900
# Nearest neighbors: osa-circ60623-OS11T0620000, Condition: control
# Nearest neighbors: osa-circ59304-OS09T0540900, Condition: control
# Nearest neighbors: osa-circ12738-OS01T0765300, Condition: drought
# Nearest neighbors: osa-circ13379-OS09T0280300, Condition: drought
# Nearest neighbors: osa-circ12622-OS03T0689100, Condition: drought
# Seq of "drought" group: osa-circ12634-OS02T0290300
# Nearest neighbors: osa-circ44876-OS04T0443500, Condition: control
# Nearest neighbors: osa-circ12636-OS02T0554000, Condition: drought
# Nearest neighbors: osa-circ12738-OS01T0765300, Condition: drought
# Nearest neighbors: osa-circ59304-OS09T0540900, Condition: control
# Nearest neighbors: osa-circ12633-OS02T0170900, Condition: drought
# Seq of "drought" group: osa-circ12635-OS02T0453300
# Nearest neighbors: osa-circ12622-OS03T0689100, Condition: drought
# Nearest neighbors: osa-circ13436-OS03T0689100, Condition: drought
# Nearest neighbors: osa-circ28525-OS07T0227400, Condition: control
# Nearest neighbors: osa-circ60672-OS03T0696000, Condition: control
# Nearest neighbors: osa-circ12600-OS01T0877600, Condition: drought
# Seq of "drought" group: osa-circ12636-OS02T0554000
# Nearest neighbors: osa-circ12738-OS01T0765300, Condition: drought
# Nearest neighbors: osa-circ12634-OS02T0290300, Condition: drought
# Nearest neighbors: osa-circ29224-OS06T0183800, Condition: control
# Nearest neighbors: osa-circ13034-OS01T0231500, Condition: control
# Nearest neighbors: osa-circ29852-OS09T0133200, Condition: control
# Seq of "drought" group: osa-circ12637-OS02T0554100
# Nearest neighbors: osa-circ29359-OS06T0274200, Condition: control
# Nearest neighbors: osa-circ32799-OS05T0558900, Condition: control
# Nearest neighbors: osa-circ27877-OS04T0474900, Condition: control
# Nearest neighbors: osa-circ10530-OS03T0169000, Condition: control
# Nearest neighbors: osa-circ13424-OS03T0254700, Condition: drought
# Seq of "drought" group: osa-circ12638-OS02T0554300
# Nearest neighbors: osa-circ49372--, Condition: control
# Nearest neighbors: osa-circ12590-OS01T0570500, Condition: drought
# Nearest neighbors: osa-circ51130-OS10T0170200, Condition: drought
# Nearest neighbors: osa-circ19692-OS03T0130500, Condition: control
# Nearest neighbors: osa-circ12676-OS07T0558200, Condition: drought
# Seq of "drought" group: osa-circ12639-OS02T0610700
# Nearest neighbors: osa-circ12568-OS11T0592400, Condition: drought
# Nearest neighbors: osa-circ13422-OS03T0201200, Condition: drought
# Nearest neighbors: osa-circ21079-OS05T0363500, Condition: control
# Nearest neighbors: osa-circ12656-OS05T0394900, Condition: drought
# Nearest neighbors: osa-circ12662-OS04T0194800, Condition: drought
# Seq of "drought" group: osa-circ12640-OS02T0645100
# Nearest neighbors: osa-circ13368-OS07T0418000, Condition: drought
# Nearest neighbors: osa-circ13254-OS06T0214900, Condition: control
# Nearest neighbors: osa-circ12579-OS12T0292900, Condition: drought
# Nearest neighbors: osa-circ39795-OS03T0851300, Condition: control
# Nearest neighbors: osa-circ36368-OS03T0266800, Condition: control
# Seq of "drought" group: osa-circ12641-OS02T0649700
# Nearest neighbors: osa-circ51409-OS09T0314400, Condition: drought
# Nearest neighbors: osa-circ51105-OS04T0131900, Condition: drought
# Nearest neighbors: osa-circ51075-OS01T0818700, Condition: drought
# Nearest neighbors: osa-circ53256-OS05T0144100, Condition: control
# Nearest neighbors: osa-circ51092-OS02T0254700, Condition: drought
# Seq of "drought" group: osa-circ12642-OS02T0678200
# Nearest neighbors: osa-circ12547-OS05T0275600, Condition: control
# Nearest neighbors: osa-circ33278-OS06T0234200, Condition: control
# Nearest neighbors: osa-circ27252-OS05T0460800, Condition: control
# Nearest neighbors: osa-circ12671-OS07T0108300, Condition: drought
# Nearest neighbors: osa-circ11452-OS02T0297600, Condition: control
# Seq of "drought" group: osa-circ12643-OS02T0725200
# Nearest neighbors: osa-circ44967-OS08T0441400, Condition: control
# Nearest neighbors: osa-circ13378-OS06T0623300, Condition: drought
# Nearest neighbors: osa-circ6278-OS01T0700000, Condition: control
# Nearest neighbors: osa-circ7180-OS01T0635400, Condition: control
# Nearest neighbors: osa-circ12598-OS01T0817700, Condition: drought
# Seq of "drought" group: osa-circ12644-OS02T0729400
# Nearest neighbors: osa-circ13334-OS02T0203000, Condition: drought
# Nearest neighbors: osa-circ17460-OS06T0162600, Condition: control
# Nearest neighbors: osa-circ5636-OS06T0348800, Condition: drought
# Nearest neighbors: osa-circ1644-OS03T0343500, Condition: control
# Nearest neighbors: osa-circ50158-OS12T0189400, Condition: control
# Seq of "drought" group: osa-circ12645-OS02T0735200
# Nearest neighbors: osa-circ42170-OS03T0278200, Condition: control
# Nearest neighbors: osa-circ5574-OS05T0563400, Condition: drought
# Nearest neighbors: osa-circ12543-OS02T0507400, Condition: drought
# Nearest neighbors: osa-circ13459-OS05T0455600, Condition: drought
# Nearest neighbors: osa-circ53481-OS02T0704600, Condition: control
# Seq of "drought" group: osa-circ12646-OS02T0739000
# Nearest neighbors: osa-circ32713-OS05T0373400, Condition: control
# Nearest neighbors: osa-circ54795-OS04T0431800, Condition: control
# Nearest neighbors: osa-circ16688-OS02T0209100, Condition: control
# Nearest neighbors: osa-circ13410-OS01T0624000, Condition: drought
# Nearest neighbors: osa-circ12801-OS04T0668800, Condition: drought
# Seq of "drought" group: osa-circ12647-OS02T0744700
# Nearest neighbors: osa-circ13254-OS06T0214900, Condition: control
# Nearest neighbors: osa-circ13481-OS06T0114000, Condition: drought
# Nearest neighbors: osa-circ36368-OS03T0266800, Condition: control
# Nearest neighbors: osa-circ3028-OS05T0388500, Condition: control
# Nearest neighbors: osa-circ2196-OS01T0924900, Condition: control
# Seq of "drought" group: osa-circ12648-OS02T0761700
# Nearest neighbors: osa-circ49394--, Condition: control
# Nearest neighbors: osa-circ51387-OS03T0726400, Condition: drought
# Nearest neighbors: osa-circ3897-OS09T0453000, Condition: control
# Nearest neighbors: osa-circ21369-OS09T0526700, Condition: control
# Nearest neighbors: osa-circ13490-OS06T0709100, Condition: drought
# Seq of "drought" group: osa-circ12649-OS05T0105500
# Nearest neighbors: osa-circ36043-OS12T0624000, Condition: control
# Nearest neighbors: osa-circ9078-OS01T0618100, Condition: control
# Nearest neighbors: osa-circ13316-OS03T0117100, Condition: drought
# Nearest neighbors: osa-circ29241-OS06T0194900, Condition: control
# Nearest neighbors: osa-circ31505-OS10T0539900, Condition: control
# Seq of "drought" group: osa-circ12650-OS05T0110800
# Nearest neighbors: osa-circ51546-OS03T0296800, Condition: control
# Nearest neighbors: osa-circ4461-OS10T0182000, Condition: control
# Nearest neighbors: osa-circ28261-OS04T0667800, Condition: control
# Nearest neighbors: osa-circ51084-OS03T0296800, Condition: drought
# Nearest neighbors: osa-circ51450-OS07T0492000, Condition: drought
# Seq of "drought" group: osa-circ12651-OS05T0110800
# Nearest neighbors: osa-circ24324-OS03T0187300, Condition: control
# Nearest neighbors: osa-circ30128-OS09T0526700, Condition: control
# Nearest neighbors: osa-circ12724-OS01T0268300, Condition: drought
# Nearest neighbors: osa-circ27716-OS04T0393300, Condition: control
# Nearest neighbors: osa-circ1418-OS07T0191200, Condition: control
# Seq of "drought" group: osa-circ12652-OS05T0148700
# Nearest neighbors: osa-circ27877-OS04T0474900, Condition: control
# Nearest neighbors: osa-circ20934-OS02T0491400, Condition: control
# Nearest neighbors: osa-circ12616-OS03T0286200, Condition: drought
# Nearest neighbors: osa-circ13870-OS03T0430400, Condition: control
# Nearest neighbors: osa-circ12601-OS01T0898900, Condition: drought
# Seq of "drought" group: osa-circ12653-OS05T0295800
# Nearest neighbors: osa-circ51435-OS02T0639000, Condition: drought
# Nearest neighbors: osa-circ13290-OS11T0248200, Condition: drought
# Nearest neighbors: osa-circ54109-OS01T0138400, Condition: control
# Nearest neighbors: osa-circ13421-OS03T0197400, Condition: drought
# Nearest neighbors: osa-circ18520-OS07T0570300, Condition: control
# Seq of "drought" group: osa-circ12654-OS05T0349700
# Nearest neighbors: osa-circ30086-OS09T0509200, Condition: control
# Nearest neighbors: osa-circ13316-OS03T0117100, Condition: drought
# Nearest neighbors: osa-circ25849-OS02T0232400, Condition: control
# Nearest neighbors: osa-circ12684-OS06T0156900, Condition: drought
# Nearest neighbors: osa-circ26872-OS05T0145000, Condition: control
# Seq of "drought" group: osa-circ12655-OS05T0363100
# Nearest neighbors: osa-circ51398-OS04T0420801, Condition: drought
# Nearest neighbors: osa-circ30286-OS08T0151800, Condition: control
# Nearest neighbors: osa-circ6278-OS01T0700000, Condition: control
# Nearest neighbors: osa-circ23041-OS01T0303600, Condition: control
# Nearest neighbors: osa-circ12571-OS10T0159800, Condition: drought
# Seq of "drought" group: osa-circ12656-OS05T0394900
# Nearest neighbors: osa-circ13422-OS03T0201200, Condition: drought
# Nearest neighbors: osa-circ12568-OS11T0592400, Condition: drought
# Nearest neighbors: osa-circ12539-OS12T0209300, Condition: drought
# Nearest neighbors: osa-circ15889-OS07T0694500, Condition: control
# Nearest neighbors: osa-circ44742-OS01T0337900, Condition: control
# Seq of "drought" group: osa-circ12657-OS05T0399100
# Nearest neighbors: osa-circ12738-OS01T0765300, Condition: drought
# Nearest neighbors: osa-circ18520-OS07T0570300, Condition: control
# Nearest neighbors: osa-circ13309-OS01T0719100, Condition: drought
# Nearest neighbors: osa-circ29224-OS06T0183800, Condition: control
# Nearest neighbors: osa-circ12576-OS10T0578800, Condition: drought
# Seq of "drought" group: osa-circ12658-OS05T0466800
# Nearest neighbors: osa-circ6284-OS03T0110800, Condition: control
# Nearest neighbors: osa-circ60770-OS06T0102600, Condition: drought
# Nearest neighbors: osa-circ27834-OS04T0459700, Condition: control
# Nearest neighbors: osa-circ13320-OS03T0239200, Condition: drought
# Nearest neighbors: osa-circ46238--, Condition: control
# Seq of "drought" group: osa-circ12659-OS05T0496200
# Nearest neighbors: osa-circ13355-OS04T0488000, Condition: drought
# Nearest neighbors: osa-circ12718-OS01T0104800, Condition: drought
# Nearest neighbors: osa-circ51125-OS08T0532300, Condition: drought
# Nearest neighbors: osa-circ13824-OS10T0167300, Condition: control
# Nearest neighbors: osa-circ13315-OS01T0924300, Condition: drought
# Seq of "drought" group: osa-circ12660-OS05T0539400
# Nearest neighbors: osa-circ7721-OS09T0306800, Condition: control
# Nearest neighbors: osa-circ12696-OS08T0137100, Condition: drought
# Nearest neighbors: osa-circ12624-OS03T0721200, Condition: drought
# Nearest neighbors: osa-circ12784-OS05T0419500, Condition: drought
# Nearest neighbors: osa-circ24481-OS03T0254700, Condition: control
# Seq of "drought" group: osa-circ12661-OS05T0554400
# Nearest neighbors: osa-circ12801-OS04T0668800, Condition: drought
# Nearest neighbors: osa-circ13484-OS06T0237502, Condition: drought
# Nearest neighbors: osa-circ6550-OS09T0465600, Condition: control
# Nearest neighbors: osa-circ49372--, Condition: control
# Nearest neighbors: osa-circ51379-OS11T0242500, Condition: drought
# Seq of "drought" group: osa-circ12662-OS04T0194800
# ...
# Nearest neighbors: osa-circ51134-OS10T0539600, Condition: drought
# Nearest neighbors: osa-circ12994-OS06T0688100, Condition: control
# Nearest neighbors: osa-circ55830-OS07T0631900, Condition: control
# Nearest neighbors: osa-circ13341-OS02T0790500, Condition: drought
# Seq of "drought" group: osa-circ13473-OS07T0161600
# Nearest neighbors: osa-circ21939-OS10T0188100, Condition: control
# Nearest neighbors: osa-circ13380-OS09T0474300, Condition: drought
# Nearest neighbors: osa-circ20419-OS04T0620700, Condition: control
# Nearest neighbors: osa-circ44885-OS04T0558400, Condition: control
# Nearest neighbors: osa-circ2196-OS01T0924900, Condition: control
# Seq of "drought" group: osa-circ13474-OS07T0187300
# Nearest neighbors: osa-circ5895-OS08T0127700, Condition: control
# Nearest neighbors: osa-circ9457-OS02T0562600, Condition: control
# Nearest neighbors: osa-circ1448-OS08T0412200, Condition: control
# Nearest neighbors: osa-circ51434-OS02T0595700, Condition: drought
# Nearest neighbors: osa-circ49173--, Condition: control
# Seq of "drought" group: osa-circ13475-OS07T0203700
# Nearest neighbors: osa-circ30359-OS08T0205400, Condition: control
# Nearest neighbors: osa-circ12795-OS04T0605500, Condition: drought
# Nearest neighbors: osa-circ44876-OS04T0443500, Condition: control
# Nearest neighbors: osa-circ25647-OS02T0132300, Condition: control
# Nearest neighbors: osa-circ13438-OS03T0725100, Condition: drought
# Seq of "drought" group: osa-circ13476-OS07T0435300
# Nearest neighbors: osa-circ46238--, Condition: control
# Nearest neighbors: osa-circ17340-OS12T0249900, Condition: control
# Nearest neighbors: osa-circ27834-OS04T0459700, Condition: control
# Nearest neighbors: osa-circ51542-OS03T0133800, Condition: control
# Nearest neighbors: osa-circ26667-OS02T0813500, Condition: control
# Seq of "drought" group: osa-circ13477-OS07T0470800
# Nearest neighbors: osa-circ13344-OS05T0108000, Condition: drought
# Nearest neighbors: osa-circ25539-OS03T0854100, Condition: control
# Nearest neighbors: osa-circ12778-OS02T0822500, Condition: drought
# Nearest neighbors: osa-circ47612--, Condition: control
# Nearest neighbors: osa-circ16914-OS10T0400800, Condition: control
# Seq of "drought" group: osa-circ13478-OS07T0637300
# Nearest neighbors: osa-circ49698--, Condition: control
# Nearest neighbors: osa-circ12589-OS01T0499300, Condition: drought
# Nearest neighbors: osa-circ12815-OS07T0695100, Condition: drought
# Nearest neighbors: osa-circ13430-OS03T0389900, Condition: drought
# Nearest neighbors: osa-circ50460-OS04T0142400, Condition: control
# Seq of "drought" group: osa-circ13479-OS07T0658400
# Nearest neighbors: osa-circ12807-OS07T0161000, Condition: drought
# Nearest neighbors: osa-circ12762-OS02T0120400, Condition: drought
# Nearest neighbors: osa-circ12620-OS03T0626800, Condition: drought
# Nearest neighbors: osa-circ3116-OS08T0154600, Condition: control
# Nearest neighbors: osa-circ13330-OS03T0616300, Condition: drought
# Seq of "drought" group: osa-circ13480-OS06T0114000
# Nearest neighbors: osa-circ12743-OS01T0930000, Condition: drought
# Nearest neighbors: osa-circ13888-OS02T0515200, Condition: control
# Nearest neighbors: osa-circ11963-OS09T0521500, Condition: control
# Nearest neighbors: osa-circ16914-OS10T0400800, Condition: control
# Nearest neighbors: osa-circ12844-OS08T0359000, Condition: drought
# Seq of "drought" group: osa-circ13481-OS06T0114000
# Nearest neighbors: osa-circ48896--, Condition: control
# Nearest neighbors: osa-circ16667-OS03T0288600, Condition: control
# Nearest neighbors: osa-circ46918--, Condition: control
# Nearest neighbors: osa-circ22564-OS12T0578400, Condition: control
# Nearest neighbors: osa-circ12825-OS06T0342500, Condition: drought
# Seq of "drought" group: osa-circ13482-OS06T0116800
# Nearest neighbors: osa-circ14487-OS01T0778800, Condition: control
# Nearest neighbors: osa-circ12743-OS01T0930000, Condition: drought
# Nearest neighbors: osa-circ51130-OS10T0170200, Condition: drought
# Nearest neighbors: osa-circ36979-OS04T0492300, Condition: control
# Nearest neighbors: osa-circ30602-OS08T0480100, Condition: control
# Seq of "drought" group: osa-circ13483-OS06T0196300
# Nearest neighbors: osa-circ13373-OS06T0196300, Condition: drought
# Nearest neighbors: osa-circ12822-OS06T0196300, Condition: drought
# Nearest neighbors: osa-circ28090-OS04T0591100, Condition: control
# Nearest neighbors: osa-circ61373-OS03T0275300, Condition: control
# Nearest neighbors: osa-circ50669-OS03T0731900, Condition: drought
# Seq of "drought" group: osa-circ13484-OS06T0237502
# Nearest neighbors: osa-circ12801-OS04T0668800, Condition: drought
# Nearest neighbors: osa-circ12661-OS05T0554400, Condition: drought
# Nearest neighbors: osa-circ26822-OS05T0134400, Condition: control
# Nearest neighbors: osa-circ26843-OS05T0134400, Condition: control
# Nearest neighbors: osa-circ6550-OS09T0465600, Condition: control
# Seq of "drought" group: osa-circ13485-OS06T0267600
# Nearest neighbors: osa-circ13358-OS04T0533300, Condition: drought
# Nearest neighbors: osa-circ13466-OS04T0533300, Condition: drought
# Nearest neighbors: osa-circ26667-OS02T0813500, Condition: control
# Nearest neighbors: osa-circ12665-OS04T0533300, Condition: drought
# Nearest neighbors: osa-circ17692-OS03T0833900, Condition: control
# Seq of "drought" group: osa-circ13486-OS06T0498400
# Nearest neighbors: osa-circ13323-OS03T0288600, Condition: drought
# Nearest neighbors: osa-circ5737-OS03T0198300, Condition: control
# Nearest neighbors: osa-circ12563-OS11T0153600, Condition: drought
# Nearest neighbors: osa-circ6942-OS03T0646900, Condition: control
# Nearest neighbors: osa-circ12539-OS12T0209300, Condition: drought
# Seq of "drought" group: osa-circ13487-OS06T0568200
# Nearest neighbors: osa-circ51175-OS08T0326400, Condition: drought
# Nearest neighbors: osa-circ28513-OS07T0209000, Condition: control
# Nearest neighbors: osa-circ31518-OS10T0573100, Condition: control
# Nearest neighbors: osa-circ12677-OS07T0641700, Condition: drought
# Nearest neighbors: osa-circ51127-OS08T0557400, Condition: drought
# Seq of "drought" group: osa-circ13488-OS06T0608500
# Nearest neighbors: osa-circ36712-OS02T0786000, Condition: control
# Nearest neighbors: osa-circ12784-OS05T0419500, Condition: drought
# Nearest neighbors: osa-circ13423-OS03T0230500, Condition: drought
# Nearest neighbors: osa-circ30546-OS08T0430200, Condition: control
# Nearest neighbors: osa-circ9172-OS01T0962200, Condition: control
# Seq of "drought" group: osa-circ13489-OS06T0651600
# Nearest neighbors: osa-circ13438-OS03T0725100, Condition: drought
# Nearest neighbors: osa-circ51121-OS09T0544300, Condition: drought
# Nearest neighbors: osa-circ28687-OS07T0508500, Condition: control
# Nearest neighbors: osa-circ29501-OS06T0568200, Condition: control
# Nearest neighbors: osa-circ13475-OS07T0203700, Condition: drought
# Seq of "drought" group: osa-circ13490-OS06T0709100
# Nearest neighbors: osa-circ17692-OS03T0833900, Condition: control
# Nearest neighbors: osa-circ41064-OS08T0342400, Condition: control
# Nearest neighbors: osa-circ19200-OS07T0209000, Condition: control
# Nearest neighbors: osa-circ13451-OS02T0708600, Condition: drought
# Nearest neighbors: osa-circ44128-OS08T0536000, Condition: control
# Seq of "drought" group: osa-circ13491-OS06T0727200
# Nearest neighbors: osa-circ60824-OS06T0704600, Condition: drought
# Nearest neighbors: osa-circ25544-OS03T0854800, Condition: control
# Nearest neighbors: osa-circ13457-OS05T0349700, Condition: drought
# Nearest neighbors: osa-circ62160-OS11T0707600, Condition: control
# Nearest neighbors: osa-circ3710-OS12T0636800, Condition: control
# Seq of "drought" group: osa-circ13492-OS09T0392400
# Nearest neighbors: osa-circ54471-OS03T0756000, Condition: control
# Nearest neighbors: osa-circ27959-OS04T0507000, Condition: control
# Nearest neighbors: osa-circ18683-OS08T0422000, Condition: control
# Nearest neighbors: osa-circ51118-OS06T0150400, Condition: drought
# Nearest neighbors: osa-circ51149-OS03T0344700, Condition: drought
# Seq of "drought" group: osa-circ13493-OS09T0474300
# Nearest neighbors: osa-circ12625-OS03T0735000, Condition: drought
# Nearest neighbors: osa-circ11963-OS09T0521500, Condition: control
# Nearest neighbors: osa-circ1418-OS07T0191200, Condition: control
# Nearest neighbors: osa-circ12566-OS11T0483600, Condition: drought
# Nearest neighbors: osa-circ29614-OS06T0660800, Condition: control
# Seq of "drought" group: osa-circ13494-OS09T0491852
# Nearest neighbors: osa-circ20489-OS01T0177200, Condition: control
# Nearest neighbors: osa-circ10918-OS04T0543900, Condition: control
# Nearest neighbors: osa-circ17904-OS06T0163400, Condition: control
# Nearest neighbors: osa-circ13501-OS08T0242900, Condition: drought
# Nearest neighbors: osa-circ13399-OS10T0460900, Condition: drought
# Seq of "drought" group: osa-circ13495-OS09T0509200
# Nearest neighbors: osa-circ30602-OS08T0480100, Condition: control
# Nearest neighbors: osa-circ13465-OS04T0516600, Condition: drought
# Nearest neighbors: osa-circ28261-OS04T0667800, Condition: control
# Nearest neighbors: osa-circ36979-OS04T0492300, Condition: control
# Nearest neighbors: osa-circ23255-OS01T0610100, Condition: control
# Seq of "drought" group: osa-circ13496-OS09T0551300
# Nearest neighbors: osa-circ6162-OS03T0221800, Condition: control
# Nearest neighbors: osa-circ25838-OS02T0224400, Condition: control
# Nearest neighbors: osa-circ26843-OS05T0134400, Condition: control
# Nearest neighbors: osa-circ26822-OS05T0134400, Condition: control
# Nearest neighbors: osa-circ13311-OS01T0752800, Condition: drought
# Seq of "drought" group: osa-circ13497-OS09T0557800
# Nearest neighbors: osa-circ13295-OS12T0165000, Condition: drought
# Nearest neighbors: osa-circ12813-OS07T0495900, Condition: drought
# Nearest neighbors: osa-circ13402-OS12T0137200, Condition: drought
# Nearest neighbors: osa-circ37486-OS08T0342400, Condition: control
# Nearest neighbors: osa-circ13870-OS03T0430400, Condition: control
# Seq of "drought" group: osa-circ13498-OS08T0163400
# Nearest neighbors: osa-circ33451-OS09T0367900, Condition: control
# Nearest neighbors: osa-circ6861-OS06T0300700, Condition: control
# Nearest neighbors: osa-circ4256-OS03T0206400, Condition: control
# Nearest neighbors: osa-circ45767--, Condition: control
# Nearest neighbors: osa-circ49349--, Condition: control
# Seq of "drought" group: osa-circ13499-OS08T0191700
# Nearest neighbors: osa-circ12844-OS08T0359000, Condition: drought
# Nearest neighbors: osa-circ30592-OS08T0471900, Condition: control
# Nearest neighbors: osa-circ13418-OS01T0951400, Condition: drought
# Nearest neighbors: osa-circ31728-OS01T0279900, Condition: control
# Nearest neighbors: osa-circ13495-OS09T0509200, Condition: drought
# Seq of "drought" group: osa-circ13500-OS08T0242700
# Nearest neighbors: osa-circ12834-OS09T0467100, Condition: drought
# Nearest neighbors: osa-circ46379--, Condition: control
# Nearest neighbors: osa-circ46577--, Condition: control
# Nearest neighbors: osa-circ10530-OS03T0169000, Condition: control
# Nearest neighbors: osa-circ27877-OS04T0474900, Condition: control
# Seq of "drought" group: osa-circ13501-OS08T0242900
# Nearest neighbors: osa-circ13287-OS11T0157100, Condition: drought
# Nearest neighbors: osa-circ12685-OS06T0218500, Condition: drought
# Nearest neighbors: osa-circ60911-OS08T0103000, Condition: control
# Nearest neighbors: osa-circ13323-OS03T0288600, Condition: drought
# Nearest neighbors: osa-circ3582-OS05T0147400, Condition: control
# Seq of "drought" group: osa-circ13502-OS08T0248800
# Nearest neighbors: osa-circ13406-OS01T0253100, Condition: drought
# Nearest neighbors: osa-circ47740--, Condition: control
# Nearest neighbors: osa-circ21908-OS10T0151800, Condition: control
# Nearest neighbors: osa-circ12679-OS07T0658400, Condition: drought
# Nearest neighbors: osa-circ10918-OS04T0543900, Condition: control
# Seq of "drought" group: osa-circ13503-OS08T0451700
# Nearest neighbors: osa-circ16316-OS03T0360500, Condition: control
# Nearest neighbors: osa-circ51400-OS04T0479500, Condition: drought
# Nearest neighbors: osa-circ15093-OS02T0534800, Condition: control
# Nearest neighbors: osa-circ21750-OS11T0525200, Condition: control
# Nearest neighbors: osa-circ12736-OS01T0719100, Condition: drought
# Seq of "drought" group: osa-circ13504-OS08T0463900
# Nearest neighbors: osa-circ60827-OS08T0537001, Condition: drought
# Nearest neighbors: osa-circ60820-OS05T0204900, Condition: drought
# Nearest neighbors: osa-circ60815-OS08T0413850, Condition: drought
# Nearest neighbors: osa-circ62490-OS08T0461800, Condition: control
# Nearest neighbors: osa-circ18492-OS05T0509200, Condition: control
# Seq of "drought" group: osa-circ13505-OS08T0482100
# Nearest neighbors: osa-circ13386-OS08T0482100, Condition: drought
# Nearest neighbors: osa-circ23416-OS01T0681200, Condition: control
# Nearest neighbors: osa-circ26822-OS05T0134400, Condition: control
# Nearest neighbors: osa-circ26843-OS05T0134400, Condition: control
# Nearest neighbors: osa-circ6550-OS09T0465600, Condition: control
# Seq of "drought" group: osa-circ13506-OS08T0525600
# Nearest neighbors: osa-circ2677-OS05T0350600, Condition: control
# Nearest neighbors: osa-circ20106-OS07T0137200, Condition: control
# Nearest neighbors: osa-circ23459-OS01T0707300, Condition: control
# Nearest neighbors: osa-circ53932-OS11T0175450, Condition: control
# Nearest neighbors: osa-circ13331-OS03T0738000, Condition: drought
# Seq of "drought" group: osa-circ13507-OS08T0541400
# Nearest neighbors: osa-circ51126-OS08T0535700, Condition: drought
# Nearest neighbors: osa-circ29844-OS09T0128400, Condition: control
# Nearest neighbors: osa-circ51057-OS10T0556200, Condition: drought
# Nearest neighbors: osa-circ51413-OS12T0129700, Condition: drought
# Nearest neighbors: osa-circ10396-OS01T0503400, Condition: control
# Seq of "drought" group: osa-circ13508-OS08T0557100
# Nearest neighbors: osa-circ32725-OS05T0402300, Condition: control
# Nearest neighbors: osa-circ60820-OS05T0204900, Condition: drought
# Nearest neighbors: osa-circ62852-OS04T0394300, Condition: control
# Nearest neighbors: osa-circ60827-OS08T0537001, Condition: drought
# Nearest neighbors: osa-circ19225-OS08T0116400, Condition: control
# Seq of "drought" group: osa-circ13509-OS08T0557100
# Nearest neighbors: osa-circ13390-OS08T0557100, Condition: drought
# Nearest neighbors: osa-circ60820-OS05T0204900, Condition: drought
# Nearest neighbors: osa-circ20894-OS01T0225200, Condition: control
# Nearest neighbors: osa-circ60827-OS08T0537001, Condition: drought
# Nearest neighbors: osa-circ60812-OS01T0600300, Condition: drought
# Seq of "drought" group: osa-circ13510-OS08T0562200
# Nearest neighbors: osa-circ36996-OS04T0555600, Condition: control
# Nearest neighbors: osa-circ51116-OS06T0115300, Condition: drought
# Nearest neighbors: osa-circ51405-OS04T0672800, Condition: drought
# Nearest neighbors: osa-circ12572-OS10T0509200, Condition: drought
# Nearest neighbors: osa-circ13432-OS03T0586800, Condition: drought
# Seq of "drought" group: osa-circ13511-OS08T0562700
# Nearest neighbors: osa-circ12844-OS08T0359000, Condition: drought
# Nearest neighbors: osa-circ16914-OS10T0400800, Condition: control
# Nearest neighbors: osa-circ45541--, Condition: control
# Nearest neighbors: osa-circ13448-OS02T0169800, Condition: drought
# Nearest neighbors: osa-circ36853-OS05T0472200, Condition: control
# Seq of "drought" group: osa-circ50669-OS03T0731900
# Nearest neighbors: osa-circ62892--, Condition: control
# Nearest neighbors: osa-circ60767-OS04T0459500, Condition: drought
# Nearest neighbors: osa-circ8474-OS03T0180900, Condition: control
# Nearest neighbors: osa-circ60780-OS04T0459500, Condition: drought
# Nearest neighbors: osa-circ22075-OS10T0467800, Condition: control
# Seq of "drought" group: osa-circ50672-OS04T0459500
# Nearest neighbors: osa-circ60780-OS04T0459500, Condition: drought
# Nearest neighbors: osa-circ60767-OS04T0459500, Condition: drought
# Nearest neighbors: osa-circ61373-OS03T0275300, Condition: control
# Nearest neighbors: osa-circ13383-OS08T0163400, Condition: drought
# Nearest neighbors: osa-circ12138-OS01T0382700, Condition: control
# Number of iterated drought stress sequences: 824
# Total number of neighbors in the "drought" group: 1259
# Total number of neighbors in the "control" group": 584
# Percentage of neighbors in the "drought" group: 46.12%
# Percentage of neighbors in the "control" group: 21.39%
