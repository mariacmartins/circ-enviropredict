# %% [markdown]
# # Annoy Analysis:
# Annoy (Approximate Nearest Neighbors Oh Yeah) is an efficient technique for finding nearest neighbors in large datasets, particularly in applications involving vectors, such as machine learning and information retrieval.
#
# ## How Annoy Works:
#
# Data (typically vectors) are added to an index. Each vector represents a numerical representation of an item.
#
# Tree Division: Annoy builds multiple search trees, where each tree is constructed based on a random sample of the data. The idea is to partition the space into regions, allowing for faster neighbor searches.
#
# Search Algorithm:
# When querying a vector, Annoy searches through the constructed trees. It traverses the trees to find the nearest neighbors.
# The algorithm is designed to be fast, using approximation, which means it might not always find the exact nearest neighbors but frequently finds very close neighbors efficiently.

# %%
# !pip install annoy
# Out:
# Collecting annoy
#   Downloading annoy-1.17.3.tar.gz (647 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.5/647.5 kB 9.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: annoy
#   Building wheel for annoy (setup.py) ... done
#   Created wheel for annoy: filename=annoy-1.17.3-cp310-cp310-linux_x86_64.whl size=552448 sha256=ab261789336281aba0524ada12a8054b4ef5fc099dc0a10d71c39cc51f9c7eee
#   Stored in directory: /root/.cache/pip/wheels/64/8a/da/f714bcf46c5efdcfcac0559e63370c21abe961c48e3992465a
# Successfully built annoy
# Installing collected packages: annoy
# Successfully installed annoy-1.17.3

# %%
# Import Libs
import pandas as pd
from annoy import AnnoyIndex

# %%
df = pd.read_excel('/content/maize_word2vec_3mer_dataset.xlsx')

# %%
df.head(2)
# Out:
#                    circName stress          tissue chr      start        end  \
# 0  zma-circ1-Zm00001d002325      -  multipleTissue   2   10317309   10317467
# 1  zma-circ2-Zm00001d038675      -  multipleTissue   6  162376852  162378246
#
#   strand start_anno  wc_3mer_1  wc_3mer_2  ...  wc_3mer_55  wc_3mer_56  \
# 0      -   exon,CDS  -2.819397 -26.071322  ...   -1.649599   31.579550
# 1      +   exon,CDS  38.139316 -33.984278  ... -276.418821  -19.796359
#
#    wc_3mer_57  wc_3mer_58  wc_3mer_59  wc_3mer_60  wc_3mer_61  wc_3mer_62  \
# 0    8.262636   -8.476553  -21.353326   -5.830368    5.679497   -0.869754
# 1  -14.883323 -210.640130 -108.069105 -196.095334   -8.178139  196.293086
#
#    wc_3mer_63  wc_3mer_64
# 0  -16.990953  -28.061553
# 1 -111.923786 -176.260473
#
# [2 rows x 72 columns]

# %%
dimension = 64

# %% [markdown]
# # Drought stress dataset

# %%
df_drought = df.query('stress == "-" or stress == "drought"').replace('-', 'control')

# %%
df_vec = df_drought.drop(['tissue','chr','start','end','strand','start_anno'], axis=1)
df_vec
# Out:
#                        circName   stress  wc_3mer_1  wc_3mer_2   wc_3mer_3  \
# 0      zma-circ1-Zm00001d002325  control  -2.819397 -26.071322   -2.050199
# 1      zma-circ2-Zm00001d038675  control  38.139316 -33.984278 -402.364554
# 2      zma-circ3-Zm00001d038163  control -13.009970 -12.990245  -26.831700
# 3      zma-circ4-Zm00001d049552  control  -7.712050  -3.377060   10.117356
# 4      zma-circ5-Zm00001d032567  control   5.437028 -13.467944  -87.025836
# ...                         ...      ...        ...        ...         ...
# 38780           zma-circ38781--  control -13.972886   6.107950  -25.147395
# 38781           zma-circ38782--  control   7.036017 -10.090989  -36.701810
# 38782           zma-circ38783--  control -18.672884  43.651235  -33.115869
# 38783           zma-circ38784--  control   7.627427 -54.741109 -242.209928
# 38784           zma-circ38785--  control   4.367715 -40.484883 -155.242902
#
#         wc_3mer_4   wc_3mer_5   wc_3mer_6   wc_3mer_7  wc_3mer_8  ...  \
# 0       11.781961   -9.510820   20.928187   10.537300   8.309442  ...
# 1      -30.165603   47.523170  189.462963 -281.399404  95.374081  ...
# 2       57.567522  -63.762736  -13.593141   39.764057 -25.189784  ...
# 3       10.020552    2.411303   19.037348   -2.969932   3.283452  ...
# 4        3.275219   17.536336   70.588946  -70.014532  31.610944  ...
# ...           ...         ...         ...         ...        ...  ...
# 38780   73.045038  -87.992530  -31.104236   68.620450 -49.629747  ...
# 38781   24.329014  -40.458631   17.339536   -3.631819 -21.419614  ...
# 38782  118.402164 -140.489068  -27.546500   68.986703 -92.037108  ...
# 38783  153.955496 -204.570579  -41.848951   36.354824 -20.722182  ...
# 38784  109.700609 -131.003867  -32.675168   30.445829  -9.771256  ...
#
#        wc_3mer_55  wc_3mer_56  wc_3mer_57  wc_3mer_58  wc_3mer_59  wc_3mer_60  \
# 0       -1.649599   31.579550    8.262636   -8.476553  -21.353326   -5.830368
# 1     -276.418821  -19.796359  -14.883323 -210.640130 -108.069105 -196.095334
# 2       41.822434    8.608161   -6.166661   31.397092   23.119942   14.479912
# 3      -28.654313    9.646898   16.798625    4.431155  -22.220375  -12.460058
# 4      -27.083839  -10.496368   -3.498599  -47.558427   34.946736  -30.822783
# ...           ...         ...         ...         ...         ...         ...
# 38780   98.429620    7.452953  -15.737801   35.920804   61.204687   48.885356
# 38781   24.790249    6.276686  -12.864078   -1.256257   42.178863   -4.007750
# 38782  172.084031   18.400802  -26.153603   36.820269  153.651124  101.715267
# 38783   87.106894   30.368255  -34.900771   53.611954   44.205673  -65.699111
# 38784   63.924154   24.569074  -20.824994   33.809647   26.775046  -38.116541
#
#        wc_3mer_61  wc_3mer_62  wc_3mer_63  wc_3mer_64
# 0        5.679497   -0.869754  -16.990953  -28.061553
# 1       -8.178139  196.293086 -111.923786 -176.260473
# 2        7.400303  -15.383993   25.829718  -35.978360
# 3        8.829987   17.305939  -19.056328   -6.713643
# 4      -12.506350   11.305700  -11.058980  -78.504665
# ...           ...         ...         ...         ...
# 38780  -12.690994  -36.205666   44.758745  -17.722664
# 38781  -10.729215   -5.812331    7.679475  -18.434670
# 38782  -52.398818  -47.916956   38.571516  -17.400118
# 38783   30.057831  104.595740   81.229813 -104.068594
# 38784   20.627757   61.305800   55.650500  -70.285168
#
# [32015 rows x 66 columns]

# %%
df_vec['stress'].value_counts()
# Out:
# stress
# control    20809
# drought    11206
# Name: count, dtype: int64

# %%
drought_sequences = df_vec[df_vec['stress'] == 'drought']
control_sequences = df_vec[df_vec['stress'] == 'control']

# creating sample
control_sample = control_sequences.sample(n=11206, random_state=42)

combined_sequences = pd.concat([drought_sequences, control_sample])

t = AnnoyIndex(dimension, 'angular')
for i in range(len(combined_sequences)):
    t.add_item(i, combined_sequences.iloc[i, 2:2 + dimension].values)
t.build(10)

similarities = {}
n_vizinhos = 5  # number of neighbors

# Analyzing only 'drought' sequences
for estresse_index in drought_sequences.index:
    if estresse_index < len(df_vec):
        adjusted_index = combined_sequences.index.get_loc(estresse_index)

        #Search neighbors
        vizinhos = t.get_nns_by_item(adjusted_index, n_vizinhos + 1)
        valid_vizinhos = []

        for i in vizinhos:
            if combined_sequences.iloc[i]['circName'] != combined_sequences.iloc[adjusted_index]['circName']:
                valid_vizinhos.append(i)
            if len(valid_vizinhos) == n_vizinhos:
                break

        similarities[estresse_index] = valid_vizinhos

# Results
drought_count = 0
control_count = 0
control_neighbors = set()

with open('neighbors_results_drought_maize.txt', 'w') as f:
  for estresse_index, vizinhos in similarities.items():
      drought_sequence = combined_sequences.iloc[combined_sequences.index.get_loc(estresse_index)]['circName']
      similar_sequences = [combined_sequences.iloc[i]['circName'] for i in vizinhos]
      similar_conditions = [combined_sequences.iloc[i]['stress'] for i in vizinhos]

      for i in vizinhos:
          if combined_sequences.iloc[i]['stress'] == 'control':
              control_neighbors.add(i)

      drought_count += similar_conditions.count('drought')

      print(f'Seq of "drought" group: {drought_sequence}')
      f.write(f'Seq of "drought" group: {drought_sequence}\n')

      for seq, cond in zip(similar_sequences, similar_conditions):
          print(f'Nearest neighbors: {seq}, Condition: {cond}')
          f.write(f'Nearest neighbors: {seq}, Condition: {cond}\n')

control_count = len(control_neighbors)

# Similarity analysis
total_vizinhos = len(similarities) * n_vizinhos
num_drought_sequences = len(drought_sequences)

print(f'Number of iterated drought stress sequences: {num_drought_sequences}')
print(f'Total number of neighbors in the "drought" group: {drought_count}')
print(f'Total number of neighbors in the "control" group": {control_count}')
print(f'Percentage of neighbors in the "drought" group: {drought_count / total_vizinhos * 100:.2f}%')
print(f'Percentage of neighbors in the "control" group: {control_count / total_vizinhos * 100:.2f}%')
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Nearest neighbors: zma-circ34102-Zm00001d039341, Condition: drought
# Nearest neighbors: zma-circ21388-Zm00001d028010, Condition: control
# Nearest neighbors: zma-circ35918-Zm00001d042569, Condition: control
# Seq of "drought" group: zma-circ20113-Zm00001d026000
# Nearest neighbors: zma-circ12963-Zm00001d004159, Condition: drought
# Nearest neighbors: zma-circ32455-Zm00001d018481, Condition: drought
# Nearest neighbors: zma-circ15184-Zm00001d040340, Condition: drought
# Nearest neighbors: zma-circ35266-Zm00001d017997, Condition: drought
# Nearest neighbors: zma-circ15171-Zm00001d039534, Condition: drought
# Seq of "drought" group: zma-circ20114-Zm00001d026031
# Nearest neighbors: zma-circ33171-Zm00001d017072, Condition: drought
# Nearest neighbors: zma-circ35550-Zm00001d007599, Condition: control
# Nearest neighbors: zma-circ33434-Zm00001d017872, Condition: control
# Nearest neighbors: zma-circ37795-Zm00001d018642, Condition: drought
# Nearest neighbors: zma-circ33940-Zm00001d017072, Condition: control
# Seq of "drought" group: zma-circ20115-Zm00001d026567
# Nearest neighbors: zma-circ21423-Zm00001d013334, Condition: control
# Nearest neighbors: zma-circ14168-Zm00001d022338, Condition: drought
# Nearest neighbors: zma-circ20318-Zm00001d038097, Condition: drought
# Nearest neighbors: zma-circ16190-Zm00001d027971, Condition: drought
# Nearest neighbors: zma-circ21923-Zm00001d050304, Condition: drought
# Seq of "drought" group: zma-circ20116-Zm00001d027369
# Nearest neighbors: zma-circ698-Zm00001d021972, Condition: control
# Nearest neighbors: zma-circ3038-Zm00001d025111, Condition: control
# Nearest neighbors: zma-circ27808--, Condition: control
# Nearest neighbors: zma-circ19411-Zm00001d023640, Condition: drought
# Nearest neighbors: zma-circ15401-Zm00001d006382, Condition: drought
# Seq of "drought" group: zma-circ20117-Zm00001d027512
# Nearest neighbors: zma-circ21154-Zm00001d051951, Condition: control
# Nearest neighbors: zma-circ32008-Zm00001d036620, Condition: control
# Nearest neighbors: zma-circ20008-Zm00001d035695, Condition: drought
# Nearest neighbors: zma-circ37824-Zm00001d029426, Condition: drought
# Nearest neighbors: zma-circ21077-Zm00001d027722, Condition: control
# Seq of "drought" group: zma-circ20118-Zm00001d027701
# Nearest neighbors: zma-circ17869-Zm00001d040010, Condition: control
# Nearest neighbors: zma-circ20657-Zm00001d041568, Condition: control
# Nearest neighbors: zma-circ19977-Zm00001d041568, Condition: drought
# Nearest neighbors: zma-circ8859-Zm00001d037877, Condition: control
# Nearest neighbors: zma-circ18854-Zm00001d028818, Condition: drought
# Seq of "drought" group: zma-circ20119-Zm00001d027869
# Nearest neighbors: zma-circ20369-Zm00001d047239, Condition: drought
# Nearest neighbors: zma-circ29274--, Condition: control
# Nearest neighbors: zma-circ1688-Zm00001d004877, Condition: control
# Nearest neighbors: zma-circ34119-Zm00001d043110, Condition: drought
# Nearest neighbors: zma-circ20107-Zm00001d038779, Condition: drought
# Seq of "drought" group: zma-circ20120-Zm00001d028359
# Nearest neighbors: zma-circ21580-Zm00001d044273, Condition: control
# Nearest neighbors: zma-circ29482--, Condition: control
# Nearest neighbors: zma-circ31249-Zm00001d017174, Condition: control
# Nearest neighbors: zma-circ18591-Zm00001d013380, Condition: control
# Nearest neighbors: zma-circ17309-Zm00001d028232, Condition: drought
# Seq of "drought" group: zma-circ20121-Zm00001d028728
# Nearest neighbors: zma-circ15792-Zm00001d049409, Condition: drought
# Nearest neighbors: zma-circ35472-Zm00001d051394, Condition: control
# Nearest neighbors: zma-circ28341--, Condition: control
# Nearest neighbors: zma-circ15676-Zm00001d014422, Condition: drought
# Nearest neighbors: zma-circ16291-Zm00001d014090, Condition: drought
# Seq of "drought" group: zma-circ20122-Zm00001d028896
# Nearest neighbors: zma-circ13431-Zm00001d002992, Condition: control
# Nearest neighbors: zma-circ13432-Zm00001d002992, Condition: control
# Nearest neighbors: zma-circ30967-Zm00001d018413, Condition: control
# Nearest neighbors: zma-circ32957-Zm00001d012635, Condition: control
# Nearest neighbors: zma-circ31759-Zm00001d035750, Condition: control
# Seq of "drought" group: zma-circ20123-Zm00001d030164
# Nearest neighbors: zma-circ17431-Zm00001d045327, Condition: drought
# Nearest neighbors: zma-circ12913-Zm00001d018901, Condition: drought
# Nearest neighbors: zma-circ12431-Zm00001d030164, Condition: control
# Nearest neighbors: zma-circ8033-Zm00001d010855, Condition: drought
# Nearest neighbors: zma-circ30890-Zm00001d022421, Condition: control
# Seq of "drought" group: zma-circ20124-Zm00001d030657
# Nearest neighbors: zma-circ11474-Zm00001d030657, Condition: control
# Nearest neighbors: zma-circ421-Zm00001d025125, Condition: control
# Nearest neighbors: zma-circ35216-Zm00001d007661, Condition: drought
# Nearest neighbors: zma-circ20239-Zm00001d052353, Condition: drought
# Nearest neighbors: zma-circ35301-Zm00001d017398, Condition: drought
# Seq of "drought" group: zma-circ20125-Zm00001d031074
# Nearest neighbors: zma-circ20866-Zm00001d038348, Condition: control
# Nearest neighbors: zma-circ34196-Zm00001d007397, Condition: drought
# Nearest neighbors: zma-circ20192-Zm00001d038999, Condition: drought
# Nearest neighbors: zma-circ16289-Zm00001d014038, Condition: drought
# Nearest neighbors: zma-circ15227-Zm00001d043151, Condition: drought
# Seq of "drought" group: zma-circ20126-Zm00001d031254
# Nearest neighbors: zma-circ16816-Zm00001d030266, Condition: drought
# Nearest neighbors: zma-circ17395-Zm00001d014109, Condition: drought
# Nearest neighbors: zma-circ15809-Zm00001d050612, Condition: drought
# Nearest neighbors: zma-circ18701-Zm00001d044364, Condition: drought
# Nearest neighbors: zma-circ4110-Zm00001d050134, Condition: drought
# Seq of "drought" group: zma-circ20127-Zm00001d031701
# Nearest neighbors: zma-circ20343-Zm00001d030725, Condition: drought
# Nearest neighbors: zma-circ21124-Zm00001d013607, Condition: control
# Nearest neighbors: zma-circ2879-Zm00001d035515, Condition: drought
# Nearest neighbors: zma-circ21544-Zm00001d052945, Condition: control
# Nearest neighbors: zma-circ8167-Zm00001d022586, Condition: drought
# Seq of "drought" group: zma-circ20128-Zm00001d032127
# Nearest neighbors: zma-circ5881-Zm00001d002185, Condition: control
# Nearest neighbors: zma-circ29231--, Condition: control
# Nearest neighbors: zma-circ1395-Zm00001d051976, Condition: drought
# Nearest neighbors: zma-circ6985-Zm00001d028813, Condition: control
# Nearest neighbors: zma-circ148-Zm00001d043376, Condition: control
# Seq of "drought" group: zma-circ20129-Zm00001d032166
# Nearest neighbors: zma-circ29642--, Condition: control
# Nearest neighbors: zma-circ21408-Zm00001d032166, Condition: control
# Nearest neighbors: zma-circ30222--, Condition: control
# Nearest neighbors: zma-circ19352-Zm00001d004667, Condition: drought
# Nearest neighbors: zma-circ18337-Zm00001d029557, Condition: control
# Seq of "drought" group: zma-circ20130-Zm00001d032379
# Nearest neighbors: zma-circ8586-Zm00001d009146, Condition: control
# Nearest neighbors: zma-circ8052-Zm00001d040123, Condition: drought
# Nearest neighbors: zma-circ33437-Zm00001d045539, Condition: control
# Nearest neighbors: zma-circ8461-Zm00001d014957, Condition: drought
# Nearest neighbors: zma-circ17021-Zm00001d052803, Condition: drought
# Seq of "drought" group: zma-circ20131-Zm00001d032875
# Nearest neighbors: zma-circ4614-Zm00001d018694, Condition: drought
# Nearest neighbors: zma-circ21234-Zm00001d013282, Condition: control
# Nearest neighbors: zma-circ12264-Zm00001d021126, Condition: control
# Nearest neighbors: zma-circ20948-Zm00001d051233, Condition: control
# Nearest neighbors: zma-circ1611-Zm00001d001988, Condition: control
# Seq of "drought" group: zma-circ20132-Zm00001d033020
# Nearest neighbors: zma-circ15858-Zm00001d010957, Condition: drought
# Nearest neighbors: zma-circ10628-Zm00001d008340, Condition: control
# Nearest neighbors: zma-circ20897-Zm00001d033020, Condition: control
# Nearest neighbors: zma-circ12919-Zm00001d019563, Condition: drought
# Nearest neighbors: zma-circ15004-Zm00001d019563, Condition: control
# Seq of "drought" group: zma-circ20133-Zm00001d034254
# Nearest neighbors: zma-circ34549-Zm00001d007938, Condition: drought
# Nearest neighbors: zma-circ4437-Zm00001d046039, Condition: drought
# Nearest neighbors: zma-circ15108-Zm00001d053059, Condition: drought
# Nearest neighbors: zma-circ16884-Zm00001d013371, Condition: drought
# Nearest neighbors: zma-circ30252--, Condition: control
# Seq of "drought" group: zma-circ20134-Zm00001d034345
# Nearest neighbors: zma-circ20450-Zm00001d019627, Condition: control
# Nearest neighbors: zma-circ5751-Zm00001d007095, Condition: control
# Nearest neighbors: zma-circ31826-Zm00001d018277, Condition: control
# Nearest neighbors: zma-circ13323-Zm00001d043309, Condition: control
# Nearest neighbors: zma-circ5553-Zm00001d020943, Condition: control
# Seq of "drought" group: zma-circ20135-Zm00001d013317
# Nearest neighbors: zma-circ5033-Zm00001d013317, Condition: control
# Nearest neighbors: zma-circ20324-Zm00001d024596, Condition: drought
# Nearest neighbors: zma-circ15646-Zm00001d034810, Condition: drought
# Nearest neighbors: zma-circ4313-Zm00001d051976, Condition: drought
# Nearest neighbors: zma-circ17786-Zm00001d047498, Condition: control
# Seq of "drought" group: zma-circ20136-Zm00001d013745
# Nearest neighbors: zma-circ606-Zm00001d019905, Condition: control
# Nearest neighbors: zma-circ19078-Zm00001d007081, Condition: drought
# Nearest neighbors: zma-circ4730-Zm00001d033159, Condition: control
# Nearest neighbors: zma-circ1646-Zm00001d032587, Condition: control
# Nearest neighbors: zma-circ6884-Zm00001d021132, Condition: drought
# Seq of "drought" group: zma-circ20137-Zm00001d013758
# Nearest neighbors: zma-circ4901-Zm00001d013758, Condition: drought
# Nearest neighbors: zma-circ6283-Zm00001d047385, Condition: control
# Nearest neighbors: zma-circ35761-Zm00001d017043, Condition: control
# Nearest neighbors: zma-circ6042-Zm00001d013391, Condition: control
# Nearest neighbors: zma-circ15380-Zm00001d004739, Condition: drought
# Seq of "drought" group: zma-circ20138-Zm00001d013887
# Nearest neighbors: zma-circ8373-Zm00001d029418, Condition: drought
# Nearest neighbors: zma-circ35372-Zm00001d017863, Condition: drought
# Nearest neighbors: zma-circ35508-Zm00001d017863, Condition: control
# Nearest neighbors: zma-circ21432-Zm00001d015415, Condition: control
# Nearest neighbors: zma-circ11473-Zm00001d030533, Condition: control
# Seq of "drought" group: zma-circ20139-Zm00001d014090
# Nearest neighbors: zma-circ20075-Zm00001d043649, Condition: drought
# Nearest neighbors: zma-circ35333-Zm00001d048286, Condition: drought
# Nearest neighbors: zma-circ11895-Zm00001d043239, Condition: control
# Nearest neighbors: zma-circ31755-Zm00001d000436, Condition: control
# Nearest neighbors: zma-circ31861-Zm00001d012451, Condition: control
# Seq of "drought" group: zma-circ20140-Zm00001d014626
# Nearest neighbors: zma-circ8114-Zm00001d020537, Condition: drought
# Nearest neighbors: zma-circ21998-Zm00001d013310, Condition: drought
# Nearest neighbors: zma-circ10885-Zm00001d036959, Condition: control
# Nearest neighbors: zma-circ15756-Zm00001d046719, Condition: drought
# Nearest neighbors: zma-circ10902-Zm00001d038190, Condition: control
# Seq of "drought" group: zma-circ20141-Zm00001d014753
# Nearest neighbors: zma-circ29976--, Condition: control
# Nearest neighbors: zma-circ687-Zm00001d042306, Condition: control
# Nearest neighbors: zma-circ30509--, Condition: control
# Nearest neighbors: zma-circ34717-Zm00001d002130, Condition: drought
# Nearest neighbors: zma-circ34542-GRMZM5G856027, Condition: drought
# Seq of "drought" group: zma-circ20142-Zm00001d015327
# Nearest neighbors: zma-circ15697-Zm00001d015327, Condition: drought
# Nearest neighbors: zma-circ10638-Zm00001d015327, Condition: control
# Nearest neighbors: zma-circ11764-Zm00001d015327, Condition: control
# Nearest neighbors: zma-circ209-Zm00001d015327, Condition: control
# Nearest neighbors: zma-circ33429-Zm00001d015327, Condition: control
# Seq of "drought" group: zma-circ20143-Zm00001d015780
# Nearest neighbors: zma-circ10284-Zm00001d027324, Condition: drought
# Nearest neighbors: zma-circ4173-Zm00001d022502, Condition: drought
# Nearest neighbors: zma-circ15400-Zm00001d006344, Condition: drought
# Nearest neighbors: zma-circ17979-Zm00001d006344, Condition: control
# Nearest neighbors: zma-circ31877-Zm00001d031534, Condition: control
# Seq of "drought" group: zma-circ20144-Zm00001d016587
# Nearest neighbors: zma-circ134-Zm00001d021261, Condition: control
# Nearest neighbors: zma-circ35213-Zm00001d022302, Condition: drought
# Nearest neighbors: zma-circ18200-Zm00001d021261, Condition: control
# Nearest neighbors: zma-circ16085-Zm00001d037035, Condition: drought
# Nearest neighbors: zma-circ6166-Zm00001d009872, Condition: control
# Seq of "drought" group: zma-circ20145-Zm00001d044929
# Nearest neighbors: zma-circ28505--, Condition: control
# Nearest neighbors: zma-circ3584-Zm00001d041392, Condition: control
# Nearest neighbors: zma-circ6791-Zm00001d046449, Condition: control
# Nearest neighbors: zma-circ16074-Zm00001d035953, Condition: drought
# Nearest neighbors: zma-circ34691-Zm00001d054076, Condition: drought
# Seq of "drought" group: zma-circ20146-Zm00001d045509
# Nearest neighbors: zma-circ9523-Zm00001d011373, Condition: control
# Nearest neighbors: zma-circ2738-Zm00001d039221, Condition: control
# Nearest neighbors: zma-circ13703-Zm00001d033370, Condition: control
# Nearest neighbors: zma-circ35177-Zm00001d016991, Condition: drought
# Nearest neighbors: zma-circ14909-Zm00001d008997, Condition: control
# Seq of "drought" group: zma-circ20147-Zm00001d046221
# Nearest neighbors: zma-circ6689-Zm00001d047536, Condition: control
# Nearest neighbors: zma-circ2804-Zm00001d047536, Condition: control
# Nearest neighbors: zma-circ19957-Zm00001d051846, Condition: drought
# Nearest neighbors: zma-circ17611-Zm00001d005276, Condition: control
# Nearest neighbors: zma-circ32144-Zm00001d048693, Condition: drought
# Seq of "drought" group: zma-circ20148-Zm00001d046948
# Nearest neighbors: zma-circ8370-Zm00001d029264, Condition: drought
# Nearest neighbors: zma-circ16009-Zm00001d002396, Condition: drought
# Nearest neighbors: zma-circ17080-Zm00001d041307, Condition: drought
# Nearest neighbors: zma-circ35530-Zm00001d012085, Condition: control
# Nearest neighbors: zma-circ27317-Zm00001d007075, Condition: control
# Seq of "drought" group: zma-circ20149-Zm00001d047757
# Nearest neighbors: zma-circ30121--, Condition: control
# Nearest neighbors: zma-circ28749--, Condition: control
# Nearest neighbors: zma-circ12634-Zm00001d003106, Condition: drought
# Nearest neighbors: zma-circ34195-Zm00001d007378, Condition: drought
# Nearest neighbors: zma-circ15160-Zm00001d010321, Condition: drought
# Seq of "drought" group: zma-circ20150-Zm00001d048066
# Nearest neighbors: zma-circ19951-Zm00001d048066, Condition: drought
# Nearest neighbors: zma-circ18908-Zm00001d014321, Condition: drought
# Nearest neighbors: zma-circ8342-Zm00001d028093, Condition: drought
# Nearest neighbors: zma-circ12538-Zm00001d008846, Condition: drought
# Nearest neighbors: zma-circ17383-Zm00001d012815, Condition: drought
# Seq of "drought" group: zma-circ20151-Zm00001d048741
# Nearest neighbors: zma-circ7063-Zm00001d048741, Condition: control
# Nearest neighbors: zma-circ11838-Zm00001d048741, Condition: control
# Nearest neighbors: zma-circ15784-Zm00001d048741, Condition: drought
# Nearest neighbors: zma-circ19852-Zm00001d048741, Condition: drought
# Nearest neighbors: zma-circ20056-Zm00001d048741, Condition: drought
# Seq of "drought" group: zma-circ20152-Zm00001d049148
# Nearest neighbors: zma-circ1601-Zm00001d037725, Condition: control
# Nearest neighbors: zma-circ29691--, Condition: control
# Nearest neighbors: zma-circ35439-Zm00001d034867, Condition: control
# Nearest neighbors: zma-circ8373-Zm00001d029418, Condition: drought
# Nearest neighbors: zma-circ33660-Zm00001d018275, Condition: drought
# Seq of "drought" group: zma-circ20153-Zm00001d049638
# Nearest neighbors: zma-circ35520-Zm00001d053919, Condition: control
# Nearest neighbors: zma-circ35978-Zm00001d018418, Condition: drought
# Nearest neighbors: zma-circ21651-Zm00001d038302, Condition: control
# Nearest neighbors: zma-circ20866-Zm00001d038348, Condition: control
# Nearest neighbors: zma-circ38423--, Condition: control
# Seq of "drought" group: zma-circ20154-Zm00001d050300
# Nearest neighbors: zma-circ32288-Zm00001d016722, Condition: control
# Nearest neighbors: zma-circ659-Zm00001d052009, Condition: control
# Nearest neighbors: zma-circ30553--, Condition: control
# Nearest neighbors: zma-circ6706-Zm00001d019075, Condition: drought
# Nearest neighbors: zma-circ2671-Zm00001d004616, Condition: control
# Seq of "drought" group: zma-circ20155-Zm00001d052348
# Nearest neighbors: zma-circ34878-Zm00001d048546, Condition: control
# Nearest neighbors: zma-circ21977-Zm00001d026547, Condition: drought
# Nearest neighbors: zma-circ7354-Zm00001d015754, Condition: drought
# Nearest neighbors: zma-circ35694-Zm00001d027288, Condition: control
# Nearest neighbors: zma-circ21790-Zm00001d043840, Condition: control
# Seq of "drought" group: zma-circ20156-Zm00001d008614
# Nearest neighbors: zma-circ34532-Zm00001d043724, Condition: drought
# Nearest neighbors: zma-circ14105-Zm00001d020140, Condition: drought
# Nearest neighbors: zma-circ8328-Zm00001d026501, Condition: drought
# Nearest neighbors: zma-circ35594-Zm00001d051599, Condition: control
# Nearest neighbors: zma-circ20226-Zm00001d045472, Condition: drought
# Seq of "drought" group: zma-circ20157-Zm00001d009597
# Nearest neighbors: zma-circ8321-Zm00001d026022, Condition: drought
# Nearest neighbors: zma-circ19957-Zm00001d051846, Condition: drought
# Nearest neighbors: zma-circ18860-Zm00001d029487, Condition: drought
# Nearest neighbors: zma-circ32144-Zm00001d048693, Condition: drought
# Nearest neighbors: zma-circ12725-Zm00001d025865, Condition: drought
# Seq of "drought" group: zma-circ20158-Zm00001d010639
# Nearest neighbors: zma-circ2559-Zm00001d045559, Condition: drought
# Nearest neighbors: zma-circ32974-Zm00001d012108, Condition: drought
# Nearest neighbors: zma-circ7307-Zm00001d037992, Condition: drought
# Nearest neighbors: zma-circ33383-Zm00001d017564, Condition: control
# Nearest neighbors: zma-circ20935-Zm00001d047044, Condition: control
# Seq of "drought" group: zma-circ20159-Zm00001d010744
# Nearest neighbors: zma-circ21381-Zm00001d026426, Condition: control
# Nearest neighbors: zma-circ20253-Zm00001d011688, Condition: drought
# Nearest neighbors: zma-circ2093-Zm00001d020001, Condition: control
# Nearest neighbors: zma-circ17118-Zm00001d044251, Condition: drought
# Nearest neighbors: zma-circ19743-Zm00001d029056, Condition: drought
# Seq of "drought" group: zma-circ20160-Zm00001d011060
# Nearest neighbors: zma-circ4459-Zm00001d011060, Condition: drought
# Nearest neighbors: zma-circ18269-Zm00001d038163, Condition: control
# Nearest neighbors: zma-circ38735--, Condition: control
# Nearest neighbors: zma-circ12995-Zm00001d037323, Condition: drought
# Nearest neighbors: zma-circ20132-Zm00001d033020, Condition: drought
# Seq of "drought" group: zma-circ20161-Zm00001d011611
# Nearest neighbors: zma-circ21629-Zm00001d035029, Condition: control
# Nearest neighbors: zma-circ35765-Zm00001d017703, Condition: control
# Nearest neighbors: zma-circ13075-Zm00001d031525, Condition: drought
# Nearest neighbors: zma-circ19926-Zm00001d031525, Condition: drought
# Nearest neighbors: zma-circ35630-Zm00001d018637, Condition: control
# Seq of "drought" group: zma-circ20162-Zm00001d039537
# Nearest neighbors: zma-circ255-Zm00001d027392, Condition: control
# Nearest neighbors: zma-circ28392--, Condition: control
# Nearest neighbors: zma-circ27862--, Condition: control
# Nearest neighbors: zma-circ14953-Zm00001d025263, Condition: control
# Nearest neighbors: zma-circ319-Zm00001d025830, Condition: control
# Seq of "drought" group: zma-circ20163-Zm00001d039673
# Nearest neighbors: zma-circ33512-Zm00001d018080, Condition: control
# Nearest neighbors: zma-circ26594-Zm00001d052796, Condition: control
# Nearest neighbors: zma-circ17062-Zm00001d039348, Condition: drought
# Nearest neighbors: zma-circ35230-Zm00001d048410, Condition: drought
# Nearest neighbors: zma-circ14334-Zm00001d036228, Condition: drought
# Seq of "drought" group: zma-circ20164-Zm00001d040026
# Nearest neighbors: zma-circ129-Zm00001d052379, Condition: control
# Nearest neighbors: zma-circ10729-Zm00001d043444, Condition: control
# Nearest neighbors: zma-circ30531--, Condition: control
# Nearest neighbors: zma-circ10005-Zm00001d048648, Condition: control
# Nearest neighbors: zma-circ34204-Zm00001d035037, Condition: drought
# Seq of "drought" group: zma-circ20165-Zm00001d040829
# Nearest neighbors: zma-circ17309-Zm00001d028232, Condition: drought
# Nearest neighbors: zma-circ11759-Zm00001d014138, Condition: control
# Nearest neighbors: zma-circ32994-Zm00001d011750, Condition: drought
# Nearest neighbors: zma-circ20322-Zm00001d023689, Condition: drought
# Nearest neighbors: zma-circ8437-Zm00001d012858, Condition: drought
# Seq of "drought" group: zma-circ20166-Zm00001d041785
# Nearest neighbors: zma-circ19976-Zm00001d040301, Condition: drought
# Nearest neighbors: zma-circ10588-Zm00001d047034, Condition: drought
# Nearest neighbors: zma-circ20728-Zm00001d028187, Condition: control
# Nearest neighbors: zma-circ17434-Zm00001d045435, Condition: drought
# Nearest neighbors: zma-circ31120-GRMZM5G874448, Condition: control
# Seq of "drought" group: zma-circ20167-Zm00001d041833
# Nearest neighbors: zma-circ4462-Zm00001d011401, Condition: drought
# Nearest neighbors: zma-circ19527-Zm00001d048734, Condition: drought
# Nearest neighbors: zma-circ19135-Zm00001d026270, Condition: drought
# Nearest neighbors: zma-circ16776-Zm00001d027320, Condition: drought
# Nearest neighbors: zma-circ1653-Zm00001d043134, Condition: control
# Seq of "drought" group: zma-circ20168-Zm00001d041900
# Nearest neighbors: zma-circ9412-Zm00001d021351, Condition: control
# Nearest neighbors: zma-circ19611-Zm00001d019052, Condition: drought
# Nearest neighbors: zma-circ37829-Zm00001d030666, Condition: drought
# Nearest neighbors: zma-circ1535-Zm00001d014280, Condition: control
# Nearest neighbors: zma-circ6191-Zm00001d027503, Condition: control
# Seq of "drought" group: zma-circ20169-Zm00001d042350
# Nearest neighbors: zma-circ26601-Zm00001d022243, Condition: control
# Nearest neighbors: zma-circ8972-Zm00001d031028, Condition: control
# Nearest neighbors: zma-circ18335-Zm00001d029394, Condition: control
# Nearest neighbors: zma-circ8023-Zm00001d009555, Condition: drought
# Nearest neighbors: zma-circ32318-Zm00001d046399, Condition: control
# Seq of "drought" group: zma-circ20170-Zm00001d042475
# Nearest neighbors: zma-circ20234-Zm00001d050043, Condition: drought
# Nearest neighbors: zma-circ18892-Zm00001d033591, Condition: drought
# Nearest neighbors: zma-circ19984-Zm00001d018873, Condition: drought
# Nearest neighbors: zma-circ31213-Zm00001d013540, Condition: control
# Nearest neighbors: zma-circ20033-Zm00001d031747, Condition: drought
# Seq of "drought" group: zma-circ20171-Zm00001d042585
# Nearest neighbors: zma-circ8131-Zm00001d021621, Condition: drought
# Nearest neighbors: zma-circ16872-Zm00001d034719, Condition: drought
# Nearest neighbors: zma-circ20571-Zm00001d033798, Condition: control
# Nearest neighbors: zma-circ17158-Zm00001d021846, Condition: drought
# Nearest neighbors: zma-circ16467-Zm00001d012628, Condition: drought
# Seq of "drought" group: zma-circ20172-Zm00001d042802
# Nearest neighbors: zma-circ2866-Zm00001d037196, Condition: control
# Nearest neighbors: zma-circ21139-Zm00001d044931, Condition: control
# Nearest neighbors: zma-circ17108-Zm00001d043805, Condition: drought
# Nearest neighbors: zma-circ18173-Zm00001d042180, Condition: control
# Nearest neighbors: zma-circ9275-Zm00001d027329, Condition: drought
# Seq of "drought" group: zma-circ20173-Zm00001d043669
# Nearest neighbors: zma-circ16577-Zm00001d021721, Condition: drought
# Nearest neighbors: zma-circ18211-Zm00001d021721, Condition: control
# Nearest neighbors: zma-circ6162-Zm00001d047910, Condition: control
# Nearest neighbors: zma-circ20284-Zm00001d020541, Condition: drought
# Nearest neighbors: zma-circ8115-Zm00001d020541, Condition: drought
# Seq of "drought" group: zma-circ20174-Zm00001d044570
# Nearest neighbors: zma-circ20280-Zm00001d044570, Condition: drought
# Nearest neighbors: zma-circ4933-Zm00001d044570, Condition: drought
# Nearest neighbors: zma-circ4610-Zm00001d044313, Condition: drought
# Nearest neighbors: zma-circ720-Zm00001d030340, Condition: control
# Nearest neighbors: zma-circ8289-Zm00001d039051, Condition: drought
# Seq of "drought" group: zma-circ20175-Zm00001d019724
# Nearest neighbors: zma-circ18619-Zm00001d049377, Condition: drought
# Nearest neighbors: zma-circ15788-Zm00001d049377, Condition: drought
# Nearest neighbors: zma-circ1472-Zm00001d025507, Condition: control
# Nearest neighbors: zma-circ17129-Zm00001d018829, Condition: drought
# Nearest neighbors: zma-circ10125-Zm00001d018829, Condition: drought
# Seq of "drought" group: zma-circ20176-Zm00001d019754
# Nearest neighbors: zma-circ20118-Zm00001d027701, Condition: drought
# Nearest neighbors: zma-circ32775-Zm00001d048924, Condition: control
# Nearest neighbors: zma-circ26673-Zm00001d047527, Condition: control
# Nearest neighbors: zma-circ35655-Zm00001d013076, Condition: control
# Nearest neighbors: zma-circ2941-Zm00001d022180, Condition: drought
# Seq of "drought" group: zma-circ20177-Zm00001d020898
# Nearest neighbors: zma-circ15979-Zm00001d020898, Condition: drought
# Nearest neighbors: zma-circ30279--, Condition: control
# Nearest neighbors: zma-circ12837-Zm00001d047941, Condition: drought
# Nearest neighbors: zma-circ34188-Zm00001d006008, Condition: drought
# Nearest neighbors: zma-circ32282-Zm00001d013493, Condition: control
# Seq of "drought" group: zma-circ20178-Zm00001d022169
# Nearest neighbors: zma-circ28924--, Condition: control
# Nearest neighbors: zma-circ29429--, Condition: control
# Nearest neighbors: zma-circ17296-Zm00001d026653, Condition: drought
# Nearest neighbors: zma-circ20908-Zm00001d012911, Condition: control
# Nearest neighbors: zma-circ35818-Zm00001d053545, Condition: control
# Seq of "drought" group: zma-circ20179-Zm00001d022454
# Nearest neighbors: zma-circ8165-Zm00001d022554, Condition: drought
# Nearest neighbors: zma-circ11262-Zm00001d045042, Condition: control
# Nearest neighbors: zma-circ5994-Zm00001d013367, Condition: control
# Nearest neighbors: zma-circ32364-Zm00001d012561, Condition: drought
# Nearest neighbors: zma-circ29865--, Condition: control
# Seq of "drought" group: zma-circ20180-Zm00001d022454
# Nearest neighbors: zma-circ12227-Zm00001d040279, Condition: control
# Nearest neighbors: zma-circ10604-Zm00001d007032, Condition: drought
# Nearest neighbors: zma-circ19990-Zm00001d003143, Condition: drought
# Nearest neighbors: zma-circ8486-Zm00001d044860, Condition: drought
# Nearest neighbors: zma-circ35601-Zm00001d053738, Condition: control
# Seq of "drought" group: zma-circ20181-Zm00001d001879
# Nearest neighbors: zma-circ14156-Zm00001d021829, Condition: drought
# Nearest neighbors: zma-circ14070-Zm00001d044303, Condition: drought
# Nearest neighbors: zma-circ13872-Zm00001d052282, Condition: drought
# Nearest neighbors: zma-circ31641-Zm00001d017449, Condition: control
# Nearest neighbors: zma-circ12663-Zm00001d036137, Condition: drought
# Seq of "drought" group: zma-circ20182-Zm00001d002781
# Nearest neighbors: zma-circ12888-Zm00001d042695, Condition: drought
# Nearest neighbors: zma-circ35069-Zm00001d013466, Condition: drought
# Nearest neighbors: zma-circ31881-Zm00001d017026, Condition: control
# Nearest neighbors: zma-circ6732-Zm00001d014377, Condition: drought
# Nearest neighbors: zma-circ17266-Zm00001d023238, Condition: drought
# Seq of "drought" group: zma-circ20183-Zm00001d004517
# Nearest neighbors: zma-circ30944-Zm00001d017522, Condition: drought
# Nearest neighbors: zma-circ20550-Zm00001d031490, Condition: control
# Nearest neighbors: zma-circ5310-Zm00001d028464, Condition: control
# Nearest neighbors: zma-circ8846-Zm00001d037100, Condition: control
# Nearest neighbors: zma-circ18334-Zm00001d029281, Condition: control
# Seq of "drought" group: zma-circ20184-Zm00001d005539
# Nearest neighbors: zma-circ3402-Zm00001d022169, Condition: drought
# Nearest neighbors: zma-circ29361--, Condition: control
# Nearest neighbors: zma-circ7454-Zm00001d011601, Condition: control
# Nearest neighbors: zma-circ9980-Zm00001d019670, Condition: control
# Nearest neighbors: zma-circ21839-Zm00001d035185, Condition: control
# Seq of "drought" group: zma-circ20185-Zm00001d006113
# Nearest neighbors: zma-circ8029-Zm00001d009866, Condition: drought
# Nearest neighbors: zma-circ20363-Zm00001d015026, Condition: drought
# Nearest neighbors: zma-circ21993-Zm00001d034809, Condition: drought
# Nearest neighbors: zma-circ20234-Zm00001d050043, Condition: drought
# Nearest neighbors: zma-circ15129-Zm00001d008439, Condition: drought
# Seq of "drought" group: zma-circ20186-Zm00001d035346
# Nearest neighbors: zma-circ15996-Zm00001d022384, Condition: drought
# Nearest neighbors: zma-circ8023-Zm00001d009555, Condition: drought
# Nearest neighbors: zma-circ35582-Zm00001d045596, Condition: control
# Nearest neighbors: zma-circ29891--, Condition: control
# Nearest neighbors: zma-circ20169-Zm00001d042350, Condition: drought
# Seq of "drought" group: zma-circ20187-Zm00001d036351
# Nearest neighbors: zma-circ37673-Zm00001d013532, Condition: control
# Nearest neighbors: zma-circ37696-Zm00001d013532, Condition: drought
# Nearest neighbors: zma-circ29093--, Condition: control
# Nearest neighbors: zma-circ33391-Zm00001d018363, Condition: control
# Nearest neighbors: zma-circ13099-Zm00001d034590, Condition: drought
# Seq of "drought" group: zma-circ20188-Zm00001d037045
# Nearest neighbors: zma-circ17460-Zm00001d047946, Condition: drought
# Nearest neighbors: zma-circ16657-Zm00001d007202, Condition: drought
# Nearest neighbors: zma-circ16086-Zm00001d037045, Condition: drought
# Nearest neighbors: zma-circ6617-Zm00001d037045, Condition: drought
# Nearest neighbors: zma-circ31807-Zm00001d012634, Condition: control
# Seq of "drought" group: zma-circ20189-Zm00001d037326
# Nearest neighbors: zma-circ6173-Zm00001d021404, Condition: control
# Nearest neighbors: zma-circ21848-Zm00001d038104, Condition: control
# Nearest neighbors: zma-circ17404-Zm00001d014773, Condition: drought
# Nearest neighbors: zma-circ4878-Zm00001d040416, Condition: drought
# Nearest neighbors: zma-circ19452-Zm00001d030102, Condition: drought
# Seq of "drought" group: zma-circ20190-Zm00001d037346
# Nearest neighbors: zma-circ17182-Zm00001d002422, Condition: drought
# Nearest neighbors: zma-circ31894-Zm00001d044495, Condition: control
# Nearest neighbors: zma-circ35102-Zm00001d044495, Condition: drought
# Nearest neighbors: zma-circ3277-Zm00001d028699, Condition: drought
# Nearest neighbors: zma-circ29744--, Condition: control
# Seq of "drought" group: zma-circ20191-Zm00001d038570
# Nearest neighbors: zma-circ2107-Zm00001d003813, Condition: control
# Nearest neighbors: zma-circ967-Zm00001d014188, Condition: drought
# Nearest neighbors: zma-circ21823-Zm00001d004676, Condition: control
# Nearest neighbors: zma-circ17336-Zm00001d030266, Condition: drought
# Nearest neighbors: zma-circ7755-Zm00001d025860, Condition: control
# Seq of "drought" group: zma-circ20192-Zm00001d038999
# Nearest neighbors: zma-circ32077-Zm00001d053954, Condition: drought
# Nearest neighbors: zma-circ17550-Zm00001d043948, Condition: control
# Nearest neighbors: zma-circ17396-Zm00001d014188, Condition: drought
# Nearest neighbors: zma-circ17319-Zm00001d028949, Condition: drought
# Nearest neighbors: zma-circ12580-Zm00001d043948, Condition: drought
# Seq of "drought" group: zma-circ20193-Zm00001d038999
# Nearest neighbors: zma-circ13058-Zm00001d028601, Condition: drought
# Nearest neighbors: zma-circ14779-Zm00001d015328, Condition: drought
# Nearest neighbors: zma-circ37355-Zm00001d016826, Condition: control
# Nearest neighbors: zma-circ1812-Zm00001d010855, Condition: control
# Nearest neighbors: zma-circ12114-Zm00001d033248, Condition: control
# Seq of "drought" group: zma-circ20194-Zm00001d025240
# Nearest neighbors: zma-circ35321-Zm00001d007972, Condition: drought
# Nearest neighbors: zma-circ31510-Zm00001d048527, Condition: control
# Nearest neighbors: zma-circ35761-Zm00001d017043, Condition: control
# Nearest neighbors: zma-circ19875-Zm00001d039678, Condition: drought
# Nearest neighbors: zma-circ8709-Zm00001d020011, Condition: control
# Seq of "drought" group: zma-circ20195-Zm00001d025866
# Nearest neighbors: zma-circ32125-Zm00001d020537, Condition: control
# Nearest neighbors: zma-circ20558-Zm00001d031712, Condition: control
# Nearest neighbors: zma-circ14277-Zm00001d005969, Condition: drought
# Nearest neighbors: zma-circ16869-Zm00001d034256, Condition: drought
# Nearest neighbors: zma-circ19646-Zm00001d001983, Condition: drought
# Seq of "drought" group: zma-circ20196-Zm00001d025946
# Nearest neighbors: zma-circ4371-Zm00001d006657, Condition: control
# Nearest neighbors: zma-circ21468-Zm00001d022131, Condition: control
# Nearest neighbors: zma-circ35574-Zm00001d016254, Condition: control
# Nearest neighbors: zma-circ16484-Zm00001d040342, Condition: drought
# Nearest neighbors: zma-circ34561-Zm00001d013466, Condition: drought
# Seq of "drought" group: zma-circ20197-Zm00001d026270
# Nearest neighbors: zma-circ19102-Zm00001d037813, Condition: drought
# Nearest neighbors: zma-circ4064-Zm00001d028218, Condition: control
# Nearest neighbors: zma-circ19839-Zm00001d045783, Condition: drought
# Nearest neighbors: zma-circ20372-Zm00001d048122, Condition: drought
# Nearest neighbors: zma-circ34837-Zm00001d051666, Condition: control
# Seq of "drought" group: zma-circ20198-Zm00001d026653
# Nearest neighbors: zma-circ15554-Zm00001d029095, Condition: drought
# Nearest neighbors: zma-circ4543-Zm00001d029095, Condition: control
# Nearest neighbors: zma-circ29030--, Condition: control
# Nearest neighbors: zma-circ16113-Zm00001d038097, Condition: drought
# Nearest neighbors: zma-circ12565-Zm00001d042540, Condition: drought
# Seq of "drought" group: zma-circ20199-Zm00001d027934
# Nearest neighbors: zma-circ35321-Zm00001d007972, Condition: drought
# Nearest neighbors: zma-circ35761-Zm00001d017043, Condition: control
# Nearest neighbors: zma-circ21438-Zm00001d045872, Condition: control
# Nearest neighbors: zma-circ18387-Zm00001d014568, Condition: control
# Nearest neighbors: zma-circ35735-Zm00001d021864, Condition: control
# Seq of "drought" group: zma-circ20200-Zm00001d028474
# Nearest neighbors: zma-circ5971-Zm00001d005779, Condition: control
# Nearest neighbors: zma-circ16950-Zm00001d045574, Condition: drought
# Nearest neighbors: zma-circ13558-Zm00001d039144, Condition: control
# Nearest neighbors: zma-circ19302-Zm00001d040422, Condition: drought
# Nearest neighbors: zma-circ4488-Zm00001d020515, Condition: control
# Seq of "drought" group: zma-circ20201-Zm00001d028549
# Nearest neighbors: zma-circ15217-Zm00001d042262, Condition: drought
# Nearest neighbors: zma-circ28239--, Condition: control
# Nearest neighbors: zma-circ15706-Zm00001d016070, Condition: drought
# Nearest neighbors: zma-circ15153-Zm00001d009948, Condition: drought
# Nearest neighbors: zma-circ2167-Zm00001d044757, Condition: drought
# Seq of "drought" group: zma-circ20202-Zm00001d029753
# Nearest neighbors: zma-circ14423-Zm00001d023506, Condition: drought
# Nearest neighbors: zma-circ13286-Zm00001d040154, Condition: control
# Nearest neighbors: zma-circ4104-Zm00001d049049, Condition: drought
# Nearest neighbors: zma-circ20494-Zm00001d006567, Condition: control
# Nearest neighbors: zma-circ21832-Zm00001d006567, Condition: control
# Seq of "drought" group: zma-circ20203-Zm00001d029848
# Nearest neighbors: zma-circ20546-Zm00001d030101, Condition: control
# Nearest neighbors: zma-circ35189-Zm00001d047045, Condition: drought
# Nearest neighbors: zma-circ9443-Zm00001d013729, Condition: control
# Nearest neighbors: zma-circ16147-Zm00001d024815, Condition: drought
# Nearest neighbors: zma-circ14834-Zm00001d046630, Condition: drought
# Seq of "drought" group: zma-circ20204-Zm00001d030725
# Nearest neighbors: zma-circ9296-Zm00001d030725, Condition: drought
# Nearest neighbors: zma-circ34575-Zm00001d017398, Condition: drought
# Nearest neighbors: zma-circ11796-Zm00001d052721, Condition: control
# Nearest neighbors: zma-circ11606-Zm00001d041550, Condition: control
# Nearest neighbors: zma-circ28708--, Condition: control
# Seq of "drought" group: zma-circ20205-Zm00001d031064
# Nearest neighbors: zma-circ60-Zm00001d011622, Condition: control
# Nearest neighbors: zma-circ8631-Zm00001d040422, Condition: control
# Nearest neighbors: zma-circ4496-Zm00001d022586, Condition: drought
# Nearest neighbors: zma-circ21919-Zm00001d048133, Condition: control
# Nearest neighbors: zma-circ33375-Zm00001d017121, Condition: control
# Seq of "drought" group: zma-circ20206-Zm00001d031258
# Nearest neighbors: zma-circ32994-Zm00001d011750, Condition: drought
# Nearest neighbors: zma-circ19203-Zm00001d013984, Condition: drought
# Nearest neighbors: zma-circ8437-Zm00001d012858, Condition: drought
# Nearest neighbors: zma-circ1582-Zm00001d000040, Condition: control
# Nearest neighbors: zma-circ16322-Zm00001d016479, Condition: drought
# Seq of "drought" group: zma-circ20207-Zm00001d032280
# Nearest neighbors: zma-circ19508-Zm00001d015890, Condition: drought
# Nearest neighbors: zma-circ20726-Zm00001d028143, Condition: control
# Nearest neighbors: zma-circ13053-Zm00001d028143, Condition: drought
# Nearest neighbors: zma-circ21177-Zm00001d043484, Condition: control
# Nearest neighbors: zma-circ3031-Zm00001d036741, Condition: control
# Seq of "drought" group: zma-circ20208-Zm00001d033020
# Nearest neighbors: zma-circ20897-Zm00001d033020, Condition: control
# Nearest neighbors: zma-circ6655-Zm00001d008727, Condition: control
# Nearest neighbors: zma-circ15112-Zm00001d053234, Condition: drought
# Nearest neighbors: zma-circ17448-Zm00001d046865, Condition: drought
# Nearest neighbors: zma-circ27155-Zm00001d040212, Condition: control
# Seq of "drought" group: zma-circ20209-Zm00001d033020
# Nearest neighbors: zma-circ20898-Zm00001d033020, Condition: control
# Nearest neighbors: zma-circ20035-Zm00001d033020, Condition: drought
# Nearest neighbors: zma-circ37870-Zm00001d003195, Condition: control
# Nearest neighbors: zma-circ37368-Zm00001d003195, Condition: control
# Nearest neighbors: zma-circ21987-Zm00001d033020, Condition: drought
# Seq of "drought" group: zma-circ20210-Zm00001d033108
# Nearest neighbors: zma-circ4235-Zm00001d025894, Condition: drought
# Nearest neighbors: zma-circ17103-Zm00001d043305, Condition: drought
# Nearest neighbors: zma-circ31443-Zm00001d039349, Condition: control
# Nearest neighbors: zma-circ28525--, Condition: control
# Nearest neighbors: zma-circ34561-Zm00001d013466, Condition: drought
# Seq of "drought" group: zma-circ20211-Zm00001d033244
# Nearest neighbors: zma-circ711-Zm00001d039138, Condition: drought
# Nearest neighbors: zma-circ256-Zm00001d014188, Condition: control
# Nearest neighbors: zma-circ4079-Zm00001d026479, Condition: control
# Nearest neighbors: zma-circ11772-Zm00001d045042, Condition: control
# Nearest neighbors: zma-circ4559-Zm00001d014188, Condition: drought
# Seq of "drought" group: zma-circ20212-Zm00001d033272
# Nearest neighbors: zma-circ6298-Zm00001d020053, Condition: control
# Nearest neighbors: zma-circ21945-Zm00001d020053, Condition: drought
# Nearest neighbors: zma-circ20355-Zm00001d034796, Condition: drought
# Nearest neighbors: zma-circ19882-Zm00001d041900, Condition: drought
# Nearest neighbors: zma-circ17950-Zm00001d002089, Condition: control
# Seq of "drought" group: zma-circ20213-Zm00001d033535
# Nearest neighbors: zma-circ20980-Zm00001d042347, Condition: control
# Nearest neighbors: zma-circ20030-Zm00001d030340, Condition: drought
# Nearest neighbors: zma-circ26600-Zm00001d021301, Condition: control
# Nearest neighbors: zma-circ19357-Zm00001d005460, Condition: drought
# Nearest neighbors: zma-circ8772-Zm00001d003917, Condition: control
# Seq of "drought" group: zma-circ20214-Zm00001d033886
# Nearest neighbors: zma-circ4989-Zm00001d013019, Condition: control
# Nearest neighbors: zma-circ14607-Zm00001d030266, Condition: drought
# Nearest neighbors: zma-circ6338-Zm00001d011595, Condition: control
# Nearest neighbors: zma-circ4467-Zm00001d039856, Condition: drought
# Nearest neighbors: zma-circ18469-Zm00001d039758, Condition: control
# Seq of "drought" group: zma-circ20215-Zm00001d034038
# Nearest neighbors: zma-circ14522-Zm00001d027481, Condition: drought
# Nearest neighbors: zma-circ19162-Zm00001d030357, Condition: drought
# Nearest neighbors: zma-circ34196-Zm00001d007397, Condition: drought
# Nearest neighbors: zma-circ6954-Zm00001d026483, Condition: drought
# Nearest neighbors: zma-circ29396--, Condition: control
# Seq of "drought" group: zma-circ20216-Zm00001d012815
# Nearest neighbors: zma-circ21615-Zm00001d005538, Condition: control
# Nearest neighbors: zma-circ13188-Zm00001d050339, Condition: control
# Nearest neighbors: zma-circ3168-Zm00001d047634, Condition: control
# Nearest neighbors: zma-circ18953-Zm00001d050339, Condition: drought
# Nearest neighbors: zma-circ17404-Zm00001d014773, Condition: drought
# Seq of "drought" group: zma-circ20217-Zm00001d013669
# Nearest neighbors: zma-circ2376-Zm00001d033210, Condition: control
# Nearest neighbors: zma-circ10237-Zm00001d033210, Condition: drought
# Nearest neighbors: zma-circ33980-Zm00001d046949, Condition: control
# Nearest neighbors: zma-circ11344-Zm00001d043682, Condition: control
# Nearest neighbors: zma-circ10100-Zm00001d043682, Condition: drought
# Seq of "drought" group: zma-circ20218-Zm00001d014073
# Nearest neighbors: zma-circ21552-Zm00001d011411, Condition: control
# Nearest neighbors: zma-circ21292-Zm00001d043860, Condition: control
# Nearest neighbors: zma-circ4656-Zm00001d028464, Condition: control
# Nearest neighbors: zma-circ35197-Zm00001d053625, Condition: drought
# Nearest neighbors: zma-circ20499-Zm00001d007357, Condition: control
# Seq of "drought" group: zma-circ20219-Zm00001d014232
# Nearest neighbors: zma-circ19065-Zm00001d005099, Condition: drought
# Nearest neighbors: zma-circ11403-Zm00001d035487, Condition: control
# Nearest neighbors: zma-circ16423-Zm00001d008432, Condition: drought
# Nearest neighbors: zma-circ34665-Zm00001d017373, Condition: drought
# Nearest neighbors: zma-circ17979-Zm00001d006344, Condition: control
# Seq of "drought" group: zma-circ20220-Zm00001d014343
# Nearest neighbors: zma-circ7763-Zm00001d026490, Condition: control
# Nearest neighbors: zma-circ18882-Zm00001d032790, Condition: drought
# Nearest neighbors: zma-circ11653-Zm00001d005818, Condition: control
# Nearest neighbors: zma-circ21995-Zm00001d012797, Condition: drought
# Nearest neighbors: zma-circ30356--, Condition: control
# Seq of "drought" group: zma-circ20221-Zm00001d014626
# Nearest neighbors: zma-circ20787-Zm00001d008363, Condition: control
# Nearest neighbors: zma-circ33709-Zm00001d007943, Condition: drought
# Nearest neighbors: zma-circ16800-Zm00001d028960, Condition: drought
# Nearest neighbors: zma-circ28204--, Condition: control
# Nearest neighbors: zma-circ2991-Zm00001d044195, Condition: control
# Seq of "drought" group: zma-circ20222-Zm00001d014761
# Nearest neighbors: zma-circ12528-Zm00001d052079, Condition: drought
# Nearest neighbors: zma-circ13066-Zm00001d029118, Condition: drought
# Nearest neighbors: zma-circ20912-Zm00001d013721, Condition: control
# Nearest neighbors: zma-circ20039-Zm00001d013721, Condition: drought
# Nearest neighbors: zma-circ20905-Zm00001d034701, Condition: control
# Seq of "drought" group: zma-circ20223-Zm00001d015245
# Nearest neighbors: zma-circ6826-Zm00001d026439, Condition: drought
# Nearest neighbors: zma-circ31412-Zm00001d007807, Condition: drought
# Nearest neighbors: zma-circ17147-Zm00001d021187, Condition: drought
# Nearest neighbors: zma-circ21862-Zm00001d026119, Condition: control
# Nearest neighbors: zma-circ15803-Zm00001d049958, Condition: drought
# Seq of "drought" group: zma-circ20224-Zm00001d015259
# Nearest neighbors: zma-circ20571-Zm00001d033798, Condition: control
# Nearest neighbors: zma-circ16872-Zm00001d034719, Condition: drought
# Nearest neighbors: zma-circ8823-Zm00001d035598, Condition: control
# Nearest neighbors: zma-circ19817-Zm00001d014912, Condition: drought
# Nearest neighbors: zma-circ2712-Zm00001d045160, Condition: control
# Seq of "drought" group: zma-circ20225-Zm00001d017756
# Nearest neighbors: zma-circ13148-Zm00001d047455, Condition: drought
# Nearest neighbors: zma-circ28327--, Condition: control
# Nearest neighbors: zma-circ5858-Zm00001d011309, Condition: control
# Nearest neighbors: zma-circ1617-Zm00001d051187, Condition: drought
# Nearest neighbors: zma-circ85-Zm00001d040082, Condition: control
# Seq of "drought" group: zma-circ20226-Zm00001d045472
# Nearest neighbors: zma-circ8328-Zm00001d026501, Condition: drought
# Nearest neighbors: zma-circ19910-Zm00001d023373, Condition: drought
# Nearest neighbors: zma-circ34532-Zm00001d043724, Condition: drought
# Nearest neighbors: zma-circ20156-Zm00001d008614, Condition: drought
# Nearest neighbors: zma-circ14457-Zm00001d025131, Condition: drought
# Seq of "drought" group: zma-circ20227-Zm00001d047053
# Nearest neighbors: zma-circ20214-Zm00001d033886, Condition: drought
# Nearest neighbors: zma-circ18194-Zm00001d020711, Condition: control
# Nearest neighbors: zma-circ421-Zm00001d025125, Condition: control
# Nearest neighbors: zma-circ19769-Zm00001d032016, Condition: drought
# Nearest neighbors: zma-circ21933-Zm00001d039580, Condition: drought
# Seq of "drought" group: zma-circ20228-Zm00001d048783
# Nearest neighbors: zma-circ16372-Zm00001d048783, Condition: drought
# Nearest neighbors: zma-circ14871-Zm00001d048783, Condition: control
# Nearest neighbors: zma-circ20913-Zm00001d014378, Condition: control
# Nearest neighbors: zma-circ28747--, Condition: control
# Nearest neighbors: zma-circ10852-Zm00001d004172, Condition: control
# Seq of "drought" group: zma-circ20229-Zm00001d048839
# Nearest neighbors: zma-circ9942-Zm00001d028429, Condition: control
# Nearest neighbors: zma-circ13469-Zm00001d007113, Condition: control
# Nearest neighbors: zma-circ32577-Zm00001d029806, Condition: control
# Nearest neighbors: zma-circ6804-Zm00001d039674, Condition: drought
# Nearest neighbors: zma-circ30455--, Condition: control
# Seq of "drought" group: zma-circ20230-Zm00001d049232
# Nearest neighbors: zma-circ16681-Zm00001d037035, Condition: drought
# Nearest neighbors: zma-circ2093-Zm00001d020001, Condition: control
# Nearest neighbors: zma-circ4395-Zm00001d027392, Condition: drought
# Nearest neighbors: zma-circ19512-Zm00001d016373, Condition: drought
# Nearest neighbors: zma-circ15497-Zm00001d025100, Condition: drought
# Seq of "drought" group: zma-circ20231-Zm00001d049297
# Nearest neighbors: zma-circ29016--, Condition: control
# Nearest neighbors: zma-circ34660-Zm00001d016926, Condition: drought
# Nearest neighbors: zma-circ19141-Zm00001d027715, Condition: drought
# Nearest neighbors: zma-circ16157-Zm00001d025203, Condition: drought
# Nearest neighbors: zma-circ17212-Zm00001d006717, Condition: drought
# Seq of "drought" group: zma-circ20232-Zm00001d049674
# Nearest neighbors: zma-circ20776-Zm00001d049674, Condition: control
# Nearest neighbors: zma-circ19403-Zm00001d038675, Condition: drought
# Nearest neighbors: zma-circ31518-Zm00001d012017, Condition: control
# Nearest neighbors: zma-circ4915-Zm00001d025750, Condition: control
# Nearest neighbors: zma-circ21638-Zm00001d036624, Condition: control
# Seq of "drought" group: zma-circ20233-Zm00001d049707
# Nearest neighbors: zma-circ20479-Zm00001d003373, Condition: control
# Nearest neighbors: zma-circ4239-Zm00001d027333, Condition: drought
# Nearest neighbors: zma-circ12567-Zm00001d042804, Condition: drought
# Nearest neighbors: zma-circ15933-Zm00001d043023, Condition: drought
# Nearest neighbors: zma-circ15860-Zm00001d011147, Condition: drought
# Seq of "drought" group: zma-circ20234-Zm00001d050043
# Nearest neighbors: zma-circ21993-Zm00001d034809, Condition: drought
# Nearest neighbors: zma-circ18469-Zm00001d039758, Condition: control
# Nearest neighbors: zma-circ35267-Zm00001d018036, Condition: drought
# Nearest neighbors: zma-circ18703-Zm00001d044478, Condition: drought
# Nearest neighbors: zma-circ8168-Zm00001d001788, Condition: drought
# Seq of "drought" group: zma-circ20235-Zm00001d051211
# Nearest neighbors: zma-circ13853-Zm00001d051211, Condition: drought
# Nearest neighbors: zma-circ6056-Zm00001d051211, Condition: control
# Nearest neighbors: zma-circ3434-Zm00001d051211, Condition: control
# Nearest neighbors: zma-circ1263-Zm00001d051211, Condition: control
# Nearest neighbors: zma-circ19312-Zm00001d043294, Condition: drought
# Seq of "drought" group: zma-circ20236-Zm00001d051590
# ...
# Nearest neighbors: zma-circ33107-Zm00001d012735, Condition: drought
# Nearest neighbors: zma-circ1384-Zm00001d014674, Condition: drought
# Nearest neighbors: zma-circ34511-Zm00001d053401, Condition: drought
# Seq of "drought" group: zma-circ31725-Zm00001d025819
# Nearest neighbors: zma-circ31885-Zm00001d017526, Condition: control
# Nearest neighbors: zma-circ19959-Zm00001d051913, Condition: drought
# Nearest neighbors: zma-circ4171-Zm00001d022388, Condition: drought
# Nearest neighbors: zma-circ35186-Zm00001d017798, Condition: drought
# Nearest neighbors: zma-circ16048-Zm00001d006382, Condition: drought
# Seq of "drought" group: zma-circ31726-Zm00001d033160
# Nearest neighbors: zma-circ16528-Zm00001d043982, Condition: drought
# Nearest neighbors: zma-circ34607-Zm00001d052074, Condition: drought
# Nearest neighbors: zma-circ19729-Zm00001d026696, Condition: drought
# Nearest neighbors: zma-circ35678-Zm00001d052565, Condition: control
# Nearest neighbors: zma-circ747-Zm00001d010974, Condition: control
# Seq of "drought" group: zma-circ31727-Zm00001d016702
# Nearest neighbors: zma-circ29755--, Condition: control
# Nearest neighbors: zma-circ8100-Zm00001d018896, Condition: drought
# Nearest neighbors: zma-circ3180-Zm00001d040341, Condition: control
# Nearest neighbors: zma-circ33030-Zm00001d047522, Condition: drought
# Nearest neighbors: zma-circ7652-Zm00001d007213, Condition: control
# Seq of "drought" group: zma-circ31728-Zm00001d047461
# Nearest neighbors: zma-circ31737-Zm00001d019374, Condition: control
# Nearest neighbors: zma-circ20315-Zm00001d037059, Condition: drought
# Nearest neighbors: zma-circ14532-Zm00001d027656, Condition: drought
# Nearest neighbors: zma-circ10604-Zm00001d007032, Condition: drought
# Nearest neighbors: zma-circ9712-Zm00001d052364, Condition: control
# Seq of "drought" group: zma-circ31729-Zm00001d048091
# Nearest neighbors: zma-circ13624-Zm00001d028474, Condition: control
# Nearest neighbors: zma-circ7895-Zm00001d013940, Condition: control
# Nearest neighbors: zma-circ19671-Zm00001d035491, Condition: drought
# Nearest neighbors: zma-circ16892-Zm00001d013863, Condition: drought
# Nearest neighbors: zma-circ35011-Zm00001d013040, Condition: drought
# Seq of "drought" group: zma-circ31730-Zm00001d048383
# Nearest neighbors: zma-circ33400-Zm00001d051480, Condition: control
# Nearest neighbors: zma-circ6615-Zm00001d036280, Condition: drought
# Nearest neighbors: zma-circ20349-Zm00001d032531, Condition: drought
# Nearest neighbors: zma-circ28286--, Condition: control
# Nearest neighbors: zma-circ11540-Zm00001d045192, Condition: control
# Seq of "drought" group: zma-circ31731-Zm00001d048452
# Nearest neighbors: zma-circ15443-Zm00001d037557, Condition: drought
# Nearest neighbors: zma-circ3270-Zm00001d037152, Condition: control
# Nearest neighbors: zma-circ4497-Zm00001d022614, Condition: drought
# Nearest neighbors: zma-circ14517-Zm00001d027366, Condition: drought
# Nearest neighbors: zma-circ27408-Zm00001d046939, Condition: drought
# Seq of "drought" group: zma-circ31732-Zm00001d048535
# Nearest neighbors: zma-circ2900-Zm00001d022584, Condition: control
# Nearest neighbors: zma-circ9217-Zm00001d001947, Condition: drought
# Nearest neighbors: zma-circ8553-Zm00001d051664, Condition: control
# Nearest neighbors: zma-circ33673-Zm00001d048524, Condition: drought
# Nearest neighbors: zma-circ3110-Zm00001d019091, Condition: drought
# Seq of "drought" group: zma-circ31969-Zm00001d011474
# Nearest neighbors: zma-circ995-Zm00001d045739, Condition: control
# Nearest neighbors: zma-circ4117-Zm00001d052803, Condition: drought
# Nearest neighbors: zma-circ9943-Zm00001d029684, Condition: control
# Nearest neighbors: zma-circ32829-Zm00001d023510, Condition: control
# Nearest neighbors: zma-circ3844-Zm00001d002759, Condition: control
# Seq of "drought" group: zma-circ31970-Zm00001d011792
# Nearest neighbors: zma-circ8424-Zm00001d034035, Condition: drought
# Nearest neighbors: zma-circ3385-Zm00001d006511, Condition: drought
# Nearest neighbors: zma-circ33263-Zm00001d048520, Condition: control
# Nearest neighbors: zma-circ30217--, Condition: control
# Nearest neighbors: zma-circ9282-Zm00001d028601, Condition: drought
# Seq of "drought" group: zma-circ31971-Zm00001d011854
# Nearest neighbors: zma-circ12870-Zm00001d011610, Condition: drought
# Nearest neighbors: zma-circ20852-Zm00001d007383, Condition: control
# Nearest neighbors: zma-circ6124-Zm00001d031939, Condition: control
# Nearest neighbors: zma-circ33238-Zm00001d007900, Condition: control
# Nearest neighbors: zma-circ13903-Zm00001d008826, Condition: drought
# Seq of "drought" group: zma-circ31972-Zm00001d012061
# Nearest neighbors: zma-circ15242-Zm00001d043953, Condition: drought
# Nearest neighbors: zma-circ34363-Zm00001d007599, Condition: control
# Nearest neighbors: zma-circ2170-Zm00001d046097, Condition: drought
# Nearest neighbors: zma-circ19590-Zm00001d042908, Condition: drought
# Nearest neighbors: zma-circ19539-Zm00001d051502, Condition: drought
# Seq of "drought" group: zma-circ31973-Zm00001d000328
# Nearest neighbors: zma-circ4402-Zm00001d028902, Condition: drought
# Nearest neighbors: zma-circ19446-Zm00001d029004, Condition: drought
# Nearest neighbors: zma-circ19416-Zm00001d024679, Condition: drought
# Nearest neighbors: zma-circ34742-Zm00001d017961, Condition: drought
# Nearest neighbors: zma-circ756-Zm00001d024009, Condition: control
# Seq of "drought" group: zma-circ31974-Zm00001d039330
# Nearest neighbors: zma-circ15685-Zm00001d014967, Condition: drought
# Nearest neighbors: zma-circ18089-Zm00001d047392, Condition: control
# Nearest neighbors: zma-circ17413-Zm00001d015364, Condition: drought
# Nearest neighbors: zma-circ15074-Zm00001d050216, Condition: drought
# Nearest neighbors: zma-circ15862-Zm00001d011231, Condition: drought
# Seq of "drought" group: zma-circ31975-Zm00001d007960
# Nearest neighbors: zma-circ9036-Zm00001d013019, Condition: control
# Nearest neighbors: zma-circ6285-Zm00001d047491, Condition: control
# Nearest neighbors: zma-circ6942-Zm00001d044271, Condition: drought
# Nearest neighbors: zma-circ18926-Zm00001d045109, Condition: drought
# Nearest neighbors: zma-circ917-Zm00001d049211, Condition: control
# Seq of "drought" group: zma-circ31976-Zm00001d036428
# Nearest neighbors: zma-circ10328-Zm00001d038776, Condition: drought
# Nearest neighbors: zma-circ13265-Zm00001d011560, Condition: control
# Nearest neighbors: zma-circ19915-Zm00001d025278, Condition: drought
# Nearest neighbors: zma-circ20016-Zm00001d025278, Condition: drought
# Nearest neighbors: zma-circ27506-Zm00001d049469, Condition: control
# Seq of "drought" group: zma-circ31977-Zm00001d039181
# Nearest neighbors: zma-circ35928-Zm00001d039181, Condition: control
# Nearest neighbors: zma-circ9426-Zm00001d035664, Condition: control
# Nearest neighbors: zma-circ18704-Zm00001d044584, Condition: drought
# Nearest neighbors: zma-circ12131-Zm00001d013367, Condition: control
# Nearest neighbors: zma-circ4589-Zm00001d050612, Condition: control
# Seq of "drought" group: zma-circ31978-Zm00001d015091
# Nearest neighbors: zma-circ27155-Zm00001d040212, Condition: control
# Nearest neighbors: zma-circ5703-Zm00001d020556, Condition: drought
# Nearest neighbors: zma-circ15930-Zm00001d042692, Condition: drought
# Nearest neighbors: zma-circ14676-Zm00001d032950, Condition: drought
# Nearest neighbors: zma-circ6655-Zm00001d008727, Condition: control
# Seq of "drought" group: zma-circ31979-Zm00001d017522
# Nearest neighbors: zma-circ1068-Zm00001d001814, Condition: control
# Nearest neighbors: zma-circ7766-Zm00001d026630, Condition: control
# Nearest neighbors: zma-circ11077-Zm00001d043335, Condition: control
# Nearest neighbors: zma-circ15131-Zm00001d008617, Condition: drought
# Nearest neighbors: zma-circ30284--, Condition: control
# Seq of "drought" group: zma-circ31980-Zm00001d018416
# Nearest neighbors: zma-circ1298-Zm00001d009508, Condition: control
# Nearest neighbors: zma-circ10959-Zm00001d033937, Condition: control
# Nearest neighbors: zma-circ10958-Zm00001d033937, Condition: control
# Nearest neighbors: zma-circ27881--, Condition: control
# Nearest neighbors: zma-circ12556-Zm00001d040026, Condition: drought
# Seq of "drought" group: zma-circ31981-Zm00001d000169
# Nearest neighbors: zma-circ29402--, Condition: control
# Nearest neighbors: zma-circ16631-Zm00001d005001, Condition: drought
# Nearest neighbors: zma-circ28956--, Condition: control
# Nearest neighbors: zma-circ10071-Zm00001d006227, Condition: drought
# Nearest neighbors: zma-circ13878-Zm00001d052445, Condition: drought
# Seq of "drought" group: zma-circ31982-Zm00001d051183
# Nearest neighbors: zma-circ8016-Zm00001d008762, Condition: drought
# Nearest neighbors: zma-circ3158-Zm00001d015272, Condition: control
# Nearest neighbors: zma-circ19469-Zm00001d033155, Condition: drought
# Nearest neighbors: zma-circ13890-Zm00001d053251, Condition: drought
# Nearest neighbors: zma-circ10141-Zm00001d028412, Condition: drought
# Seq of "drought" group: zma-circ31983-Zm00001d053575
# Nearest neighbors: zma-circ19045-Zm00001d002012, Condition: drought
# Nearest neighbors: zma-circ29696--, Condition: control
# Nearest neighbors: zma-circ4238-Zm00001d027333, Condition: drought
# Nearest neighbors: zma-circ4232-Zm00001d025734, Condition: control
# Nearest neighbors: zma-circ34455-Zm00001d007907, Condition: drought
# Seq of "drought" group: zma-circ31984-Zm00001d053813
# Nearest neighbors: zma-circ2645-Zm00001d016402, Condition: control
# Nearest neighbors: zma-circ1845-Zm00001d016070, Condition: control
# Nearest neighbors: zma-circ34198-Zm00001d007886, Condition: drought
# Nearest neighbors: zma-circ31787-Zm00001d053609, Condition: control
# Nearest neighbors: zma-circ34080-Zm00001d012213, Condition: drought
# Seq of "drought" group: zma-circ31985-Zm00001d008176
# Nearest neighbors: zma-circ4-Zm00001d049552, Condition: control
# Nearest neighbors: zma-circ35796-Zm00001d025048, Condition: control
# Nearest neighbors: zma-circ3070-Zm00001d045783, Condition: control
# Nearest neighbors: zma-circ30699-Zm00001d045783, Condition: control
# Nearest neighbors: zma-circ31314-Zm00001d045783, Condition: control
# Seq of "drought" group: zma-circ31986-Zm00001d006561
# Nearest neighbors: zma-circ26863-Zm00001d003855, Condition: control
# Nearest neighbors: zma-circ3188-Zm00001d021512, Condition: control
# Nearest neighbors: zma-circ14621-Zm00001d031316, Condition: drought
# Nearest neighbors: zma-circ6096-Zm00001d002338, Condition: control
# Nearest neighbors: zma-circ10243-Zm00001d014957, Condition: drought
# Seq of "drought" group: zma-circ31987-Zm00001d007599
# Nearest neighbors: zma-circ1797-Zm00001d026079, Condition: control
# Nearest neighbors: zma-circ21913-Zm00001d045573, Condition: control
# Nearest neighbors: zma-circ35846-Zm00001d019700, Condition: control
# Nearest neighbors: zma-circ1169-Zm00001d040422, Condition: drought
# Nearest neighbors: zma-circ20013-Zm00001d038752, Condition: drought
# Seq of "drought" group: zma-circ31988-Zm00001d036981
# Nearest neighbors: zma-circ10332-Zm00001d031764, Condition: drought
# Nearest neighbors: zma-circ34464-Zm00001d016838, Condition: drought
# Nearest neighbors: zma-circ4656-Zm00001d028464, Condition: control
# Nearest neighbors: zma-circ14096-Zm00001d019591, Condition: drought
# Nearest neighbors: zma-circ35712-Zm00001d053873, Condition: control
# Seq of "drought" group: zma-circ31989-Zm00001d047805
# Nearest neighbors: zma-circ10832-Zm00001d021806, Condition: control
# Nearest neighbors: zma-circ10161-Zm00001d043768, Condition: drought
# Nearest neighbors: zma-circ17206-Zm00001d006212, Condition: drought
# Nearest neighbors: zma-circ32892-Zm00001d011597, Condition: control
# Nearest neighbors: zma-circ32594-Zm00001d017303, Condition: control
# Seq of "drought" group: zma-circ31990-Zm00001d048511
# Nearest neighbors: zma-circ17155-Zm00001d021802, Condition: drought
# Nearest neighbors: zma-circ12170-Zm00001d048526, Condition: control
# Nearest neighbors: zma-circ8214-Zm00001d006480, Condition: drought
# Nearest neighbors: zma-circ10214-Zm00001d020827, Condition: drought
# Nearest neighbors: zma-circ17537-Zm00001d042267, Condition: control
# Seq of "drought" group: zma-circ31991-Zm00001d049816
# Nearest neighbors: zma-circ12892-Zm00001d043425, Condition: drought
# Nearest neighbors: zma-circ7258-Zm00001d041353, Condition: drought
# Nearest neighbors: zma-circ19587-Zm00001d042585, Condition: drought
# Nearest neighbors: zma-circ8329-Zm00001d026548, Condition: drought
# Nearest neighbors: zma-circ17058-Zm00001d039252, Condition: drought
# Seq of "drought" group: zma-circ31992-Zm00001d053675
# Nearest neighbors: zma-circ34395-Zm00001d053675, Condition: drought
# Nearest neighbors: zma-circ19686-Zm00001d037156, Condition: drought
# Nearest neighbors: zma-circ12754-Zm00001d029170, Condition: drought
# Nearest neighbors: zma-circ19283-Zm00001d009288, Condition: drought
# Nearest neighbors: zma-circ4473-Zm00001d041083, Condition: drought
# Seq of "drought" group: zma-circ31993-Zm00001d041476
# Nearest neighbors: zma-circ16749-Zm00001d024291, Condition: drought
# Nearest neighbors: zma-circ16620-Zm00001d003904, Condition: drought
# Nearest neighbors: zma-circ6307-Zm00001d006131, Condition: control
# Nearest neighbors: zma-circ14505-Zm00001d026635, Condition: drought
# Nearest neighbors: zma-circ6028-Zm00001d027267, Condition: control
# Seq of "drought" group: zma-circ31994-Zm00001d043149
# Nearest neighbors: zma-circ29792--, Condition: control
# Nearest neighbors: zma-circ11099-Zm00001d021390, Condition: control
# Nearest neighbors: zma-circ38406--, Condition: control
# Nearest neighbors: zma-circ19791-Zm00001d012964, Condition: drought
# Nearest neighbors: zma-circ29790--, Condition: control
# Seq of "drought" group: zma-circ31995-Zm00001d038163
# Nearest neighbors: zma-circ37309-Zm00001d038163, Condition: drought
# Nearest neighbors: zma-circ37310-Zm00001d038163, Condition: drought
# Nearest neighbors: zma-circ32568-Zm00001d023640, Condition: control
# Nearest neighbors: zma-circ11764-Zm00001d015327, Condition: control
# Nearest neighbors: zma-circ33429-Zm00001d015327, Condition: control
# Seq of "drought" group: zma-circ31996-Zm00001d017700
# Nearest neighbors: zma-circ1791-Zm00001d022134, Condition: control
# Nearest neighbors: zma-circ35328-Zm00001d016920, Condition: drought
# Nearest neighbors: zma-circ32138-Zm00001d018522, Condition: control
# Nearest neighbors: zma-circ20923-Zm00001d016595, Condition: control
# Nearest neighbors: zma-circ13073-Zm00001d030666, Condition: drought
# Seq of "drought" group: zma-circ31997-Zm00001d017866
# Nearest neighbors: zma-circ34354-Zm00001d048442, Condition: drought
# Nearest neighbors: zma-circ33082-Zm00001d023580, Condition: drought
# Nearest neighbors: zma-circ34333-Zm00001d046226, Condition: drought
# Nearest neighbors: zma-circ27379-Zm00001d007065, Condition: drought
# Nearest neighbors: zma-circ14828-Zm00001d046385, Condition: drought
# Seq of "drought" group: zma-circ31998-Zm00001d018004
# Nearest neighbors: zma-circ7312-Zm00001d038163, Condition: drought
# Nearest neighbors: zma-circ7313-Zm00001d038163, Condition: drought
# Nearest neighbors: zma-circ7311-Zm00001d038163, Condition: drought
# Nearest neighbors: zma-circ32065-Zm00001d004916, Condition: control
# Nearest neighbors: zma-circ7310-Zm00001d038163, Condition: drought
# Seq of "drought" group: zma-circ31999-Zm00001d018474
# Nearest neighbors: zma-circ35292-Zm00001d026231, Condition: drought
# Nearest neighbors: zma-circ30694-Zm00001d017274, Condition: control
# Nearest neighbors: zma-circ9267-Zm00001d023587, Condition: drought
# Nearest neighbors: zma-circ32540-Zm00001d018748, Condition: control
# Nearest neighbors: zma-circ7281-Zm00001d021306, Condition: drought
# Seq of "drought" group: zma-circ32015-Zm00001d051908
# Nearest neighbors: zma-circ14285-Zm00001d006447, Condition: drought
# Nearest neighbors: zma-circ9342-Zm00001d044902, Condition: drought
# Nearest neighbors: zma-circ784-Zm00001d045042, Condition: control
# Nearest neighbors: zma-circ21959-Zm00001d006881, Condition: drought
# Nearest neighbors: zma-circ28287--, Condition: control
# Number of iterated drought stress sequences: 11206
# Total number of neighbors in the "drought" group: 24270
# Total number of neighbors in the "control" group": 7979
# Percentage of neighbors in the "drought" group: 53.51%
# Percentage of neighbors in the "control" group: 17.59%
